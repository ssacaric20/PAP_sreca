# %% [markdown]
# <div style="text-align: center;">
#
# # SVEUČILIŠTE U ZAGREBU
# # FAKULTET ORGANIZACIJE I INFORMATIKE
# # V A R A Ž D I N
# <br><br><br><br><br><br>
# **Sandra Sačarić
# Studij: Informacijski i poslovni sustavi**
# <br><br><br><br><br><br><br><br><br><br><br><br><br>
# # ANALIZA ČIMBENIKA SREĆE
# # PROJEKT IZ KOLEGIJA PROGRAMIRANJE ZA ANALIZU PODATAKA
# <br><br><br><br><br><br><br><br><br><br>
# **Mentor:**
# **Prof. dr. sc. Markus Schatten**
# <br><br><br><br><br><br><br><br>
# **Varaždin, siječanj 2025.**
#
# </div>

# %% [markdown]
# <br><br><br><br>
#
# Sandra Sačarić
#
# Izjava o izvornosti
#
# *Izjavljujem da je moj projekt izvorni rezultat mojeg rada te da se u izradi istoga nisam koristio drugim izvorima osim onima koji su u njemu navedeni. Za izradu rada su korištene etički prikladne i prihvatljive metode i tehnike rada.*
# **_______________________________________________________________________________________________________________________________**
#
# <br><br><br><br>

# %% [markdown]
# # 1. Uvod
#
# Sreća predstavlja univerzalno poželjan cilj koji nadjačava sve moguće društvene, ekonomske i kulturne razlike među ljudima. Razumijevanje čimbenika koji doprinose sreći ključno je za oblikovanje sustava koji postoje u svrhe ljudskog korištenja i donošenja odluka, koje za cilj imaju potaknuti rast pojedinca i zajednica.
#
# Motivacija za odabir ove teme leži u činjenici da sreća pojedinca ovisi o načinu na koji su ljudi tretirani te okolini u kojoj djeluju, kao i mnoštvo drugih varijabli koje imaju izravan utjecaj na produktivnost i učinkovitost obavljanja bilo kakvog procesa. Općepoznato je da zadovoljni pojedinci lakše ostvaruju profesionalne i osobne ciljeve, dok zadovoljne zajednice stvaraju povoljne uvjete za rast i napredak civilizacije. Razumijevanjem čimbenika koji utječu na sreću mogu se oblikovati strategije za unaprjeđenje kvalitete života i održivog razvoja, čime se pozitivno doprinosi društvu u cjelini.
#
# Cilj ovog projekta je analizirati čimbenike koji utječu na sreću koristeći podatke dostupne u World Happiness Reportu. Projekt se temelji na integraciji i obradi podataka iz više izvora, što omogućuje istraživanje trendova i identifikaciju ključnih uzoraka (patterns) koji mogu biti korisni u stvaranju modela az donošenje odluka. Analiza će uključivati korelaciju čimbenika poput BDP-a po stanovniku, socijalne podrške, očekivanog trajanja života i slobode donošenja odluka s indeksom sreće. Dobiveni rezultati će pružit dublji uvid u međuzavisnost čimbenika sreće i njihov utjecaj.
#
# Ovaj projekt nastojat će demonstrirati kompetencije u radu s heterogenim skupovima podataka, njihovoj integraciji u sustave za pohranu, tj. baze podataka, kao i primjena alata za analizu i vizualizaciju. Time će se prikazati praktična i interdisciplinarna primjena znanja iz područja obrade podataka, vizualizacije i razvoja aplikacija.
#
#
# <br><br>
#
# Link na GitHub repozitorij u kojem se nalaze potrebne datoteke za pokretanje programa:

# %% [markdown]
# # 2. Opis implementacije
#
#
# Implementacija sustava za analizu čimbenika sreće sadržat će nekoliko ključnih komponenti koje obuhvaćaju prikupljanje, obradu, pohranu, analizu i vizualizaciju podataka te izradu sučelja za pristup istim. Svaka od komponenti implementirana je u skladu s definiranim zahtjevima projekta i određenim standardima obrade podataka.
#
# 1. Prikupljanje podataka
#
# Podaci vezani za indeks sreće preuzeti su s platforme Kaggle, iz skupa podataka vezanih za World Happiness Report [1]. Kasnije kroz fazu prikupljanja podataka utvrđeno je kako bi se mogla razmotriti i povezanost indeksa sreće s globalnim indeksom mira. Skup podataka preuzet sa stranice Vision of Humanity [2], a sadrži kvalitativne i kvantitativne podatke. Oba skupa podataka koriste različite formate:
#
# •	CSV format: Podaci o indeksu sreće zemalja s faktorima poput BDP-a, socijalne podrške, očekivanog trajanja života, percepcije korupcije u vladi i poslovanju, velikodušnosti, pozitivnog i negativnog učinka, i slobode donošenja odluka.<br>
# •	XLSX format: Podaci o globalnom indeksu mira koji sadrže podatke o razini sigurnosti i zaštite, opsegu postojećeg sukoba, i stupnju militarizacije, no za svrher ovog projekta koristit će se samo sveukupna ocjena indeksa mira.
#
# Izvori podataka su jasno navedeni u literaturi, uz navođenje poveznica na originalne izvore.
#
# ________________________________________
# 2. Pretprocesiranje i integracija podataka
#
# Prikupljeni podaci prošli su kroz nekoliko faza obrade kako bi se osigurala njihova konzistentnost i kvaliteta:
#
# •	Čišćenje podataka: Provjera dupliciranih i nepotpunih vrijednosti te popunjavanje nedostajućih primjenom metoda interpolacije i fillna.<br>
# •	Transformacija podataka: Normalizacija numeričkih vrijednosti radi usporedbe između skupova podataka različitih razmjera.<br>
#
# Za integraciju je korišten Pythonov modul Pandas.
#
# ________________________________________
# 3. Pohrana podataka
#
# Integrirani skup podataka pohranjen je u relacijskoj bazi podataka koristeći sustav SQLite. Struktura baze optimizirana je za analizu i uključuje sljedeće tablice:
#
# •	file: Sadrži podatke o indeksu sreće zemalja po godinama, sa svim prijašnje navedenim čimbenicima.<br>
# •	pis_file: Sadrži podatke o indeksu mira po godinama, bez dodatnih čimbenika.<br>
#
# ________________________________________
# 4. Izrada sučelja za pristup podacima
#
# Za pristup podacima razvijen je REST API koristeći Flask. API omogućuje dohvaćanje podataka prema sljedećim kriterijima:
#
# •	Pregled indeksa sreće po godinama za odabranu zemlju.<br>
# •	Dohvaćanje čimbenika sreće za određenu zemlju.<br>
# •	Filtriranje podataka prema minimalnom i maksimalnom indeksu sreće.<br>
# •	Prikaz preklapanja indeksa mira i indeksa sreće prema fiksnim kriterijima, ukoliko postoji.
#
# ________________________________________
# 5. Bazična analiza i vizualizacija
#
# Za analizu podataka implementirane su osnovne statističke metode i vizualizacije koristeći alate Matplotlib i Seaborn:
#
# •	Trendovi indeksa sreće kroz godine: Boxplot prikazuje promjene sreće u odabranim zemljama kroz vremenski period.<br>
# •	Korelacijska analiza čimbenika sreće: Toplinska karta prikazuje međusobnu povezanost čimbenika kao što su BDP i socijalna podrška.<br>
# •	Distribucija podataka: Za prikaz distribucije podataka koristit će se čimbenici koji su pokazali značajnu razinu korelacije s indeksom sreće.
#
# ________________________________________
# Ovaj modularni pristup omogućava lako proširenje sustava za dodatne funkcionalnosti, kao što su integracija novih izvora podataka ili implementacija naprednih analitičkih modela. Svaka komponenta sustava detaljno je dokumentirana kako bi se olakšala reprodukcija rezultata.
#
#
# <br>

# %% [markdown]
# # 3. Prikaz rada aplikacije
#
# Kao što je ranije navedeno, aplikacija se sastoji od tri glavna segmenta: obrade podataka i kreiranja baze, postavljanja Flask servera te vizualizacije podataka. U nastavku će svaki od tih dijelova biti ukratko predstavljen kako bi se prikazala njihova svrha i način implementacije.
#
# Za početak će se instalirati potrebne resurse.

# %%
# !pip install flask
# !pip install pandas
# !pip install openpyxl
# !pip install numpy
# !pip install matplotlib seaborn
# Out:
# Requirement already satisfied: flask in c:\users\sandra\anaconda3\lib\site-packages (3.0.3)
# Requirement already satisfied: Werkzeug>=3.0.0 in c:\users\sandra\anaconda3\lib\site-packages (from flask) (3.0.3)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\users\sandra\anaconda3\lib\site-packages (from flask) (3.1.4)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\users\sandra\anaconda3\lib\site-packages (from flask) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\sandra\anaconda3\lib\site-packages (from flask) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in c:\users\sandra\anaconda3\lib\site-packages (from flask) (1.6.2)
# Requirement already satisfied: colorama in c:\users\sandra\anaconda3\lib\site-packages (from click>=8.1.3->flask) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sandra\anaconda3\lib\site-packages (from Jinja2>=3.1.2->flask) (2.1.3)
# Requirement already satisfied: pandas in c:\users\sandra\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\sandra\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\sandra\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sandra\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sandra\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\sandra\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: openpyxl in c:\users\sandra\anaconda3\lib\site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in c:\users\sandra\anaconda3\lib\site-packages (from openpyxl) (1.1.0)
# Requirement already satisfied: numpy in c:\users\sandra\anaconda3\lib\site-packages (1.26.4)
# Requirement already satisfied: matplotlib in c:\users\sandra\anaconda3\lib\site-packages (3.9.2)
# Requirement already satisfied: seaborn in c:\users\sandra\anaconda3\lib\site-packages (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sandra\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\sandra\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sandra\anaconda3\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\sandra\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.23 in c:\users\sandra\anaconda3\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\sandra\anaconda3\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\sandra\anaconda3\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\sandra\anaconda3\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sandra\anaconda3\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in c:\users\sandra\anaconda3\lib\site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sandra\anaconda3\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sandra\anaconda3\lib\site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\sandra\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %% [markdown]
# <br>
#
# ## 3.1. Obrađivanje podataka i kreiranje baze
# <br>

# %% [markdown]
# Uvest će se dva različita skupa podataka, jedan tipa CSV a drugi XLSX. Za svaki će se najprije prikazati prvih par redaka za svaki stupac, a onda će se korak po korak set prilagođavati za lakšu manipulaciju podacima u kasnijoj fazi projekta. Za početak, uvest će se CSV datoteka koja prikazuje World Happiness Report podatke.

# %%
import pandas as pd

data1 = "World-happiness-report-updated_2024.csv"

hepi_podaci = pd.read_csv(data1, encoding='latin1')

print(hepi_podaci.head())
# Out:
#   Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0  Afghanistan  2008        3.724               7.350           0.451
# 1  Afghanistan  2009        4.402               7.509           0.552
# 2  Afghanistan  2010        4.758               7.614           0.539
# 3  Afghanistan  2011        3.832               7.581           0.521
# 4  Afghanistan  2012        3.783               7.661           0.521
#
#    Healthy life expectancy at birth  Freedom to make life choices  Generosity  \
# 0                              50.5                         0.718       0.164
# 1                              50.8                         0.679       0.187
# 2                              51.1                         0.600       0.118
# 3                              51.4                         0.496       0.160
# 4                              51.7                         0.531       0.234
#
#    Perceptions of corruption  Positive affect  Negative affect
# 0                      0.882            0.414            0.258
# 1                      0.850            0.481            0.237
# 2                      0.707            0.517            0.275
# 3                      0.731            0.480            0.267
# 4                      0.776            0.614            0.268

# %%
#print(hepi_podaci.info())
#print(hepi_podaci.describe())

# %% [markdown]
# Sveukupno je 10 stupaca, a ako se uključi i ime zemalja 11. Na temelju danih podataka moguće je vidjeti minimalne i maksimalne, odnosno srednje vrijednosti. Proći će se po svakom stupcu zasebno, odrediti ima li mogućih opažanja vrijedna spomena, i naznačiti ima li ikakvih potencijalnih zaključaka koji bi se u kasnijoj fazi mogli potvrditi detaljnijom analizom.
#
# 1. Distribucija sreće, tj. "Life Ladder"
#
# Proječna vrijednost iznosi 5.48 na ljestvici od 1 do 10, a dobiva se preko ispitanika kada ih se pita kako bi ocjenili zadovoljstvo u svom životu [3]. Vrijednost 5.48 sugerira umjerenu razinu sreće u svijetu, gdje je najniža vrijednost 1.28, a najveća 8.02, što ukazuje na velike razlike zemalja.
#
# 2. Ekonomski čimbenik
#
# Prosječan logaritmirani BDP po stanovniku iznosi 9.3, s minimalnom vrijednošću od 5.53, a najvišom od 11.68. Visoki BDP često pozitivno utjeće na razinu sreće, ali detaljnija analiza bila bi potrebna kako bi se ta pretpostavka potvrdila.
#
# 3. Socijalna podrška
#
# Prosječna vrijednost socijalne podrške iznosi 0.99, s minimalnom vrijednošću od 0.12. Ovo ukazuje na to da u nekim zemljama socijalna podrška može biti izrazito niska, što može utjecati na ukupnu razinu sreće.
#
# 4. Zdravstveni čimbenik
#
# Ovdje se radi o očekivanom trajanju života u zdravim uvjetima koje se utvrdi prilikom rođenja. Računa se na specifičan način gdje se za svaku zemlju pojedinačno gleda razlika između očekivanog trajanja života u odnosu na zemlju koja ima najniže očekivano trajanje života te se zatim množi s određenim koeficijentom, dok produkt ukazuje na razliku u razini sreće između zemlje za koju računamo i zemlje sa spomenutom najnižom vrijednošću [4]. Najmanja vrijednost je izrazito niska i iznosi 6.72, najviša 74.6, dok sama srednja vrijednost iznosi 63.4.
#
# 5. Sloboda donošenja odluka
#
# Prosječna percepcija slobode donošenja odluka iznosi 0.75, što ukazuje na relativno pozitivan osjećaj autonomije. Međutim, minimalna zabilježena vrijednost (0.23) sugerira da postoje regije gdje je sloboda značajno ograničena.
#
# 6. Čimbenik velikodušnosti
#
# Podaci o velikodušnosti se prikupljaju preko pitanja koliki udio populacije donira novac u dobrotvorne svrhe, u odnosu na BDP. S obzirom da je srednja vrijednost 0.000098, najviša 0.7, a najniža u negativi (kao i više od 50% vrijednosti), moguće je zaključiti da je dostignuta niža razina velikodušnosti od očekivane s obzirom na BDP.
#
# 8. Percepcija korupcije
#
# Percepcija korupcije predstavlja prosječnu ocjenu stanovništva o postojanju korupcije u vladi i poslovanju. Najniža vrijednost je 0.04, najviša 0.93, a srednja 0.74, što bi značilo da većina stanovništva ispitanih država smatra da u vladi ili poslovanju postoji primjetna razina korupcije.
#
# 9. i 10. Pozitivni i negativni utjecaj
#
# Pozitivni, odnosno negativni utjecaj označava odgovore na pitanje ispitanika jesu li prethodan dan doživjeli iskušenje pozitivnih ili negativnih emocija [4]. Kao što je vidljivo, pozitivni utjecaj (prosjek: 0.65) je znatno viši od negativnog utjecaja (prosjek: 0.27). Ovo ukazuje na to da ljudi globalno doživljavaju više pozitivnih nego negativnih emocija, iako varijacije među zemljama ostaju značajne.
#
# Za sve opise kao izvor koristila se službena stranica Happiness World Reporta [3][4], s kojih su i prikupljeni podaci.
#
# ________________________________________
#
# Nekoliko varijabli, poput očekivanog trajanja zdravog života i percepcije korupcije, ima manjak podataka za određene zemlje ili godine. Jedna od stavki projekta bit će dodatna obrada podataka koja bi ispravile takve greške.

# %%
print(hepi_podaci.isnull().sum())

nedostajuce = hepi_podaci[hepi_podaci.isna().any(axis=1)]
print("\nRedovi s nedostajućim vrijednostima:")
print(nedostajuce)
# Out:
# Country name                          0
# year                                  0
# Life Ladder                           0
# Log GDP per capita                   28
# Social support                       13
# Healthy life expectancy at birth     63
# Freedom to make life choices         36
# Generosity                           81
# Perceptions of corruption           125
# Positive affect                      24
# Negative affect                      16
# dtype: int64
#
# Redovi s nedostajućim vrijednostima:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 13    Afghanistan  2022        1.281                 NaN           0.228
# 14    Afghanistan  2023        1.446                 NaN           0.368
# 31        Algeria  2010        5.464               9.306             NaN
# 34        Algeria  2014        6.355               9.355           0.818
# 35        Algeria  2016        5.341               9.383           0.749
# ...           ...   ...          ...                 ...             ...
# 2314        Yemen  2007        4.477               8.212           0.825
# 2322        Yemen  2016        3.826               7.552           0.775
# 2323        Yemen  2017        3.254               7.243           0.790
# 2326        Yemen  2022        3.590                 NaN           0.872
# 2327        Yemen  2023        3.532                 NaN           0.825
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# 13                              54.875                         0.368
# 14                              55.200                         0.228
# 31                              65.500                         0.593
# 34                              65.900                           NaN
# 35                              66.100                           NaN
# ...                                ...                           ...
# 2314                            58.720                         0.673
# 2322                            58.175                         0.533
# 2323                            57.950                         0.595
# 2326                            56.825                         0.607
# 2327                            56.600                         0.583
#
#       Generosity  Perceptions of corruption  Positive affect  Negative affect
# 13           NaN                      0.733            0.206            0.576
# 14           NaN                      0.738            0.261            0.460
# 31        -0.212                      0.618              NaN              NaN
# 34           NaN                        NaN            0.558            0.177
# 35           NaN                        NaN            0.565            0.377
# ...          ...                        ...              ...              ...
# 2314       0.006                        NaN            0.524            0.379
# 2322      -0.144                        NaN            0.401            0.228
# 2323      -0.128                        NaN            0.368            0.295
# 2326         NaN                      0.788            0.460            0.255
# 2327         NaN                      0.771            0.447            0.341
#
# [266 rows x 11 columns]

# %%
print(hepi_podaci.duplicated().sum())
# Out:
# 0

# %% [markdown]
# Provjerom je ustanovljeno da nema dupliciranih vrijednosti.
#
# Sada će se pokušati popuniti nedostajuće vrijednosti korištenjem metode interpolacije, na način da će prvo retci biti kategorizirani, odnosno podijeljeni u grupe prema atributu "Country name", nakon čega bi se izračunala središnja vrijednost za danu zemlju. To će se koristiti kako bi se preciznije pogodila moguća nedostajuća vrijednost, s obzirom na odabranu državu.

# %%
hepi_podaci.reset_index(drop=True, inplace=True)

koristeci = hepi_podaci.select_dtypes(include=['float64']).columns
for column in koristeci:
 
    hepi_podaci[column] = (
    hepi_podaci.groupby('Country name')[column].apply(lambda group: group.interpolate(method='linear', limit_direction='both')).reset_index(drop=True)
        )

for column in koristeci:
    hepi_podaci[column] = hepi_podaci.groupby('Country name')[column].transform(
        lambda x: x.fillna(x.mean())
    )


print(hepi_podaci.info())
print(hepi_podaci.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2363 entries, 0 to 2362
# Data columns (total 11 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Country name                      2363 non-null   object
#  1   year                              2363 non-null   int64
#  2   Life Ladder                       2363 non-null   float64
#  3   Log GDP per capita                2354 non-null   float64
#  4   Social support                    2362 non-null   float64
#  5   Healthy life expectancy at birth  2313 non-null   float64
#  6   Freedom to make life choices      2363 non-null   float64
#  7   Generosity                        2354 non-null   float64
#  8   Perceptions of corruption         2333 non-null   float64
#  9   Positive affect                   2361 non-null   float64
#  10  Negative affect                   2362 non-null   float64
# dtypes: float64(9), int64(1), object(1)
# memory usage: 203.2+ KB
# None
#               year  Life Ladder  Log GDP per capita  Social support  \
# count  2363.000000  2363.000000         2354.000000     2362.000000
# mean   2014.763860     5.483566            9.393506        0.809620
# std       5.059436     1.125522            1.164645        0.121009
# min    2005.000000     1.281000            5.527000        0.228000
# 25%    2011.000000     4.647000            8.504000        0.744000
# 50%    2015.000000     5.449000            9.501500        0.835000
# 75%    2019.000000     6.323500           10.396000        0.904000
# max    2023.000000     8.019000           11.676000        0.987000
#
#        Healthy life expectancy at birth  Freedom to make life choices  \
# count                       2313.000000                   2363.000000
# mean                          63.436665                      0.750701
# std                            6.839102                      0.139598
# min                            6.720000                      0.228000
# 25%                           59.300000                      0.661000
# 50%                           65.140000                      0.772000
# 75%                           68.675000                      0.862000
# max                           74.600000                      0.985000
#
#         Generosity  Perceptions of corruption  Positive affect  \
# count  2354.000000                2333.000000      2361.000000
# mean      0.000605                   0.736391         0.651446
# std       0.160840                   0.188513         0.106111
# min      -0.340000                   0.035000         0.179000
# 25%      -0.111000                   0.675000         0.572000
# 50%      -0.021000                   0.793000         0.663000
# 75%       0.094750                   0.865000         0.737000
# max       0.700000                   0.983000         0.884000
#
#        Negative affect
# count      2362.000000
# mean          0.273374
# std           0.087109
# min           0.083000
# 25%           0.209000
# 50%           0.263000
# 75%           0.326000
# max           0.705000

# %% [markdown]
# U nekim slučajevima metoda interpolacije nije bila izvediva, s obzirom da za neke države nedostaju podaci u pojedinom atributu kroz svaku godinu. Te iznimke i nedostajeće vrijednosti popunit će se fillna metodom, koja će uzimati središnju vrijednost cijelog stupca za nadopunjavanje NaN vrijednosti.

# %%
hepi_podaci = hepi_podaci.apply(lambda col: col.fillna(col.mean()) if col.dtype in ['float64'] else col)

print(hepi_podaci.info())
hepi_podaci.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2363 entries, 0 to 2362
# Data columns (total 11 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Country name                      2363 non-null   object
#  1   year                              2363 non-null   int64
#  2   Life Ladder                       2363 non-null   float64
#  3   Log GDP per capita                2363 non-null   float64
#  4   Social support                    2363 non-null   float64
#  5   Healthy life expectancy at birth  2363 non-null   float64
#  6   Freedom to make life choices      2363 non-null   float64
#  7   Generosity                        2363 non-null   float64
#  8   Perceptions of corruption         2363 non-null   float64
#  9   Positive affect                   2363 non-null   float64
#  10  Negative affect                   2363 non-null   float64
# dtypes: float64(9), int64(1), object(1)
# memory usage: 203.2+ KB
# None
#               year  Life Ladder  Log GDP per capita  Social support  \
# count  2363.000000  2363.000000         2363.000000     2363.000000
# mean   2014.763860     5.483566            9.399671        0.809369
# std       5.059436     1.125522            1.145221        0.120878
# min    2005.000000     1.281000            5.527000        0.228000
# 25%    2011.000000     4.647000            8.520000        0.744000
# 50%    2015.000000     5.449000            9.492000        0.834000
# 75%    2019.000000     6.323500           10.382000        0.904000
# max    2023.000000     8.019000           11.676000        0.987000
#
#        Healthy life expectancy at birth  Freedom to make life choices  \
# count                       2363.000000                   2363.000000
# mean                          63.401828                      0.750282
# std                            6.750773                      0.138291
# min                            6.720000                      0.228000
# 25%                           59.545000                      0.662000
# 50%                           64.900000                      0.769000
# 75%                           68.400000                      0.861000
# max                           74.600000                      0.985000
#
#         Generosity  Perceptions of corruption  Positive affect  \
# count  2363.000000                2363.000000      2363.000000
# mean      0.000098                   0.743971         0.651882
# std       0.158596                   0.179907         0.105699
# min      -0.340000                   0.035000         0.179000
# 25%      -0.108000                   0.696000         0.573000
# 50%      -0.015000                   0.790000         0.662000
# 75%       0.088000                   0.864000         0.736500
# max       0.700000                   0.983000         0.884000
#
#        Negative affect
# count      2363.000000
# mean          0.273151
# std           0.086835
# min           0.083000
# 25%           0.209000
# 50%           0.263000
# 75%           0.326000
# max           0.705000

# %% [markdown]
# Tako su sve nedostajeće vrijednosti nadopunjene. Kao što je već spomenuto, za razliku od metode fillna, kod interpolacije su vrijednosti grupirane prema zemlji, a uzete isključivo središnje vrijednosti samo od odabrane zemlje (za razliku od metode fillna, koja koristi srednju vrijednost cijelog stupca), što je omogućilo realističnije rezultate. Ukoliko neka zemlja nije imala prikupljene podatke unutar određenog stupca, tamo su ostale NaN vrijednosti. Te su vrijednosti dodatno popunjene klasičnom fillna metodom, s obzirom da tamo nije bila primjenjiva metoda interpolacije.
#
# Interpolacijom nisu se mijenjale krajnje vrijednosti (vrijednosti minimalnog i maksimalnog kvartila), već samo središnje, a isto vrijedi i za fillna metodu. Za razumijevanje i pomoć kod korištenja metoda interpolacije i fillna, koristio se Llego.dev [10].

# %%
hp2 = hepi_podaci.drop(columns=['year'])
hp2.describe()
# Out:
#        Life Ladder  Log GDP per capita  Social support  \
# count  2363.000000         2363.000000     2363.000000
# mean      5.483566            9.393506        0.809620
# std       1.125522            1.162424        0.120983
# min       1.281000            5.527000        0.228000
# 25%       4.647000            8.505500        0.744000
# 50%       5.449000            9.497000        0.835000
# 75%       6.323500           10.392500        0.904000
# max       8.019000           11.676000        0.987000
#
#        Healthy life expectancy at birth  Freedom to make life choices  \
# count                       2363.000000                   2363.000000
# mean                          63.436665                      0.750701
# std                            6.766328                      0.139598
# min                            6.720000                      0.228000
# 25%                           59.545000                      0.661000
# 50%                           65.000000                      0.772000
# 75%                           68.525000                      0.862000
# max                           74.600000                      0.985000
#
#         Generosity  Perceptions of corruption  Positive affect  \
# count  2363.000000                2363.000000      2363.000000
# mean      0.000605                   0.736391         0.651446
# std       0.160534                   0.187312         0.106066
# min      -0.340000                   0.035000         0.179000
# 25%      -0.111000                   0.676000         0.572000
# 50%      -0.021000                   0.791000         0.663000
# 75%       0.094000                   0.864000         0.736500
# max       0.700000                   0.983000         0.884000
#
#        Negative affect
# count      2363.000000
# mean          0.273374
# std           0.087090
# min           0.083000
# 25%           0.209000
# 50%           0.263000
# 75%           0.326000
# max           0.705000

# %% [markdown]
# Sada će se uvesti i drugi set podataka.

# %%
data2 = "GPI-2022-overall-scores-and-domains-2008-2022.xlsx"

pis_full = pd.read_excel(data2, sheet_name="Overall Scores")

sheet_names = pd.ExcelFile(data2).sheet_names
print(sheet_names)
print(pis_full.head())
# Out:
# ['Overview', 'Overall Scores', 'Safety and Security', 'Militarisation', 'Ongoing Conflict']
#     Unnamed: 0 Unnamed: 1  Unnamed: 2 Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0          NaN        NaN         NaN        NaN         NaN         NaN
# 1          NaN        NaN         NaN                    NaN         NaN
# 2      Country      iso3c    2008.000       2009     2010.00    2011.000
# 3  Afghanistan        AFG       3.095      3.191        3.04       3.021
# 4      Albania        ALB       1.806      1.779        1.77       1.797
#
#    Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  Unnamed: 16  \
# 0         NaN         NaN         NaN         NaN  ...          NaN
# 1         NaN         NaN         NaN         NaN  ...          NaN
# 2    2012.000    2013.000    2014.000    2015.000  ...     2022.000
# 3       3.154       3.258       3.212       3.316  ...        3.554
# 4       1.799       1.816       1.810       1.806  ...        1.761
#
#    Unnamed: 17  Unnamed: 18  Unnamed: 19  Unnamed: 20  Unnamed: 21  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#    Unnamed: 22  Unnamed: 23  Unnamed: 24  Unnamed: 25
# 0          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN
#
# [5 rows x 26 columns]

# %% [markdown]
# S obzirom na to da u Excel datoteci koja je pronađena postoje retci i stupci koji su iskorišteni kao "ukras", odnosno ne služe srvsi prikazivanja podataka, već isključivo kozmetičkoj, potrebno je te retke i stupce maknuti kako bi se odstranile NaN vrijednosti.
#
# Prvi stupac označava zemlju za koju se prikupljaju podaci, drugi stupac označava kratice, tj. kôd svake države određene ISO standardom [8], dok treći stupac predstavlja godinu u kojoj se izvelo ispitivanje.
#
# Kao pomoć pri micanju redundantnih redaka i stupaca koristila se službena Pandas dokumentacija [6].

# %%
pis = pis_full

pis.columns = pis.iloc[2]
pis = pis[3:].reset_index(drop=True)


#pis = pis.drop(pis.columns[0:2], axis=1)
pis = pis.drop(pis.columns[15:26], axis=1)

pis.head()
# Out:
# 2      Country iso3c  2008.0   2009  2010.0  2011.0  2012.0  2013.0  2014.0  \
# 0  Afghanistan   AFG   3.095  3.191   3.040   3.021   3.154   3.258   3.212
# 1      Albania   ALB   1.806  1.779   1.770   1.797   1.799   1.816   1.810
# 2      Algeria   DZA   2.306  2.333   2.333   2.479   2.399   2.383   2.293
# 3       Angola   AGO   2.062  2.066   2.006   2.049   2.087   2.089   2.062
# 4    Argentina   ARG   1.818  1.946   1.947   1.909   1.872   2.001   1.905
#
# 2  2015.0  2016.0  2017.0  2018.0  2019.0  2020.0
# 0   3.316   3.362   3.412   3.513   3.520   3.592
# 1   1.806   1.761   1.774   1.714   1.712   1.771
# 2   2.263   2.238   2.206   2.212   2.235   2.234
# 3   1.957   1.974   1.938   1.972   1.955   1.989
# 4   1.984   1.981   1.936   1.914   1.978   1.948

# %% [markdown]
# U sljedećem dijelu će se uvesti baza podataka.

# %%
import os
import sqlite3

#from datetime import datetime

#os.getcwd()

# %%
con = sqlite3.connect('SQL1.db')
cursor = con.cursor()
cursor.execute("""
    CREATE TABLE IF NOT EXISTS file (
        id INTEGER PRIMARY KEY AUTOINCREMENT,
        country_name TEXT,
        year INT,
        life_ladder REAL,
        log_gdp_per_capita REAL,
        social_support REAL,
        healthy_life_expectancy REAL,
        freedom_to_make_choices REAL,
        generosity REAL,
        perceptions_of_corruption REAL,
        positive_affect REAL,
        negative_affect REAL
        )
    """)
con.commit()

# %% [markdown]
# Utvrđeno je da bi SQLite bila najbolja biblioteka za stvaranje baze podataka, s obzirom da za potrebe projekta nisu potrebne ogromne količine podataka ni rad s više korisnika. Za tablicu koja se kreira i kojoj će se pristupati za dohvat podataka, kreirani su istoimeni atributi o kojima je već bilo rečeno u prijašnjem dijelu.
#
# Kao pomoć pri stvaranju baze, koristio se forum za izmijenjivanje ideja i materijala preko stranice Stackoverflow [5].

# %%
for _, row in hepi_podaci.iterrows():
    cursor.execute("""
    INSERT OR REPLACE INTO file (country_name, year, life_ladder, log_gdp_per_capita, social_support, 
                                healthy_life_expectancy, freedom_to_make_choices, generosity, 
                                perceptions_of_corruption, positive_affect, negative_affect)
    VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
    """, tuple(row))
    
    con.commit()

# %% [markdown]
# Vrijednosti iz svakog retka dataframea "hepi_podaci" se redoslijedno unose u odgovarajuće stupce tablice, a petljom se iterira proces za svaki redak. Podaci se upisuju koristeći cursor, a metoda commit se poziva nakon svakog unosa kako bi se promjene pohranile u bazu.

# %%
cursor.execute("SELECT * FROM file")
rows = cursor.fetchall()

for row in rows:
    print(row)
#con.close()
# Out:
# (1, 'Afghanistan', 2008, 3.724, 7.35, 0.451, 50.5, 0.718, 0.164, 0.882, 0.414, 0.258)
# (2, 'Afghanistan', 2009, 4.402, 7.509, 0.552, 50.8, 0.679, 0.187, 0.85, 0.481, 0.237)
# (3, 'Afghanistan', 2010, 4.758, 7.614, 0.539, 51.1, 0.6, 0.118, 0.707, 0.517, 0.275)
# (4, 'Afghanistan', 2011, 3.832, 7.581, 0.521, 51.4, 0.496, 0.16, 0.731, 0.48, 0.267)
# (5, 'Afghanistan', 2012, 3.783, 7.661, 0.521, 51.7, 0.531, 0.234, 0.776, 0.614, 0.268)
# (6, 'Afghanistan', 2013, 3.572, 7.68, 0.484, 52.0, 0.578, 0.059, 0.823, 0.547, 0.273)
# (7, 'Afghanistan', 2014, 3.131, 7.671, 0.526, 52.3, 0.509, 0.102, 0.871, 0.492, 0.375)
# (8, 'Afghanistan', 2015, 3.983, 7.654, 0.529, 52.6, 0.389, 0.078, 0.881, 0.491, 0.339)
# (9, 'Afghanistan', 2016, 4.22, 7.65, 0.559, 52.925, 0.523, 0.04, 0.793, 0.501, 0.348)
# (10, 'Afghanistan', 2017, 2.662, 7.648, 0.491, 53.25, 0.427, -0.123, 0.954, 0.435, 0.371)
# (11, 'Afghanistan', 2018, 2.694, 7.631, 0.508, 53.575, 0.374, -0.095, 0.928, 0.385, 0.405)
# (12, 'Afghanistan', 2019, 2.375, 7.64, 0.42, 53.9, 0.394, -0.109, 0.924, 0.324, 0.502)
# (13, 'Afghanistan', 2021, 2.436, 7.325, 0.454, 54.55, 0.394, -0.085, 0.946, 0.179, 0.607)
# (14, 'Afghanistan', 2022, 1.281, 7.325, 0.228, 54.875, 0.368, -0.085, 0.733, 0.206, 0.576)
# (15, 'Afghanistan', 2023, 1.446, 7.325, 0.368, 55.2, 0.228, -0.085, 0.738, 0.261, 0.46)
# (16, 'Albania', 2007, 4.634, 9.122, 0.821, 66.76, 0.529, -0.013, 0.875, 0.489, 0.246)
# (17, 'Albania', 2009, 5.485, 9.241, 0.833, 67.32, 0.525, -0.162, 0.864, 0.564, 0.279)
# (18, 'Albania', 2010, 5.269, 9.283, 0.733, 67.6, 0.569, -0.176, 0.726, 0.576, 0.3)
# (19, 'Albania', 2011, 5.867, 9.31, 0.759, 67.88, 0.487, -0.209, 0.877, 0.566, 0.257)
# (20, 'Albania', 2012, 5.51, 9.326, 0.785, 68.16, 0.602, -0.173, 0.848, 0.553, 0.271)
# (21, 'Albania', 2013, 4.551, 9.338, 0.759, 68.44, 0.632, -0.131, 0.863, 0.541, 0.338)
# (22, 'Albania', 2014, 4.814, 9.358, 0.626, 68.72, 0.735, -0.029, 0.883, 0.573, 0.335)
# (23, 'Albania', 2015, 4.607, 9.382, 0.639, 69.0, 0.704, -0.085, 0.885, 0.579, 0.35)
# (24, 'Albania', 2016, 4.511, 9.417, 0.638, 69.025, 0.73, -0.021, 0.901, 0.567, 0.322)
# (25, 'Albania', 2017, 4.64, 9.455, 0.638, 69.05, 0.75, -0.033, 0.876, 0.547, 0.334)
# (26, 'Albania', 2018, 5.004, 9.497, 0.684, 69.075, 0.824, 0.005, 0.899, 0.592, 0.319)
# (27, 'Albania', 2019, 4.995, 9.522, 0.686, 69.1, 0.777, -0.103, 0.914, 0.548, 0.274)
# (28, 'Albania', 2020, 5.365, 9.494, 0.71, 69.125, 0.754, 0.002, 0.891, 0.563, 0.265)
# (29, 'Albania', 2021, 5.255, 9.588, 0.702, 69.15, 0.827, 0.039, 0.896, 0.554, 0.254)
# (30, 'Albania', 2022, 5.212, 9.649, 0.724, 69.175, 0.802, -0.07, 0.846, 0.547, 0.255)
# (31, 'Albania', 2023, 5.445, 9.689, 0.691, 69.2, 0.872, 0.068, 0.855, 0.597, 0.314)
# (32, 'Algeria', 2010, 5.464, 9.306, 0.81, 65.5, 0.593, -0.212, 0.618, 0.503, 0.255)
# (33, 'Algeria', 2011, 5.317, 9.316, 0.81, 65.6, 0.53, -0.188, 0.638, 0.503, 0.255)
# (34, 'Algeria', 2012, 5.605, 9.33, 0.839, 65.7, 0.587, -0.179, 0.69, 0.54, 0.23)
# (35, 'Algeria', 2014, 6.355, 9.355, 0.818, 65.9, 0.5369999999999999, -0.17733333333333332, 0.6933333333333332, 0.558, 0.177)
# (36, 'Algeria', 2016, 5.341, 9.383, 0.749, 66.1, 0.487, -0.17566666666666667, 0.6966666666666667, 0.565, 0.377)
# (37, 'Algeria', 2017, 5.249, 9.377, 0.807, 66.2, 0.437, -0.174, 0.7, 0.555, 0.289)
# (38, 'Algeria', 2018, 5.043, 9.37, 0.799, 66.3, 0.583, -0.153, 0.759, 0.534, 0.293)
# (39, 'Algeria', 2019, 4.745, 9.361, 0.803, 66.4, 0.385, -0.002, 0.741, 0.544, 0.215)
# (40, 'Algeria', 2020, 5.438, 9.291, 0.868, 66.5, 0.574, -0.124, 0.724, 0.524, 0.311)
# (41, 'Algeria', 2021, 5.217, 9.308, 0.841, 66.6, 0.558, -0.116, 0.712, 0.498, 0.258)
# (42, 'Algeria', 2022, 5.538, 9.323, 0.783, 66.7, 0.44, -0.045, 0.611, 0.583, 0.259)
# (43, 'Angola', 2011, 5.589, 8.944, 0.723, 51.22, 0.584, 0.05, 0.911, 0.667, 0.361)
# (44, 'Angola', 2012, 4.36, 8.989, 0.753, 51.84, 0.456, -0.141, 0.906, 0.591, 0.305)
# (45, 'Angola', 2013, 3.937, 9.0, 0.722, 52.46, 0.41, -0.109, 0.816, 0.65, 0.371)
# (46, 'Angola', 2014, 3.795, 9.01, 0.755, 53.08, 0.375, -0.173, 0.834, 0.595, 0.368)
# (47, 'Argentina', 2006, 6.313, 9.937, 0.938, 65.82, 0.733, -0.162, 0.852, 0.748, 0.328)
# (48, 'Argentina', 2007, 6.073, 10.013, 0.862, 65.94, 0.653, -0.146, 0.881, 0.75, 0.279)
# (49, 'Argentina', 2008, 5.961, 10.043, 0.892, 66.06, 0.678, -0.137, 0.865, 0.72, 0.318)
# (50, 'Argentina', 2009, 6.424, 9.972, 0.919, 66.18, 0.637, -0.135, 0.885, 0.762, 0.237)
# (51, 'Argentina', 2010, 6.441, 10.066, 0.927, 66.3, 0.73, -0.132, 0.855, 0.765, 0.211)
# (52, 'Argentina', 2011, 6.776, 10.112, 0.889, 66.42, 0.816, -0.18, 0.755, 0.769, 0.232)
# (53, 'Argentina', 2012, 6.468, 10.091, 0.902, 66.54, 0.747, -0.153, 0.817, 0.744, 0.272)
# (54, 'Argentina', 2013, 6.582, 10.103, 0.91, 66.66, 0.737, -0.136, 0.823, 0.766, 0.254)
# (55, 'Argentina', 2014, 6.671, 10.067, 0.918, 66.78, 0.745, -0.17, 0.854, 0.769, 0.238)
# (56, 'Argentina', 2015, 6.697, 10.083, 0.926, 66.9, 0.881, -0.18, 0.851, 0.768, 0.305)
# (57, 'Argentina', 2016, 6.427, 10.051, 0.883, 66.95, 0.848, -0.198, 0.851, 0.732, 0.312)
# (58, 'Argentina', 2017, 6.039, 10.069, 0.907, 67.0, 0.832, -0.192, 0.841, 0.715, 0.292)
# (59, 'Argentina', 2018, 5.793, 10.032, 0.9, 67.05, 0.846, -0.216, 0.855, 0.732, 0.321)
# (60, 'Argentina', 2019, 6.086, 10.002, 0.896, 67.1, 0.817, -0.217, 0.83, 0.735, 0.319)
# (61, 'Argentina', 2020, 5.901, 9.888, 0.897, 67.15, 0.823, -0.131, 0.816, 0.679, 0.342)
# (62, 'Argentina', 2021, 5.908, 9.977, 0.882, 67.2, 0.819, -0.014, 0.816, 0.685, 0.345)
# (63, 'Argentina', 2022, 6.261, 10.019, 0.893, 67.25, 0.825, -0.13, 0.81, 0.724, 0.284)
# (64, 'Argentina', 2023, 6.393, 9.994, 0.892, 67.3, 0.832, -0.129, 0.846, 0.72, 0.301)
# (65, 'Armenia', 2006, 4.289, 9.021, 0.682, 63.84, 0.52, -0.235, 0.85, 0.453, 0.469)
# (66, 'Armenia', 2007, 4.882, 9.157, 0.76, 64.08, 0.605, -0.255, 0.817, 0.454, 0.412)
# (67, 'Armenia', 2008, 4.652, 9.23, 0.709, 64.32, 0.462, -0.219, 0.876, 0.486, 0.385)
# (68, 'Armenia', 2009, 4.178, 9.085, 0.68, 64.56, 0.441, -0.218, 0.882, 0.479, 0.411)
# (69, 'Armenia', 2010, 4.368, 9.113, 0.66, 64.8, 0.459, -0.18, 0.891, 0.437, 0.426)
# (70, 'Armenia', 2011, 4.26, 9.164, 0.705, 65.04, 0.465, -0.23, 0.875, 0.411, 0.459)
# (71, 'Armenia', 2012, 4.32, 9.239, 0.676, 65.28, 0.502, -0.22, 0.893, 0.47, 0.464)
# (72, 'Armenia', 2013, 4.277, 9.276, 0.723, 65.52, 0.504, -0.201, 0.9, 0.503, 0.45)
# (73, 'Armenia', 2014, 4.453, 9.315, 0.739, 65.76, 0.506, -0.225, 0.92, 0.51, 0.404)
# (74, 'Armenia', 2015, 4.348, 9.351, 0.723, 66.0, 0.551, -0.209, 0.901, 0.527, 0.438)
# (75, 'Armenia', 2016, 4.325, 9.357, 0.709, 66.275, 0.611, -0.178, 0.921, 0.516, 0.437)
# (76, 'Armenia', 2017, 4.288, 9.434, 0.698, 66.55, 0.614, -0.155, 0.865, 0.552, 0.437)
# (77, 'Armenia', 2018, 5.062, 9.49, 0.814, 66.825, 0.808, -0.171, 0.677, 0.535, 0.455)
# (78, 'Armenia', 2019, 5.488, 9.569, 0.782, 67.1, 0.844, -0.181, 0.583, 0.537, 0.43)
# (79, 'Armenia', 2021, 5.301, 9.561, 0.762, 67.65, 0.795, -0.159, 0.705, 0.566, 0.478)
# (80, 'Armenia', 2022, 5.382, 9.683, 0.811, 67.925, 0.79, -0.158, 0.705, 0.531, 0.549)
# (81, 'Armenia', 2023, 5.679, 9.73, 0.819, 68.2, 0.819, -0.179, 0.681, 0.575, 0.423)
# (82, 'Australia', 2005, 7.341, 10.662, 0.968, 69.8, 0.935, 0.342, 0.39, 0.77, 0.238)
# (83, 'Australia', 2007, 7.285, 10.694, 0.965, 69.96, 0.891, 0.342, 0.513, 0.762, 0.215)
# (84, 'Australia', 2008, 7.254, 10.709, 0.947, 70.04, 0.916, 0.3, 0.431, 0.729, 0.218)
# (85, 'Australia', 2010, 7.45, 10.714, 0.955, 70.2, 0.932, 0.311, 0.366, 0.762, 0.22)
# (86, 'Australia', 2011, 7.406, 10.723, 0.967, 70.28, 0.945, 0.364, 0.382, 0.724, 0.195)
# (87, 'Australia', 2012, 7.196, 10.744, 0.945, 70.36, 0.935, 0.268, 0.368, 0.728, 0.214)
# (88, 'Australia', 2013, 7.364, 10.752, 0.928, 70.44, 0.933, 0.263, 0.432, 0.77, 0.177)
# (89, 'Australia', 2014, 7.289, 10.763, 0.924, 70.52, 0.923, 0.313, 0.442, 0.74, 0.245)
# (90, 'Australia', 2015, 7.309, 10.77, 0.952, 70.6, 0.922, 0.327, 0.357, 0.75, 0.21)
# (91, 'Australia', 2016, 7.25, 10.781, 0.942, 70.675, 0.922, 0.233, 0.399, 0.736, 0.236)
# (92, 'Australia', 2017, 7.257, 10.787, 0.95, 70.75, 0.911, 0.312, 0.411, 0.728, 0.225)
# (93, 'Australia', 2018, 7.177, 10.801, 0.94, 70.825, 0.916, 0.141, 0.405, 0.706, 0.187)
# (94, 'Australia', 2019, 7.234, 10.807, 0.943, 70.9, 0.918, 0.115, 0.43, 0.727, 0.202)
# (95, 'Australia', 2020, 7.137, 10.794, 0.937, 70.975, 0.905, 0.202, 0.491, 0.726, 0.205)
# (96, 'Australia', 2021, 7.112, 10.815, 0.92, 71.05, 0.912, 0.234, 0.454, 0.74, 0.235)
# (97, 'Australia', 2022, 7.035, 10.84, 0.942, 71.125, 0.854, 0.153, 0.545, 0.711, 0.244)
# (98, 'Australia', 2023, 7.025, 10.846, 0.896, 71.2, 0.876, 0.187, 0.482, 0.731, 0.248)
# (99, 'Austria', 2006, 7.122, 10.836, 0.936, 69.5, 0.941, 0.297, 0.49, 0.746, 0.174)
# (100, 'Austria', 2008, 7.181, 10.881, 0.935, 69.7, 0.879, 0.286, 0.614, 0.716, 0.173)
# (101, 'Austria', 2010, 7.303, 10.856, 0.914, 69.9, 0.896, 0.125, 0.546, 0.71, 0.156)
# (102, 'Austria', 2011, 7.471, 10.881, 0.944, 70.0, 0.939, 0.126, 0.703, 0.672, 0.145)
# (103, 'Austria', 2012, 7.401, 10.884, 0.945, 70.1, 0.92, 0.112, 0.771, 0.712, 0.157)
# (104, 'Austria', 2013, 7.499, 10.878, 0.95, 70.2, 0.922, 0.163, 0.679, 0.725, 0.163)
# (105, 'Austria', 2014, 6.95, 10.877, 0.899, 70.3, 0.885, 0.112, 0.567, 0.721, 0.17)
# (106, 'Austria', 2015, 7.076, 10.876, 0.928, 70.4, 0.9, 0.093, 0.557, 0.748, 0.164)
# (107, 'Austria', 2016, 7.048, 10.885, 0.926, 70.525, 0.889, 0.074, 0.524, 0.713, 0.197)
# (108, 'Austria', 2017, 7.294, 10.9, 0.906, 70.65, 0.89, 0.128, 0.518, 0.699, 0.18)
# (109, 'Austria', 2018, 7.396, 10.919, 0.912, 70.775, 0.904, 0.048, 0.523, 0.695, 0.226)
# (110, 'Austria', 2019, 7.195, 10.93, 0.964, 70.9, 0.903, 0.054, 0.457, 0.727, 0.205)
# (111, 'Austria', 2020, 7.213, 10.859, 0.925, 71.025, 0.912, 0.004, 0.464, 0.716, 0.206)
# (112, 'Austria', 2021, 7.08, 10.899, 0.863, 71.15, 0.795, 0.158, 0.501, 0.722, 0.259)
# (113, 'Austria', 2022, 6.999, 10.938, 0.876, 71.275, 0.856, 0.137, 0.524, 0.718, 0.226)
# (114, 'Austria', 2023, 6.636, 10.93, 0.874, 71.4, 0.874, 0.209, 0.529, 0.712, 0.24)
# (115, 'Azerbaijan', 2006, 4.728, 9.154, 0.854, 60.58, 0.772, -0.239, 0.774, 0.469, 0.276)
# (116, 'Azerbaijan', 2007, 4.568, 9.366, 0.753, 60.86, 0.522, -0.211, 0.871, 0.474, 0.284)
# (117, 'Azerbaijan', 2008, 4.817, 9.447, 0.684, 61.14, 0.601, -0.034, 0.715, 0.561, 0.227)
# (118, 'Azerbaijan', 2009, 4.574, 9.515, 0.736, 61.42, 0.498, -0.091, 0.754, 0.522, 0.234)
# (119, 'Azerbaijan', 2010, 4.219, 9.553, 0.687, 61.7, 0.501, -0.128, 0.858, 0.516, 0.272)
# (120, 'Azerbaijan', 2011, 4.68, 9.541, 0.725, 61.98, 0.537, -0.11, 0.795, 0.522, 0.258)
# (121, 'Azerbaijan', 2012, 4.911, 9.549, 0.762, 62.26, 0.599, -0.146, 0.763, 0.523, 0.266)
# (122, 'Azerbaijan', 2013, 5.481, 9.592, 0.77, 62.54, 0.672, -0.173, 0.699, 0.516, 0.242)
# (123, 'Azerbaijan', 2014, 5.252, 9.607, 0.799, 62.82, 0.733, -0.214, 0.654, 0.502, 0.22)
# (124, 'Azerbaijan', 2015, 5.147, 9.606, 0.786, 63.1, 0.764, -0.203, 0.616, 0.52, 0.206)
# (125, 'Azerbaijan', 2016, 5.304, 9.563, 0.777, 63.225, 0.713, -0.21, 0.607, 0.509, 0.191)
# (126, 'Azerbaijan', 2017, 5.152, 9.555, 0.787, 63.35, 0.731, -0.231, 0.653, 0.512, 0.198)
# (127, 'Azerbaijan', 2018, 5.168, 9.562, 0.781, 63.475, 0.772, -0.237, 0.561, 0.527, 0.191)
# (128, 'Azerbaijan', 2019, 5.173, 9.578, 0.887, 63.6, 0.854, -0.22, 0.457, 0.577, 0.164)
# (129, 'Azerbaijan', 2022, 4.576, 9.619, 0.665, 63.975, 0.8, 0.075, 0.696, 0.533, 0.401)
# (130, 'Azerbaijan', 2023, 5.214, 9.637, 0.713, 64.1, 0.829, -0.16, 0.627, 0.509, 0.221)
# (131, 'Bahrain', 2009, 5.701, 10.714, 0.904, 64.76, 0.896, 0.031, 0.506, 0.707, 0.422)
# (132, 'Bahrain', 2010, 5.937, 10.728, 0.877, 65.0, 0.862, -0.008, 0.715, 0.641, 0.423)
# (133, 'Bahrain', 2011, 4.824, 10.749, 0.908, 65.24, 0.87, -0.061, 0.583, 0.506, 0.514)
# (134, 'Bahrain', 2012, 5.027, 10.775, 0.911, 65.48, 0.682, -0.019250000000000003, 0.438, 0.559, 0.381)
# (135, 'Bahrain', 2013, 6.69, 10.798, 0.884, 65.72, 0.809, 0.022499999999999992, 0.525, 0.711, 0.306)
# (136, 'Bahrain', 2014, 6.165, 10.802, 0.8685, 65.96, 0.8295, 0.06424999999999997, 0.525, 0.6819999999999999, 0.3045)
# (137, 'Bahrain', 2015, 6.007, 10.788, 0.853, 66.2, 0.85, 0.106, 0.525, 0.653, 0.303)
# (138, 'Bahrain', 2016, 6.17, 10.789, 0.863, 66.125, 0.889, 0.082, 0.525, 0.736, 0.283)
# (139, 'Bahrain', 2017, 6.227, 10.798, 0.876, 66.05, 0.906, 0.128, 0.525, 0.754, 0.29)
# (140, 'Bahrain', 2019, 7.098, 10.815, 0.878, 65.9, 0.907, 0.035, 0.525, 0.711, 0.317)
# (141, 'Bahrain', 2020, 6.173, 10.779, 0.848, 65.825, 0.945, 0.115, 0.525, 0.73, 0.297)
# (142, 'Bahrain', 2023, 5.959, 10.877, 0.817, 65.6, 0.869, 0.155, 0.525, 0.671, 0.336)
# (143, 'Bangladesh', 2006, 4.319, 7.94, 0.672, 59.12, 0.612, 0.052, 0.786, 0.459, 0.321)
# (144, 'Bangladesh', 2007, 4.607, 7.997, 0.514, 59.64, 0.605, 0.024, 0.806, 0.484, 0.313)
# (145, 'Bangladesh', 2008, 5.052, 8.047, 0.467, 60.16, 0.606, -0.06, 0.802, 0.545, 0.232)
# (146, 'Bangladesh', 2009, 5.083, 8.087, 0.528, 60.68, 0.631, -0.091, 0.776, 0.506, 0.223)
# (147, 'Bangladesh', 2010, 4.858, 8.13, 0.549, 61.2, 0.659, -0.033, 0.774, 0.496, 0.292)
# (148, 'Bangladesh', 2011, 4.986, 8.181, 0.606, 61.72, 0.838, -0.086, 0.757, 0.501, 0.235)
# (149, 'Bangladesh', 2012, 4.724, 8.231, 0.582, 62.24, 0.668, -0.051, 0.765, 0.537, 0.183)
# (150, 'Bangladesh', 2013, 4.66, 8.277, 0.53, 62.76, 0.742, -0.032, 0.743, 0.492, 0.246)
# (151, 'Bangladesh', 2014, 4.636, 8.323, 0.577, 63.28, 0.736, -0.115, 0.789, 0.5175000000000001, 0.231)
# (152, 'Bangladesh', 2015, 4.633, 8.375, 0.601, 63.8, 0.815, -0.085, 0.721, 0.543, 0.226)
# (153, 'Bangladesh', 2016, 4.556, 8.431, 0.649, 63.925, 0.875, -0.105, 0.688, 0.437, 0.235)
# (154, 'Bangladesh', 2017, 4.31, 8.483, 0.713, 64.05, 0.896, -0.004, 0.635, 0.436, 0.214)
# (155, 'Bangladesh', 2018, 4.499, 8.542, 0.706, 64.175, 0.901, -0.059, 0.701, 0.433, 0.361)
# (156, 'Bangladesh', 2019, 5.114, 8.607, 0.673, 64.3, 0.902, -0.067, 0.656, 0.433, 0.369)
# (157, 'Bangladesh', 2020, 5.28, 8.629, 0.739, 64.425, 0.777, -0.025, 0.742, 0.485, 0.332)
# (158, 'Bangladesh', 2021, 4.123, 8.685, 0.485, 64.55, 0.893, 0.089, 0.746, 0.504, 0.448)
# (159, 'Bangladesh', 2022, 3.408, 8.742, 0.404, 64.675, 0.865, -0.058, 0.617, 0.394, 0.448)
# (160, 'Bangladesh', 2023, 4.114, 8.783, 0.45, 64.8, 0.919, 0.019, 0.756, 0.435, 0.435)
# (161, 'Belarus', 2006, 5.658, 9.489, 0.918, 60.06, 0.707, -0.252, 0.708, 0.535, 0.269)
# (162, 'Belarus', 2007, 5.617, 9.576, 0.858, 60.62, 0.667, -0.23, 0.695, 0.502, 0.235)
# (163, 'Belarus', 2008, 5.463, 9.677, 0.904, 61.18, 0.64, -0.226, 0.696, 0.523, 0.246)
# (164, 'Belarus', 2009, 5.564, 9.681, 0.908, 61.74, 0.679, -0.209, 0.676, 0.544, 0.223)
# (165, 'Belarus', 2010, 5.526, 9.759, 0.918, 62.3, 0.7, -0.168, 0.706, 0.532, 0.208)
# (166, 'Belarus', 2011, 5.225, 9.813, 0.91, 62.86, 0.656, -0.174, 0.672, 0.493, 0.249)
# (167, 'Belarus', 2012, 5.749, 9.832, 0.902, 63.42, 0.645, -0.223, 0.657, 0.515, 0.181)
# (168, 'Belarus', 2013, 5.876, 9.842, 0.923, 63.98, 0.723, -0.183, 0.653, 0.545, 0.206)
# (169, 'Belarus', 2014, 5.812, 9.858, 0.88, 64.54, 0.647, -0.054, 0.682, 0.575, 0.209)
# (170, 'Belarus', 2015, 5.719, 9.818, 0.924, 65.1, 0.623, -0.097, 0.669, 0.546, 0.184)
# (171, 'Belarus', 2016, 5.178, 9.792, 0.927, 65.325, 0.658, -0.131, 0.664, 0.503, 0.182)
# (172, 'Belarus', 2017, 5.553, 9.818, 0.9, 65.55, 0.621, -0.128, 0.654, 0.502, 0.233)
# (173, 'Belarus', 2018, 5.234, 9.851, 0.905, 65.775, 0.644, -0.181, 0.718, 0.409, 0.236)
# (174, 'Belarus', 2019, 5.821, 9.867, 0.917, 66.0, 0.657, -0.192, 0.546, 0.559, 0.19)
# (175, 'Belgium', 2005, 7.262, 10.744, 0.935, 68.4, 0.924, 0.064, 0.598, 0.677, 0.26)
# (176, 'Belgium', 2007, 7.219, 10.791, 0.922, 68.72, 0.901, 0.064, 0.721, 0.744, 0.218)
# (177, 'Belgium', 2008, 7.117, 10.788, 0.923, 68.88, 0.887, 0.001, 0.652, 0.709, 0.242)
# (178, 'Belgium', 2010, 6.854, 10.778, 0.931, 69.2, 0.807, 0.016, 0.697, 0.793, 0.24)
# (179, 'Belgium', 2011, 7.111, 10.782, 0.937, 69.36, 0.88, -0.02, 0.711, 0.752, 0.225)
# (180, 'Belgium', 2012, 6.935, 10.783, 0.927, 69.52, 0.855, -0.056, 0.758, 0.718, 0.238)
# (181, 'Belgium', 2013, 7.104, 10.783, 0.909, 69.68, 0.891, 0.011, 0.574, 0.738, 0.217)
# (182, 'Belgium', 2014, 6.855, 10.794, 0.944, 69.84, 0.861, -0.005, 0.512, 0.744, 0.252)
# (183, 'Belgium', 2015, 6.904, 10.809, 0.885, 70.0, 0.869, 0.056, 0.469, 0.747, 0.24)
# (184, 'Belgium', 2016, 6.949, 10.816, 0.929, 70.15, 0.866, -0.062, 0.497, 0.701, 0.26)
# (185, 'Belgium', 2017, 6.928, 10.829, 0.922, 70.3, 0.857, 0.049, 0.543, 0.713, 0.234)
# (186, 'Belgium', 2018, 6.892, 10.842, 0.93, 70.45, 0.808, -0.13, 0.63, 0.682, 0.25)
# (187, 'Belgium', 2019, 6.772, 10.859, 0.884, 70.6, 0.776, -0.178, 0.672, 0.699, 0.244)
# (188, 'Belgium', 2020, 6.839, 10.799, 0.904, 70.75, 0.767, -0.172, 0.634, 0.619, 0.26)
# (189, 'Belgium', 2021, 6.882, 10.856, 0.915, 70.9, 0.823, 0.077, 0.523, 0.687, 0.26)
# (190, 'Belgium', 2022, 6.857, 10.881, 0.923, 71.05, 0.89, 0.095, 0.483, 0.718, 0.235)
# (191, 'Belgium', 2023, 6.944, 10.883, 0.896, 71.2, 0.87, 0.065, 0.522, 0.725, 0.245)
# (192, 'Belize', 2007, 6.451, 9.192, 0.872, 64.3, 0.705, 0.006, 0.769, 0.732, 0.251)
# (193, 'Belize', 2014, 5.956, 9.135, 0.757, 65.0, 0.874, -0.002, 0.782, 0.735, 0.282)
# (194, 'Benin', 2006, 3.33, 7.844, 0.445, 51.96, 0.58, -0.015, 0.79, 0.521, 0.309)
# (195, 'Benin', 2008, 3.667, 7.891, 0.382, 52.48, 0.709, -0.008, 0.825, 0.574, 0.303)
# (196, 'Benin', 2011, 3.87, 7.876, 0.477, 53.26, 0.773, -0.145, 0.849, 0.574, 0.219)
# (197, 'Benin', 2012, 3.193, 7.894, 0.523, 53.52, 0.769, -0.114, 0.806, 0.563, 0.231)
# (198, 'Benin', 2013, 3.479, 7.935, 0.577, 53.78, 0.783, -0.088, 0.856, 0.646, 0.216)
# (199, 'Benin', 2014, 3.347, 7.967, 0.506, 54.04, 0.776, -0.099, 0.855, 0.558, 0.273)
# (200, 'Benin', 2015, 3.625, 7.955, 0.434, 54.3, 0.733, -0.029, 0.85, 0.555, 0.373)
# (201, 'Benin', 2016, 4.007, 7.958, 0.493, 54.6, 0.78, -0.068, 0.838, 0.578, 0.456)
# (202, 'Benin', 2017, 4.853, 7.984, 0.436, 54.9, 0.727, -0.068, 0.767, 0.598, 0.458)
# (203, 'Benin', 2018, 5.82, 8.02, 0.504, 55.2, 0.713, 0.0, 0.747, 0.625, 0.468)
# (204, 'Benin', 2019, 4.976, 8.057, 0.442, 55.5, 0.77, -0.018, 0.698, 0.638, 0.441)
# (205, 'Benin', 2020, 4.408, 8.067, 0.507, 55.8, 0.783, -0.086, 0.532, 0.557, 0.305)
# (206, 'Benin', 2021, 4.493, 8.108, 0.436, 56.1, 0.724, -0.016, 0.613, 0.597, 0.435)
# (207, 'Benin', 2022, 4.217, 8.142, 0.366, 56.4, 0.714, -0.033, 0.58, 0.571, 0.444)
# (208, 'Benin', 2023, 4.42, 8.174, 0.398, 56.7, 0.786, -0.073, 0.575, 0.573, 0.428)
# (209, 'Bhutan', 2013, 5.569, 9.097, 0.819, 62.24, 0.81, 0.349, 0.802, 0.664, 0.217)
# (210, 'Bhutan', 2014, 4.939, 9.143, 0.88, 62.42, 0.834, 0.264, 0.65, 0.775, 0.324)
# (211, 'Bhutan', 2015, 5.082, 9.198, 0.848, 62.6, 0.83, 0.273, 0.634, 0.723, 0.312)
# (212, 'Bolivia', 2006, 5.374, 8.671, 0.834, 60.9, 0.77, -0.048, 0.794, 0.708, 0.432)
# (213, 'Bolivia', 2007, 5.628, 8.698, 0.796, 61.1, 0.78, -0.004, 0.817, 0.746, 0.388)
# (214, 'Bolivia', 2008, 5.298, 8.74, 0.785, 61.3, 0.726, -0.096, 0.801, 0.723, 0.392)
# (215, 'Bolivia', 2009, 6.086, 8.756, 0.831, 61.5, 0.779, -0.04, 0.763, 0.742, 0.372)
# (216, 'Bolivia', 2010, 5.781, 8.78, 0.807, 61.7, 0.703, -0.073, 0.781, 0.72, 0.35)
# (217, 'Bolivia', 2011, 5.779, 8.813, 0.817, 61.9, 0.782, -0.043, 0.825, 0.689, 0.361)
# (218, 'Bolivia', 2012, 6.019, 8.847, 0.781, 62.1, 0.862, -0.019, 0.84, 0.699, 0.409)
# (219, 'Bolivia', 2013, 5.767, 8.896, 0.803, 62.3, 0.846, -0.071, 0.812, 0.721, 0.41)
# (220, 'Bolivia', 2014, 5.865, 8.933, 0.821, 62.5, 0.881, 0.014, 0.832, 0.769, 0.398)
# (221, 'Bolivia', 2015, 5.834, 8.965, 0.829, 62.7, 0.884, -0.034, 0.862, 0.749, 0.393)
# (222, 'Bolivia', 2016, 5.77, 8.991, 0.796, 62.85, 0.882, -0.051, 0.853, 0.736, 0.376)
# (223, 'Bolivia', 2017, 5.651, 9.017, 0.779, 63.0, 0.884, -0.124, 0.819, 0.655, 0.434)
# (224, 'Bolivia', 2018, 5.916, 9.044, 0.827, 63.15, 0.863, -0.097, 0.786, 0.705, 0.387)
# (225, 'Bolivia', 2019, 5.674, 9.051, 0.784, 63.3, 0.881, -0.09, 0.857, 0.701, 0.419)
# (226, 'Bolivia', 2020, 5.559, 8.946, 0.805, 63.45, 0.877, -0.056, 0.868, 0.729, 0.382)
# (227, 'Bolivia', 2021, 5.569, 8.994, 0.798, 63.6, 0.862, -0.058, 0.812, 0.721, 0.403)
# (228, 'Bolivia', 2022, 5.929, 9.012, 0.824, 63.75, 0.865, -0.083, 0.84, 0.738, 0.426)
# (229, 'Bolivia', 2023, 5.86, 9.025, 0.786, 63.9, 0.832, -0.059, 0.877, 0.753, 0.401)
# (230, 'Bosnia and Herzegovina', 2007, 4.9, 9.191, 0.766, 67.0, 0.342, 0.006, 0.926, 0.57, 0.296)
# (231, 'Bosnia and Herzegovina', 2009, 4.963, 9.246, 0.735, 67.0, 0.258, -0.027, 0.959, 0.507, 0.39)
# (232, 'Bosnia and Herzegovina', 2010, 4.669, 9.272, 0.773, 67.0, 0.365, -0.131, 0.933, 0.465, 0.409)
# (233, 'Bosnia and Herzegovina', 2011, 4.995, 9.3, 0.725, 67.0, 0.333, -0.038, 0.925, 0.551, 0.326)
# (234, 'Bosnia and Herzegovina', 2012, 4.773, 9.31, 0.779, 67.0, 0.42, -0.016, 0.953, 0.469, 0.338)
# (235, 'Bosnia and Herzegovina', 2013, 5.124, 9.349, 0.767, 67.0, 0.39, 0.039, 0.97, 0.489, 0.315)
# (236, 'Bosnia and Herzegovina', 2014, 5.249, 9.373, 0.788, 67.0, 0.412, 0.229, 0.976, 0.491, 0.262)
# (237, 'Bosnia and Herzegovina', 2015, 5.117, 9.428, 0.656, 67.0, 0.631, -0.058, 0.96, 0.486, 0.286)
# (238, 'Bosnia and Herzegovina', 2016, 5.181, 9.473, 0.808, 67.05, 0.633, 0.13, 0.957, 0.566, 0.304)
# (239, 'Bosnia and Herzegovina', 2017, 5.09, 9.517, 0.775, 67.1, 0.564, 0.087, 0.923, 0.527, 0.271)
# (240, 'Bosnia and Herzegovina', 2018, 5.887, 9.566, 0.836, 67.15, 0.659, 0.118, 0.913, 0.568, 0.277)
# (241, 'Bosnia and Herzegovina', 2019, 6.016, 9.606, 0.873, 67.2, 0.722, 0.074, 0.963, 0.545, 0.238)
# (242, 'Bosnia and Herzegovina', 2020, 5.516, 9.588, 0.899, 67.25, 0.74, 0.132, 0.916, 0.602, 0.325)
# (243, 'Bosnia and Herzegovina', 2021, 5.749, 9.674, 0.86, 67.3, 0.759, 0.274, 0.921, 0.604, 0.305)
# (244, 'Bosnia and Herzegovina', 2022, 5.872, 9.723, 0.856, 67.35, 0.743, 0.191, 0.933, 0.543, 0.285)
# (245, 'Bosnia and Herzegovina', 2023, 6.009, 9.759, 0.879, 67.4, 0.847, 0.241, 0.948, 0.579, 0.249)
# (246, 'Botswana', 2006, 4.739, 9.495, 0.883, 48.84, 0.824, -0.201, 0.723, 0.643, 0.226)
# (247, 'Botswana', 2008, 5.451, 9.543, 0.832, 49.72, 0.858, -0.167, 0.806, 0.677, 0.218)
# (248, 'Botswana', 2010, 3.553, 9.446, 0.866, 50.6, 0.826, -0.141, 0.814, 0.617, 0.172)
# (249, 'Botswana', 2011, 3.52, 9.492, 0.86, 51.04, 0.813, -0.248, 0.816, 0.647, 0.16)
# (250, 'Botswana', 2012, 4.836, 9.471, 0.837, 51.48, 0.799, -0.197, 0.814, 0.695, 0.171)
# (251, 'Botswana', 2013, 4.128, 9.557, 0.856, 51.92, 0.767, -0.148, 0.749, 0.671, 0.244)
# (252, 'Botswana', 2014, 4.031, 9.593, 0.859, 52.36, 0.791, -0.099, 0.743, 0.626, 0.245)
# (253, 'Botswana', 2015, 3.762, 9.524, 0.816, 52.8, 0.857, -0.108, 0.86, 0.676, 0.261)
# (254, 'Botswana', 2016, 3.499, 9.573, 0.768, 53.075, 0.852, -0.246, 0.729, 0.657, 0.252)
# (255, 'Botswana', 2017, 3.505, 9.593, 0.768, 53.35, 0.817, -0.242, 0.731, 0.612, 0.276)
# (256, 'Botswana', 2018, 3.461, 9.613, 0.795, 53.625, 0.818, -0.248, 0.807, 0.688, 0.267)
# (257, 'Botswana', 2019, 3.471, 9.624, 0.774, 53.9, 0.833, -0.233, 0.792, 0.665, 0.273)
# (258, 'Botswana', 2022, 3.435, 9.65, 0.75, 54.725, 0.739, -0.218, 0.831, 0.623, 0.287)
# (259, 'Botswana', 2023, 3.332, 9.673, 0.701, 55.0, 0.741, -0.264, 0.814, 0.657, 0.247)
# (260, 'Brazil', 2005, 6.637, 9.435, 0.883, 63.1, 0.882, -0.022, 0.745, 0.77, 0.302)
# (261, 'Brazil', 2007, 6.321, 9.512, 0.886, 63.42, 0.777, -0.022, 0.728, 0.775, 0.299)
# (262, 'Brazil', 2008, 6.691, 9.552, 0.878, 63.58, 0.782, -0.083, 0.688, 0.718, 0.265)
# (263, 'Brazil', 2009, 7.001, 9.541, 0.913, 63.74, 0.767, -0.061, 0.723, 0.744, 0.274)
# (264, 'Brazil', 2010, 6.837, 9.604, 0.906, 63.9, 0.806, -0.059, 0.656, 0.726, 0.25)
# (265, 'Brazil', 2011, 7.038, 9.634, 0.916, 64.06, 0.834, -0.078, 0.662, 0.698, 0.268)
# (266, 'Brazil', 2012, 6.66, 9.644, 0.89, 64.22, 0.849, -0.089, 0.623, 0.685, 0.35)
# (267, 'Brazil', 2013, 7.14, 9.665, 0.91, 64.38, 0.785, -0.1, 0.707, 0.725, 0.276)
# (268, 'Brazil', 2014, 6.981, 9.661, 0.898, 64.54, 0.714, -0.121, 0.71, 0.718, 0.274)
# (269, 'Brazil', 2015, 6.547, 9.617, 0.907, 64.7, 0.799, -0.021, 0.771, 0.687, 0.325)
# (270, 'Brazil', 2016, 6.375, 9.575, 0.912, 64.875, 0.807, -0.106, 0.781, 0.711, 0.302)
# (271, 'Brazil', 2017, 6.333, 9.58, 0.905, 65.05, 0.765, -0.181, 0.794, 0.669, 0.308)
# (272, 'Brazil', 2018, 6.191, 9.59, 0.882, 65.225, 0.751, -0.123, 0.763, 0.677, 0.35)
# (273, 'Brazil', 2019, 6.451, 9.595, 0.899, 65.4, 0.83, -0.068, 0.762, 0.701, 0.337)
# (274, 'Brazil', 2020, 6.11, 9.555, 0.831, 65.575, 0.786, -0.061, 0.729, 0.653, 0.389)
# (275, 'Brazil', 2021, 6.01, 9.598, 0.814, 65.75, 0.792, 0.086, 0.739, 0.662, 0.407)
# (276, 'Brazil', 2022, 6.257, 9.622, 0.866, 65.925, 0.83, -0.064, 0.742, 0.681, 0.341)
# (277, 'Brazil', 2023, 6.553, 9.635, 0.856, 66.1, 0.87, -0.036, 0.733, 0.694, 0.313)
# (278, 'Bulgaria', 2007, 3.844, 9.746, 0.832, 64.78, 0.566, -0.146, 0.976, 0.5, 0.226)
# (279, 'Bulgaria', 2010, 3.912, 9.807, 0.843, 65.2, 0.545, -0.153, 0.941, 0.513, 0.238)
# (280, 'Bulgaria', 2011, 3.875, 9.834, 0.86, 65.34, 0.664, -0.236, 0.948, 0.49, 0.271)
# (281, 'Bulgaria', 2012, 4.222, 9.848, 0.838, 65.48, 0.641, -0.181, 0.938, 0.51, 0.237)
# (282, 'Bulgaria', 2013, 3.993, 9.848, 0.829, 65.62, 0.603, -0.199, 0.962, 0.537, 0.278)
# (283, 'Bulgaria', 2014, 4.438, 9.863, 0.886, 65.76, 0.576, -0.062, 0.955, 0.542, 0.236)
# (284, 'Bulgaria', 2015, 4.865, 9.903, 0.908, 65.9, 0.637, -0.207, 0.941, 0.556, 0.214)
# (285, 'Bulgaria', 2016, 4.838, 9.94, 0.926, 66.0, 0.7, -0.177, 0.936, 0.545, 0.172)
# (286, 'Bulgaria', 2017, 5.097, 9.974, 0.942, 66.1, 0.689, -0.16, 0.911, 0.542, 0.189)
# (287, 'Bulgaria', 2018, 5.099, 10.008, 0.924, 66.2, 0.724, -0.182, 0.952, 0.554, 0.189)
# (288, 'Bulgaria', 2019, 5.108, 10.055, 0.948, 66.3, 0.822, -0.115, 0.943, 0.577, 0.2)
# (289, 'Bulgaria', 2020, 5.598, 10.02, 0.916, 66.4, 0.818, -0.012, 0.901, 0.642, 0.221)
# (290, 'Bulgaria', 2021, 5.422, 10.102, 0.884, 66.5, 0.841, -0.018, 0.891, 0.647, 0.253)
# (291, 'Bulgaria', 2022, 5.378, 10.197, 0.953, 66.6, 0.741, -0.152, 0.942, 0.582, 0.165)
# (292, 'Bulgaria', 2023, 5.59, 10.273, 0.935, 66.7, 0.754, -0.131, 0.948, 0.539, 0.192)
# (293, 'Burkina Faso', 2006, 3.801, 7.327, 0.796, 49.44, 0.588, 0.026, 0.798, 0.678, 0.266)
# (294, 'Burkina Faso', 2007, 4.017, 7.337, 0.771, 49.88, 0.582, -0.062, 0.833, 0.609, 0.281)
# (295, 'Burkina Faso', 2008, 3.846, 7.364, 0.727, 50.32, 0.612, -0.103, 0.887, 0.538, 0.304)
# (296, 'Burkina Faso', 2010, 4.036, 7.416, 0.773, 51.2, 0.587, -0.038, 0.767, 0.565, 0.217)
# (297, 'Burkina Faso', 2011, 4.785, 7.45, 0.71, 51.64, 0.725, -0.107, 0.707, 0.578, 0.205)
# (298, 'Burkina Faso', 2012, 3.955, 7.482, 0.744, 52.08, 0.622, -0.072, 0.726, 0.487, 0.3)
# (299, 'Burkina Faso', 2013, 3.326, 7.509, 0.745, 52.52, 0.741, -0.018, 0.765, 0.592, 0.287)
# (300, 'Burkina Faso', 2014, 3.481, 7.521, 0.742, 52.96, 0.71, -0.006, 0.801, 0.604, 0.256)
# (301, 'Burkina Faso', 2015, 4.419, 7.53, 0.705, 53.4, 0.659, 0.001, 0.693, 0.555, 0.359)
# (302, 'Burkina Faso', 2016, 4.206, 7.558, 0.764, 53.775, 0.645, -0.003, 0.721, 0.59, 0.337)
# (303, 'Burkina Faso', 2017, 4.647, 7.59, 0.785, 54.15, 0.614, -0.066, 0.727, 0.58, 0.354)
# (304, 'Burkina Faso', 2018, 4.927, 7.626, 0.665, 54.525, 0.721, -0.016, 0.757, 0.656, 0.343)
# (305, 'Burkina Faso', 2019, 4.741, 7.654, 0.683, 54.9, 0.678, -0.007, 0.729, 0.656, 0.365)
# (306, 'Burkina Faso', 2020, 4.64, 7.647, 0.668, 55.275, 0.75, 0.12, 0.809, 0.605, 0.388)
# (307, 'Burkina Faso', 2021, 4.636, 7.687, 0.658, 55.65, 0.644, 0.064, 0.736, 0.62, 0.363)
# (308, 'Burkina Faso', 2023, 4.462, 7.693, 0.58, 56.4, 0.715, 0.105, 0.65, 0.639, 0.346)
# (309, 'Burundi', 2008, 3.563, 6.7, 0.291, 49.66, 0.26, -0.022, 0.86, 0.415, 0.253)
# (310, 'Burundi', 2009, 3.792, 6.687, 0.326, 50.28, 0.427, -0.021, 0.718, 0.607, 0.164)
# (311, 'Burundi', 2011, 3.706, 6.694, 0.422, 51.52, 0.49, -0.063, 0.677, 0.572, 0.19)
# (312, 'Burundi', 2014, 2.905, 6.723, 0.565, 53.38, 0.431, -0.059, 0.808, 0.622, 0.251)
# (313, 'Burundi', 2018, 3.775, 6.607, 0.485, 55.2, 0.646, -0.027, 0.599, 0.636, 0.363)
# (314, 'Cambodia', 2006, 3.569, 7.746, 0.793, 57.64, 0.819, 0.25, 0.829, 0.6, 0.341)
# (315, 'Cambodia', 2007, 4.156, 7.826, 0.675, 57.98, 0.819, 0.111, 0.879, 0.6, 0.32)
# (316, 'Cambodia', 2008, 4.462, 7.874, 0.619, 58.32, 0.914, 0.041, 0.888, 0.6, 0.335)
# (317, 'Cambodia', 2009, 4.111, 7.86, 0.818, 58.66, 0.937, 0.148, 0.965, 0.691, 0.188)
# (318, 'Cambodia', 2010, 4.141, 7.904, 0.697, 59.0, 0.94, 0.345, 0.896, 0.662, 0.422)
# (319, 'Cambodia', 2011, 4.161, 7.957, 0.716, 59.34, 0.927, 0.413, 0.775, 0.637, 0.308)
# (320, 'Cambodia', 2012, 3.899, 8.013, 0.606, 59.68, 0.956, 0.242, 0.89, 0.713, 0.352)
# (321, 'Cambodia', 2013, 3.674, 8.07, 0.651, 60.02, 0.941, 0.159, 0.812, 0.67, 0.44)
# (322, 'Cambodia', 2014, 3.883, 8.125, 0.693, 60.36, 0.938, 0.234, 0.843, 0.682, 0.482)
# (323, 'Cambodia', 2015, 4.162, 8.179, 0.729, 60.7, 0.956, 0.204, 0.825, 0.731, 0.399)
# (324, 'Cambodia', 2016, 4.461, 8.233, 0.746, 60.9, 0.958, 0.07, 0.84, 0.713, 0.398)
# (325, 'Cambodia', 2017, 4.586, 8.287, 0.765, 61.1, 0.964, 0.082, 0.821, 0.669, 0.408)
# (326, 'Cambodia', 2018, 5.122, 8.347, 0.795, 61.3, 0.958, 0.029, 0.8245, 0.723, 0.414)
# (327, 'Cambodia', 2019, 4.998, 8.404, 0.759, 61.5, 0.957, 0.007, 0.828, 0.704, 0.39)
# (328, 'Cambodia', 2020, 4.377, 8.361, 0.724, 61.7, 0.963, 0.047, 0.863, 0.771, 0.39)
# (329, 'Cambodia', 2021, 4.555, 8.379, 0.713, 61.9, 0.965, 0.012, 0.844, 0.759, 0.391)
# (330, 'Cambodia', 2022, 4.25, 8.419, 0.784, 62.1, 0.946, 0.151, 0.86, 0.756, 0.388)
# (331, 'Cambodia', 2023, 4.221, 8.462, 0.738, 62.3, 0.961, 0.07, 0.799, 0.683, 0.394)
# (332, 'Cameroon', 2006, 3.851, 8.09, 0.69, 47.84, 0.653, -0.02, 0.907, 0.588, 0.271)
# (333, 'Cameroon', 2007, 4.35, 8.104, 0.717, 48.28, 0.644, -0.042, 0.91, 0.63, 0.249)
# (334, 'Cameroon', 2008, 4.292, 8.104, 0.697, 48.72, 0.58, -0.079, 0.945, 0.613, 0.312)
# (335, 'Cameroon', 2009, 4.741, 8.101, 0.729, 49.16, 0.698, -0.027, 0.925, 0.592, 0.25)
# (336, 'Cameroon', 2010, 4.554, 8.101, 0.759, 49.6, 0.792, -0.008, 0.875, 0.594, 0.274)
# (337, 'Cameroon', 2011, 4.434, 8.106, 0.738, 50.04, 0.817, -0.038, 0.87, 0.608, 0.272)
# (338, 'Cameroon', 2012, 4.245, 8.123, 0.743, 50.48, 0.766, -0.041, 0.898, 0.617, 0.284)
# (339, 'Cameroon', 2013, 4.271, 8.144, 0.76, 50.92, 0.794, -0.039, 0.867, 0.64, 0.268)
# (340, 'Cameroon', 2014, 4.24, 8.169, 0.778, 51.36, 0.795, -0.08, 0.856, 0.604, 0.216)
# (341, 'Cameroon', 2015, 5.038, 8.193, 0.646, 51.8, 0.791, 0.041, 0.868, 0.624, 0.346)
# (342, 'Cameroon', 2016, 4.816, 8.207, 0.659, 52.475, 0.713, -0.012, 0.879, 0.635, 0.367)
# (343, 'Cameroon', 2017, 5.074, 8.214, 0.695, 53.15, 0.767, -0.036, 0.844, 0.632, 0.377)
# (344, 'Cameroon', 2018, 5.251, 8.225, 0.677, 53.825, 0.816, 0.028, 0.884, 0.63, 0.356)
# (345, 'Cameroon', 2019, 4.937, 8.231, 0.711, 54.5, 0.712, -0.015, 0.817, 0.606, 0.326)
# (346, 'Cameroon', 2020, 5.241, 8.207, 0.72, 55.175, 0.675, 0.042, 0.837, 0.626, 0.386)
# (347, 'Cameroon', 2021, 4.963, 8.216, 0.695, 55.85, 0.715, -0.029, 0.849, 0.612, 0.347)
# (348, 'Cameroon', 2022, 4.712, 8.225, 0.629, 56.525, 0.675, 0.022, 0.849, 0.586, 0.362)
# (349, 'Cameroon', 2023, 4.946, 8.238, 0.716, 57.2, 0.739, -0.028, 0.855, 0.588, 0.356)
# (350, 'Canada', 2005, 7.418, 10.707, 0.962, 70.5, 0.957, 0.246, 0.503, 0.783, 0.233)
# (351, 'Canada', 2007, 7.482, 10.734, 0.9504999999999999, 70.62, 0.93, 0.244, 0.406, 0.812, 0.257)
# (352, 'Canada', 2008, 7.486, 10.733, 0.939, 70.68, 0.926, 0.256, 0.37, 0.802, 0.202)
# (353, 'Canada', 2009, 7.488, 10.692, 0.943, 70.74, 0.915, 0.241, 0.413, 0.793, 0.248)
# (354, 'Canada', 2010, 7.65, 10.711, 0.954, 70.8, 0.934, 0.225, 0.413, 0.791, 0.233)
# (355, 'Canada', 2011, 7.426, 10.733, 0.922, 70.86, 0.951, 0.247, 0.433, 0.803, 0.248)
# (356, 'Canada', 2012, 7.415, 10.739, 0.948, 70.92, 0.918, 0.284, 0.466, 0.776, 0.229)
# (357, 'Canada', 2013, 7.594, 10.752, 0.936, 70.98, 0.916, 0.31, 0.406, 0.801, 0.263)
# (358, 'Canada', 2014, 7.304, 10.77, 0.918, 71.04, 0.939, 0.264, 0.442, 0.791, 0.259)
# (359, 'Canada', 2015, 7.413, 10.769, 0.939, 71.1, 0.931, 0.247, 0.427, 0.792, 0.286)
# (360, 'Canada', 2016, 7.245, 10.768, 0.924, 71.15, 0.912, 0.205, 0.385, 0.768, 0.237)
# (361, 'Canada', 2017, 7.415, 10.786, 0.934, 71.2, 0.945, 0.157, 0.362, 0.799, 0.218)
# (362, 'Canada', 2018, 7.175, 10.799, 0.923, 71.25, 0.946, 0.1, 0.372, 0.773, 0.259)
# (363, 'Canada', 2019, 7.109, 10.803, 0.925, 71.3, 0.912, 0.105, 0.436, 0.781, 0.285)
# (364, 'Canada', 2020, 7.025, 10.74, 0.931, 71.35, 0.887, 0.043, 0.434, 0.738, 0.307)
# (365, 'Canada', 2021, 6.939, 10.783, 0.926, 71.4, 0.898, 0.189, 0.384, 0.763, 0.276)
# (366, 'Canada', 2022, 6.918, 10.799, 0.929, 71.45, 0.838, 0.22, 0.442, 0.719, 0.287)
# (367, 'Canada', 2023, 6.841, 10.794, 0.902, 71.5, 0.847, 0.196, 0.468, 0.726, 0.304)
# (368, 'Central African Republic', 2007, 4.16, 6.946, 0.532, 41.48, 0.663, 0.079, 0.782, 0.567, 0.33)
# (369, 'Central African Republic', 2010, 3.568, 7.031, 0.483, 42.5, 0.69, -0.037, 0.845, 0.478, 0.257)
# (370, 'Central African Republic', 2011, 3.678, 7.057, 0.387, 42.84, 0.78, -0.016, 0.834, 0.502, 0.277)
# (371, 'Central African Republic', 2016, 2.693, 6.707, 0.29, 44.75, 0.624, 0.033, 0.859, 0.551, 0.494)
# (372, 'Central African Republic', 2017, 3.476, 6.733, 0.32, 45.3, 0.645, 0.074, 0.89, 0.602, 0.599)
# (373, 'Chad', 2006, 3.435, 7.369, 0.724, 47.08, 0.306, 0.022, 0.961, 0.571, 0.263)
# (374, 'Chad', 2007, 4.141, 7.368, 0.479, 47.46, 0.295, -0.017, 0.874, 0.598, 0.245)
# (375, 'Chad', 2008, 4.632, 7.363, 0.571, 47.84, 0.527, 0.057, 0.944, 0.569, 0.225)
# (376, 'Chad', 2009, 3.639, 7.369, 0.646, 48.22, 0.401, 0.016, 0.931, 0.601, 0.221)
# (377, 'Chad', 2010, 3.743, 7.462, 0.734, 48.6, 0.505, 0.02, 0.858, 0.56, 0.287)
# (378, 'Chad', 2011, 4.393, 7.428, 0.819, 48.98, 0.54, 0.025, 0.876, 0.579, 0.289)
# (379, 'Chad', 2012, 4.033, 7.478, 0.673, 49.36, 0.563, -0.039, 0.884, 0.498, 0.316)
# (380, 'Chad', 2013, 3.508, 7.498, 0.714, 49.74, 0.488, -0.051, 0.882, 0.437, 0.314)
# (381, 'Chad', 2014, 3.46, 7.529, 0.733, 50.12, 0.567, -0.075, 0.881, 0.524, 0.329)
# (382, 'Chad', 2015, 4.323, 7.525, 0.751, 50.5, 0.474, -0.034, 0.889, 0.593, 0.358)
# (383, 'Chad', 2016, 4.029, 7.429, 0.616, 50.875, 0.525, 0.047, 0.82, 0.564, 0.468)
# (384, 'Chad', 2017, 4.559, 7.365, 0.661, 51.25, 0.615, 0.003, 0.792, 0.584, 0.538)
# (385, 'Chad', 2018, 4.486, 7.355, 0.577, 51.625, 0.65, 0.02, 0.763, 0.532, 0.544)
# (386, 'Chad', 2019, 4.251, 7.354, 0.64, 52.0, 0.537, 0.051, 0.832, 0.556, 0.46)
# (387, 'Chad', 2022, 4.397, 7.253, 0.72, 53.125, 0.679, 0.218, 0.805, 0.588, 0.499)
# (388, 'Chad', 2023, 4.544, 7.254, 0.609, 53.5, 0.586, 0.138, 0.755, 0.541, 0.467)
# (389, 'Chile', 2006, 6.063, 9.87, 0.836, 67.78, 0.744, 0.161, 0.634, 0.752, 0.348)
# (390, 'Chile', 2007, 5.698, 9.91, 0.815, 67.96, 0.662, 0.236, 0.723, 0.708, 0.342)
# (391, 'Chile', 2008, 5.789, 9.938, 0.804, 68.14, 0.64, 0.076, 0.741, 0.706, 0.33)
# (392, 'Chile', 2009, 6.494, 9.916, 0.832, 68.32, 0.747, 0.141, 0.734, 0.756, 0.3)
# (393, 'Chile', 2010, 6.636, 9.963, 0.857, 68.5, 0.786, 0.1, 0.702, 0.76, 0.3)
# (394, 'Chile', 2011, 6.526, 10.013, 0.819, 68.68, 0.701, 0.104, 0.753, 0.758, 0.317)
# (395, 'Chile', 2012, 6.599, 10.063, 0.855, 68.86, 0.734, 0.186, 0.782, 0.736, 0.288)
# (396, 'Chile', 2013, 6.74, 10.086, 0.862, 69.04, 0.737, 0.077, 0.741, 0.791, 0.285)
# (397, 'Chile', 2014, 6.844, 10.094, 0.862, 69.22, 0.733, 0.209, 0.758, 0.8, 0.276)
# (398, 'Chile', 2015, 6.533, 10.105, 0.827, 69.4, 0.769, 0.032, 0.812, 0.752, 0.333)
# (399, 'Chile', 2016, 6.579, 10.11, 0.841, 69.55, 0.652, 0.094, 0.858, 0.792, 0.283)
# (400, 'Chile', 2017, 6.32, 10.108, 0.88, 69.7, 0.79, -0.028, 0.836, 0.765, 0.291)
# (401, 'Chile', 2018, 6.436, 10.13, 0.89, 69.85, 0.789, -0.068, 0.816, 0.755, 0.276)
# (402, 'Chile', 2019, 5.942, 10.119, 0.869, 70.0, 0.659, -0.11, 0.86, 0.741, 0.337)
# (403, 'Chile', 2020, 6.151, 10.042, 0.888, 70.15, 0.781, 0.026, 0.812, 0.753, 0.336)
# (404, 'Chile', 2021, 6.436, 10.143, 0.891, 70.3, 0.803, -0.052, 0.859, 0.735, 0.221)
# (405, 'Chile', 2022, 6.415, 10.161, 0.887, 70.45, 0.793, -0.014, 0.796, 0.775, 0.253)
# (406, 'Chile', 2023, 6.23, 10.155, 0.874, 70.6, 0.815, -0.027, 0.836, 0.779, 0.263)
# (407, 'China', 2006, 4.56, 8.696, 0.747, 65.66, 0.853, -0.182, 0.7363909129875696, 0.658, 0.17)
# (408, 'China', 2007, 4.863, 8.824, 0.811, 65.92, 0.853, -0.182, 0.7363909129875696, 0.664, 0.159)
# (409, 'China', 2008, 4.846, 8.911, 0.748, 66.18, 0.853, -0.098, 0.7363909129875696, 0.705, 0.147)
# (410, 'China', 2009, 4.454, 8.996, 0.798, 66.44, 0.771, -0.166, 0.7363909129875696, 0.67, 0.162)
# (411, 'China', 2010, 4.653, 9.092, 0.768, 66.7, 0.805, -0.139, 0.7363909129875696, 0.658, 0.158)
# (412, 'China', 2011, 5.037, 9.178, 0.787, 66.96, 0.824, -0.192, 0.7363909129875696, 0.71, 0.134)
# (413, 'China', 2012, 5.095, 9.247, 0.788, 67.22, 0.808, -0.19, 0.7363909129875696, 0.689, 0.159)
# (414, 'China', 2013, 5.241, 9.315, 0.778, 67.48, 0.805, -0.163, 0.7363909129875696, 0.717, 0.142)
# (415, 'China', 2014, 5.196, 9.38, 0.82, 67.74, 0.82325, -0.222, 0.7363909129875696, 0.71, 0.112)
# (416, 'China', 2015, 5.304, 9.442, 0.794, 68.0, 0.8415, -0.25, 0.7363909129875696, 0.667, 0.171)
# (417, 'China', 2016, 5.325, 9.503, 0.742, 68.125, 0.85975, -0.233, 0.7363909129875696, 0.683, 0.146)
# (418, 'China', 2017, 5.099, 9.564, 0.772, 68.25, 0.878, -0.18, 0.7363909129875696, 0.682, 0.214)
# (419, 'China', 2018, 5.131, 9.625, 0.788, 68.375, 0.895, -0.164, 0.7363909129875696, 0.722, 0.19)
# (420, 'China', 2019, 5.144, 9.679, 0.822, 68.5, 0.927, -0.178, 0.7363909129875696, 0.76, 0.147)
# (421, 'China', 2020, 5.771, 9.699, 0.808, 68.625, 0.891, -0.109, 0.7363909129875696, 0.663, 0.245)
# (422, 'China', 2021, 5.863, 9.779, 0.856, 68.75, 0.875, 0.02, 0.7363909129875696, 0.698, 0.24)
# (423, 'China', 2023, 6.145, 9.861, 0.797, 69.0, 0.793, -0.032, 0.7363909129875696, 0.708, 0.21)
# (424, 'Colombia', 2006, 6.025, 9.277, 0.91, 66.32, 0.805, -0.021, 0.808, 0.776, 0.326)
# (425, 'Colombia', 2007, 6.138, 9.33, 0.894, 66.54, 0.786, -0.046, 0.86, 0.774, 0.287)
# (426, 'Colombia', 2008, 6.168, 9.351, 0.88, 66.76, 0.795, -0.047, 0.763, 0.768, 0.307)
# (427, 'Colombia', 2009, 6.272, 9.351, 0.886, 66.98, 0.757, -0.06, 0.837, 0.786, 0.273)
# (428, 'Colombia', 2010, 6.408, 9.383, 0.893, 67.2, 0.816, -0.055, 0.815, 0.792, 0.265)
# (429, 'Colombia', 2011, 6.464, 9.44, 0.904, 67.42, 0.811, -0.079, 0.847, 0.785, 0.286)
# (430, 'Colombia', 2012, 6.375, 9.468, 0.914, 67.64, 0.828, -0.015, 0.868, 0.829, 0.294)
# (431, 'Colombia', 2013, 6.607, 9.508, 0.901, 67.86, 0.841, -0.076, 0.898, 0.815, 0.278)
# (432, 'Colombia', 2014, 6.449, 9.542, 0.907, 68.08, 0.801, -0.096, 0.887, 0.825, 0.278)
# (433, 'Colombia', 2015, 6.388, 9.562, 0.89, 68.3, 0.791, -0.106, 0.843, 0.803, 0.292)
# (434, 'Colombia', 2016, 6.234, 9.572, 0.882, 68.475, 0.835, -0.106, 0.898, 0.77, 0.294)
# (435, 'Colombia', 2017, 6.157, 9.57, 0.909, 68.65, 0.838, -0.163, 0.875, 0.79, 0.299)
# (436, 'Colombia', 2018, 5.984, 9.577, 0.871, 68.825, 0.851, -0.154, 0.855, 0.775, 0.301)
# (437, 'Colombia', 2019, 6.35, 9.59, 0.873, 69.0, 0.822, -0.177, 0.854, 0.791, 0.322)
# (438, 'Colombia', 2020, 5.709, 9.5, 0.797, 69.175, 0.84, -0.091, 0.808, 0.759, 0.34)
# (439, 'Colombia', 2021, 5.29, 9.593, 0.793, 69.35, 0.775, -0.065, 0.831, 0.752, 0.348)
# (440, 'Colombia', 2022, 5.892, 9.658, 0.877, 69.525, 0.799, -0.164, 0.863, 0.762, 0.306)
# (441, 'Colombia', 2023, 5.904, 9.667, 0.833, 69.7, 0.823, -0.142, 0.87, 0.754, 0.285)
# (442, 'Comoros', 2009, 3.476, 7.999, 0.629, 56.76, 0.508, -0.082, 0.838, 0.626, 0.167)
# (443, 'Comoros', 2010, 3.812, 8.015, 0.721, 57.0, 0.529, -0.003, 0.741, 0.664, 0.178)
# (444, 'Comoros', 2011, 3.838, 8.034, 0.722, 57.24, 0.5, -0.084, 0.732, 0.622, 0.173)
# (445, 'Comoros', 2012, 3.956, 8.044, 0.719, 57.48, 0.534, -0.13, 0.651, 0.616, 0.212)
# (446, 'Comoros', 2018, 3.973, 8.1, 0.621, 58.725, 0.56, 0.075, 0.794, 0.688, 0.337)
# (447, 'Comoros', 2019, 4.609, 8.099, 0.632, 58.9, 0.538, 0.067, 0.762, 0.665, 0.336)
# (448, 'Comoros', 2022, 3.545, 8.085, 0.472, 59.425, 0.481, -0.018, 0.732, 0.603, 0.352)
# (449, 'Comoros', 2023, 3.588, 8.095, 0.483, 59.6, 0.452, 0.004, 0.704, 0.535, 0.405)
# (450, 'Congo (Brazzaville)', 2008, 3.82, 8.39, 0.555, 52.24, 0.526, -0.125, 0.833, 0.603, 0.298)
# (451, 'Congo (Brazzaville)', 2011, 4.51, 8.502, 0.637, 53.38, 0.745, -0.137, 0.833, 0.601, 0.288)
# (452, 'Congo (Brazzaville)', 2012, 3.919, 8.569, 0.622, 53.76, 0.773, -0.144, 0.8, 0.547, 0.323)
# (453, 'Congo (Brazzaville)', 2013, 3.955, 8.538, 0.68, 54.14, 0.726, -0.107, 0.752, 0.599, 0.291)
# (454, 'Congo (Brazzaville)', 2014, 4.056, 8.579, 0.686, 54.52, 0.662, -0.14, 0.808, 0.558, 0.4)
# (455, 'Congo (Brazzaville)', 2015, 4.691, 8.519, 0.642, 54.9, 0.85, -0.129, 0.841, 0.555, 0.261)
# (456, 'Congo (Brazzaville)', 2016, 4.119, 8.381, 0.615, 55.225, 0.786, -0.091, 0.79, 0.586, 0.304)
# (457, 'Congo (Brazzaville)', 2017, 4.884, 8.312, 0.655, 55.55, 0.778, -0.148, 0.763, 0.574, 0.382)
# (458, 'Congo (Brazzaville)', 2018, 5.49, 8.239, 0.621, 55.875, 0.699, -0.105, 0.738, 0.571, 0.448)
# (459, 'Congo (Brazzaville)', 2019, 5.213, 8.215, 0.625, 56.2, 0.686, -0.059, 0.741, 0.594, 0.405)
# (460, 'Congo (Brazzaville)', 2020, 5.079, 8.127, 0.597, 56.525, 0.761, -0.024, 0.728, 0.572, 0.435)
# (461, 'Congo (Brazzaville)', 2021, 4.921, 8.082, 0.568, 56.85, 0.738, -0.023, 0.733, 0.568, 0.42)
# (462, 'Congo (Brazzaville)', 2022, 5.805, 8.074, 0.646, 57.175, 0.698, 0.025, 0.76, 0.583, 0.477)
# (463, 'Congo (Brazzaville)', 2023, 4.954, 8.086, 0.561, 57.5, 0.702, -0.051, 0.745, 0.585, 0.409)
# (464, 'Congo (Kinshasa)', 2009, 3.984, 6.699, 0.733, 49.4, 0.556, -0.025, 0.824, 0.487, 0.283)
# (465, 'Congo (Kinshasa)', 2011, 4.517, 6.769, 0.744, 50.4, 0.631, -0.028, 0.856, 0.565, 0.208)
# (466, 'Congo (Kinshasa)', 2012, 4.639, 6.803, 0.77, 50.9, 0.557, -0.037, 0.807, 0.626, 0.23)
# (467, 'Congo (Kinshasa)', 2013, 4.497, 6.851, 0.83, 51.4, 0.48, 0.009, 0.913, 0.556, 0.187)
# (468, 'Congo (Kinshasa)', 2014, 4.414, 6.907, 0.822, 51.9, 0.556, 0.006, 0.814, 0.519, 0.305)
# (469, 'Congo (Kinshasa)', 2015, 3.903, 6.94, 0.767, 52.4, 0.574, -0.05, 0.866, 0.538, 0.301)
# (470, 'Congo (Kinshasa)', 2016, 4.522, 6.929, 0.864, 52.825, 0.637, -0.027, 0.875, 0.61, 0.222)
# (471, 'Congo (Kinshasa)', 2017, 4.311, 6.931, 0.67, 53.25, 0.704, 0.066, 0.809, 0.541, 0.404)
# (472, 'Congo (Kinshasa)', 2022, 3.207, 7.032, 0.654, 55.375, 0.664, 0.08, 0.836, 0.563, 0.461)
# (473, 'Congo (Kinshasa)', 2023, 3.383, 7.076, 0.572, 55.8, 0.687, 0.152, 0.837, 0.546, 0.497)
# (474, 'Costa Rica', 2006, 7.082, 9.607, 0.937, 68.56, 0.882, 0.052, 0.798, 0.815, 0.236)
# (475, 'Costa Rica', 2007, 7.432, 9.672, 0.918, 68.72, 0.923, 0.089, 0.82, 0.826, 0.24)
# (476, 'Costa Rica', 2008, 6.851, 9.704, 0.916, 68.88, 0.912, 0.087, 0.816, 0.838, 0.233)
# (477, 'Costa Rica', 2009, 7.615, 9.682, 0.9, 69.04, 0.886, 0.057, 0.787, 0.84, 0.217)
# (478, 'Costa Rica', 2010, 7.271, 9.721, 0.915, 69.2, 0.881, 0.038, 0.763, 0.827, 0.221)
# (479, 'Costa Rica', 2011, 7.229, 9.752, 0.892, 69.36, 0.926, -0.042, 0.837, 0.794, 0.269)
# (480, 'Costa Rica', 2012, 7.272, 9.788, 0.902, 69.52, 0.929, 0.037, 0.794, 0.837, 0.263)
# (481, 'Costa Rica', 2013, 7.158, 9.801, 0.902, 69.68, 0.898, 0.009, 0.813, 0.809, 0.278)
# (482, 'Costa Rica', 2014, 7.247, 9.824, 0.914, 69.84, 0.927, 0.0, 0.788, 0.797, 0.29)
# (483, 'Costa Rica', 2015, 6.854, 9.85, 0.878, 70.0, 0.907, -0.068, 0.761, 0.811, 0.286)
# (484, 'Costa Rica', 2016, 7.136, 9.881, 0.901, 70.0, 0.873, -0.042, 0.781, 0.83, 0.281)
# (485, 'Costa Rica', 2017, 7.225, 9.912, 0.922, 70.0, 0.936, -0.086, 0.742, 0.791, 0.275)
# (486, 'Costa Rica', 2018, 7.141, 9.928, 0.876, 70.0, 0.942, -0.117, 0.781, 0.802, 0.326)
# (487, 'Costa Rica', 2019, 6.998, 9.944, 0.906, 70.0, 0.927, -0.156, 0.836, 0.791, 0.303)
# (488, 'Costa Rica', 2020, 6.338, 9.892, 0.834, 70.0, 0.889, -0.139, 0.772, 0.759, 0.35)
# (489, 'Costa Rica', 2021, 6.408, 9.961, 0.876, 70.0, 0.887, -0.029, 0.782, 0.774, 0.318)
# (490, 'Costa Rica', 2022, 7.077, 9.998, 0.902, 70.0, 0.91, -0.049, 0.751, 0.793, 0.272)
# (491, 'Costa Rica', 2023, 7.384, 10.021, 0.875, 70.0, 0.933, -0.067, 0.767, 0.806, 0.282)
# (492, 'Croatia', 2007, 5.821, 10.174, 0.91, 66.94, 0.662, -0.099, 0.934, 0.55, 0.337)
# (493, 'Croatia', 2009, 5.433, 10.12, 0.861, 67.18, 0.549, -0.278, 0.958, 0.557, 0.272)
# (494, 'Croatia', 2010, 5.596, 10.11, 0.796, 67.3, 0.564, -0.244, 0.973, 0.554, 0.259)
# (495, 'Croatia', 2011, 5.385, 10.113, 0.79, 67.42, 0.517, -0.205, 0.977, 0.552, 0.273)
# (496, 'Croatia', 2012, 6.028, 10.092, 0.776, 67.54, 0.542, -0.25, 0.924, 0.572, 0.271)
# (497, 'Croatia', 2013, 5.885, 10.091, 0.751, 67.66, 0.627, -0.211, 0.936, 0.554, 0.285)
# (498, 'Croatia', 2014, 5.381, 10.091, 0.646, 67.78, 0.519, 0.125, 0.918, 0.545, 0.286)
# (499, 'Croatia', 2015, 5.205, 10.124, 0.768, 67.9, 0.694, -0.104, 0.849, 0.57, 0.294)
# (500, 'Croatia', 2016, 5.417, 10.166, 0.798, 68.075, 0.672, -0.072, 0.884, 0.569, 0.337)
# (501, 'Croatia', 2017, 5.343, 10.211, 0.77, 68.25, 0.716, -0.112, 0.892, 0.618, 0.316)
# (502, 'Croatia', 2018, 5.536, 10.248, 0.91, 68.425, 0.691, -0.158, 0.925, 0.512, 0.29)
# (503, 'Croatia', 2019, 5.626, 10.287, 0.936, 68.6, 0.739, -0.145, 0.932, 0.504, 0.269)
# (504, 'Croatia', 2020, 6.508, 10.202, 0.923, 68.775, 0.837, -0.071, 0.961, 0.681, 0.286)
# (505, 'Croatia', 2021, 6.287, 10.367, 0.918, 68.95, 0.842, 0.001, 0.934, 0.64, 0.274)
# (506, 'Croatia', 2022, 5.579, 10.435, 0.91, 69.125, 0.593, -0.213, 0.875, 0.573, 0.267)
# (507, 'Croatia', 2023, 5.958, 10.462, 0.909, 69.3, 0.573, -0.205, 0.81, 0.61, 0.23)
# (508, 'Cuba', 2006, 5.418, 9.393506372132542, 0.97, 68.0, 0.281, 0.0006049277824978727, 0.7363909129875696, 0.596, 0.277)
# (509, 'Cyprus', 2006, 6.238, 10.567, 0.878, 70.16, 0.836, 0.012, 0.712, 0.704, 0.253)
# (510, 'Cyprus', 2009, 6.833, 10.559, 0.812, 70.64, 0.775, 0.048, 0.801, 0.668, 0.329)
# (511, 'Cyprus', 2010, 6.387, 10.556, 0.822, 70.8, 0.755, 0.066, 0.833, 0.699, 0.296)
# (512, 'Cyprus', 2011, 6.69, 10.534, 0.844, 70.96, 0.745, 0.173, 0.841, 0.682, 0.272)
# (513, 'Cyprus', 2012, 6.181, 10.484, 0.767, 71.12, 0.725, 0.092, 0.871, 0.687, 0.369)
# (514, 'Cyprus', 2013, 5.439, 10.418, 0.744, 71.28, 0.656, 0.096, 0.867, 0.657, 0.42)
# (515, 'Cyprus', 2014, 5.627, 10.411, 0.77, 71.44, 0.715, 0.054, 0.868, 0.661, 0.397)
# (516, 'Cyprus', 2015, 5.439, 10.451, 0.77, 71.6, 0.628, 0.107, 0.893, 0.66, 0.383)
# (517, 'Cyprus', 2016, 5.795, 10.51, 0.786, 71.8, 0.756, -0.036, 0.898, 0.631, 0.336)
# (518, 'Cyprus', 2017, 6.062, 10.556, 0.819, 72.0, 0.812, 0.036, 0.851, 0.67, 0.301)
# (519, 'Cyprus', 2018, 6.276, 10.599, 0.826, 72.2, 0.794, -0.031, 0.848, 0.663, 0.298)
# (520, 'Cyprus', 2019, 6.137, 10.639, 0.776, 72.4, 0.74, -0.018, 0.865, 0.663, 0.29)
# (521, 'Cyprus', 2020, 6.26, 10.583, 0.806, 72.6, 0.763, -0.086, 0.816, 0.671, 0.284)
# (522, 'Cyprus', 2021, 6.269, 10.638, 0.855, 72.8, 0.718, -0.038, 0.876, 0.641, 0.275)
# (523, 'Cyprus', 2022, 5.865, 10.683, 0.82, 73.0, 0.698, 0.008, 0.887, 0.659, 0.297)
# (524, 'Cyprus', 2023, 6.071, 10.683, 0.803, 73.2, 0.73, 0.008, 0.84, 0.682, 0.297)
# (525, 'Czechia', 2005, 6.439, 10.322, 0.919, 67.1, 0.865, -0.069, 0.901, 0.639, 0.258)
# (526, 'Czechia', 2007, 6.5, 10.433, 0.9, 67.34, 0.799, -0.069, 0.928, 0.66, 0.277)
# (527, 'Czechia', 2010, 6.25, 10.419, 0.934, 67.7, 0.779, -0.048, 0.926, 0.648, 0.244)
# (528, 'Czechia', 2011, 6.331, 10.434, 0.914, 67.82, 0.787, -0.112, 0.95, 0.623, 0.253)
# (529, 'Czechia', 2012, 6.334, 10.425, 0.912, 67.94, 0.74, -0.16, 0.957, 0.635, 0.257)
# (530, 'Czechia', 2013, 6.698, 10.424, 0.888, 68.06, 0.726, -0.162, 0.916, 0.656, 0.253)
# (531, 'Czechia', 2014, 6.484, 10.445, 0.878, 68.18, 0.8, -0.174, 0.897, 0.638, 0.235)
# (532, 'Czechia', 2015, 6.608, 10.496, 0.911, 68.3, 0.808, -0.152, 0.886, 0.689, 0.206)
# (533, 'Czechia', 2016, 6.736, 10.519, 0.931, 68.425, 0.85, -0.204, 0.9, 0.71, 0.201)
# (534, 'Czechia', 2017, 6.79, 10.567, 0.901, 68.55, 0.832, -0.183, 0.867, 0.672, 0.227)
# (535, 'Czechia', 2018, 7.034, 10.595, 0.929, 68.675, 0.79, -0.299, 0.851, 0.674, 0.178)
# (536, 'Czechia', 2020, 6.897, 10.562, 0.964, 68.925, 0.906, -0.135, 0.884, 0.748, 0.29)
# (537, 'Czechia', 2021, 6.942, 10.615, 0.95, 69.05, 0.891, 0.157, 0.863, 0.716, 0.24)
# (538, 'Czechia', 2022, 6.695, 10.637, 0.944, 69.175, 0.908, 0.093, 0.831, 0.743, 0.246)
# (539, 'Czechia', 2023, 6.827, 10.639, 0.927, 69.3, 0.906, 0.025, 0.832, 0.75, 0.254)
# (540, 'Denmark', 2005, 8.019, 10.849, 0.972, 68.3, 0.971, 0.234, 0.237, 0.777, 0.154)
# (541, 'Denmark', 2007, 7.834, 10.889, 0.954, 68.74, 0.932, 0.234, 0.206, 0.778, 0.194)
# (542, 'Denmark', 2008, 7.971, 10.878, 0.954, 68.96, 0.97, 0.266, 0.248, 0.759, 0.163)
# (543, 'Denmark', 2009, 7.683, 10.822, 0.939, 69.18, 0.949, 0.258, 0.206, 0.782, 0.234)
# (544, 'Denmark', 2010, 7.771, 10.836, 0.975, 69.4, 0.944, 0.237, 0.175, 0.796, 0.155)
# (545, 'Denmark', 2011, 7.788, 10.845, 0.962, 69.62, 0.935, 0.292, 0.22, 0.778, 0.175)
# (546, 'Denmark', 2012, 7.52, 10.844, 0.951, 69.84, 0.933, 0.133, 0.187, 0.783, 0.209)
# ...
# (2188, 'Ukraine', 2020, 5.27, 9.426, 0.885, 64.425, 0.784, 0.121, 0.946, 0.629, 0.285)
# (2189, 'Ukraine', 2021, 5.311, 9.469, 0.879, 64.55, 0.77, 0.166, 0.922, 0.575, 0.25)
# (2190, 'Ukraine', 2022, 4.637, 9.281, 0.863, 64.675, 0.829, 0.408, 0.852, 0.527, 0.39)
# (2191, 'Ukraine', 2023, 4.672, 9.423, 0.839, 64.8, 0.772, 0.37, 0.922, 0.49, 0.385)
# (2192, 'United Arab Emirates', 2006, 6.734, 11.433, 0.903, 64.86, 0.898, -0.043, 0.203, 0.694, 0.275)
# (2193, 'United Arab Emirates', 2009, 6.866, 10.952, 0.885, 65.04, 0.849, 0.015, 0.339, 0.718, 0.287)
# (2194, 'United Arab Emirates', 2010, 7.097, 10.909, 0.912, 65.1, 0.878, 0.051, 0.355, 0.701, 0.233)
# (2195, 'United Arab Emirates', 2011, 7.119, 10.965, 0.881, 65.16, 0.889, 0.063, 0.355, 0.702, 0.216)
# (2196, 'United Arab Emirates', 2012, 7.218, 11.001, 0.856, 65.22, 0.92, 0.09525, 0.355, 0.719, 0.224)
# (2197, 'United Arab Emirates', 2013, 6.621, 11.041, 0.864, 65.28, 0.936, 0.1275, 0.355, 0.72, 0.291)
# (2198, 'United Arab Emirates', 2014, 6.54, 11.072, 0.844, 65.34, 0.9255, 0.15975, 0.355, 0.721, 0.2935)
# (2199, 'United Arab Emirates', 2015, 6.568, 11.128, 0.824, 65.4, 0.915, 0.192, 0.355, 0.722, 0.296)
# (2200, 'United Arab Emirates', 2016, 6.831, 11.174, 0.849, 65.55, 0.949, 0.12, 0.355, 0.739, 0.245)
# (2201, 'United Arab Emirates', 2017, 7.039, 11.173, 0.836, 65.7, 0.962, 0.206, 0.355, 0.737, 0.208)
# (2202, 'United Arab Emirates', 2018, 6.604, 11.178, 0.851, 65.85, 0.944, 0.043, 0.355, 0.723, 0.302)
# (2203, 'United Arab Emirates', 2019, 6.711, 11.181, 0.862, 66.0, 0.911, 0.118, 0.355, 0.73, 0.284)
# (2204, 'United Arab Emirates', 2020, 6.458, 11.122, 0.827, 66.15, 0.942, 0.049, 0.355, 0.702, 0.298)
# (2205, 'United Arab Emirates', 2021, 6.733, 11.152, 0.826, 66.3, 0.951, 0.15, 0.355, 0.697, 0.217)
# (2206, 'United Arab Emirates', 2022, 6.738, 11.216, 0.798, 66.45, 0.932, 0.168, 0.355, 0.715, 0.242)
# (2207, 'United Arab Emirates', 2023, 6.728, 11.236, 0.776, 66.6, 0.886, 0.155, 0.355, 0.655, 0.304)
# (2208, 'United Kingdom', 2005, 6.984, 10.661, 0.979, 69.1, 0.922, 0.331, 0.398, 0.779, 0.262)
# (2209, 'United Kingdom', 2007, 6.802, 10.693, 0.97, 69.22, 0.838, 0.331, 0.498, 0.686, 0.241)
# (2210, 'United Kingdom', 2008, 6.986, 10.684, 0.954, 69.28, 0.759, 0.325, 0.548, 0.724, 0.218)
# (2211, 'United Kingdom', 2009, 6.907, 10.63, 0.964, 69.34, 0.816, 0.336, 0.559, 0.739, 0.231)
# (2212, 'United Kingdom', 2010, 7.029, 10.646, 0.955, 69.4, 0.841, 0.397, 0.587, 0.753, 0.176)
# (2213, 'United Kingdom', 2011, 6.869, 10.649, 0.949, 69.46, 0.9, 0.331, 0.438, 0.742, 0.174)
# (2214, 'United Kingdom', 2012, 6.881, 10.656, 0.935, 69.52, 0.889, 0.366, 0.425, 0.739, 0.184)
# (2215, 'United Kingdom', 2013, 6.918, 10.668, 0.937, 69.58, 0.905, 0.341, 0.568, 0.719, 0.252)
# (2216, 'United Kingdom', 2014, 6.758, 10.692, 0.91, 69.64, 0.857, 0.349, 0.484, 0.74, 0.251)
# (2217, 'United Kingdom', 2015, 6.515, 10.707, 0.936, 69.7, 0.833, 0.294, 0.456, 0.74, 0.219)
# (2218, 'United Kingdom', 2016, 6.824, 10.721, 0.954, 69.8, 0.821, 0.244, 0.458, 0.732, 0.23)
# (2219, 'United Kingdom', 2017, 7.103, 10.739, 0.937, 69.9, 0.813, 0.285, 0.419, 0.712, 0.21)
# (2220, 'United Kingdom', 2018, 7.233, 10.75, 0.928, 70.0, 0.838, 0.22, 0.404, 0.736, 0.228)
# (2221, 'United Kingdom', 2019, 7.157, 10.76, 0.943, 70.1, 0.854, 0.264, 0.485, 0.739, 0.251)
# (2222, 'United Kingdom', 2020, 6.798, 10.639, 0.929, 70.2, 0.885, 0.196, 0.49, 0.717, 0.225)
# (2223, 'United Kingdom', 2021, 6.867, 10.713, 0.854, 70.3, 0.815, 0.252, 0.448, 0.684, 0.266)
# (2224, 'United Kingdom', 2022, 6.722, 10.754, 0.863, 70.4, 0.857, 0.308, 0.426, 0.723, 0.27)
# (2225, 'United Kingdom', 2023, 6.658, 10.759, 0.886, 70.5, 0.874, 0.27, 0.49, 0.719, 0.272)
# (2226, 'United States', 2006, 7.182, 10.921, 0.965, 66.78, 0.911, 0.191, 0.6, 0.775, 0.261)
# (2227, 'United States', 2007, 7.513, 10.931, 0.959, 66.76, 0.872, 0.191, 0.633, 0.756, 0.232)
# (2228, 'United States', 2008, 7.28, 10.923, 0.953, 66.74, 0.878, 0.249, 0.668, 0.774, 0.227)
# (2229, 'United States', 2009, 7.158, 10.888, 0.912, 66.72, 0.831, 0.195, 0.665, 0.753, 0.262)
# (2230, 'United States', 2010, 7.164, 10.906, 0.926, 66.7, 0.828, 0.238, 0.69, 0.776, 0.231)
# (2231, 'United States', 2011, 7.115, 10.914, 0.922, 66.68, 0.863, 0.155, 0.697, 0.737, 0.273)
# (2232, 'United States', 2012, 7.026, 10.929, 0.903, 66.66, 0.823, 0.208, 0.71, 0.765, 0.26)
# (2233, 'United States', 2013, 7.249, 10.941, 0.925, 66.64, 0.792, 0.268, 0.747, 0.776, 0.26)
# (2234, 'United States', 2014, 7.151, 10.956, 0.902, 66.62, 0.866, 0.215, 0.702, 0.786, 0.281)
# (2235, 'United States', 2015, 6.864, 10.975, 0.904, 66.6, 0.849, 0.213, 0.698, 0.769, 0.275)
# (2236, 'United States', 2016, 6.804, 10.985, 0.897, 66.475, 0.758, 0.138, 0.739, 0.737, 0.264)
# (2237, 'United States', 2017, 6.992, 11.001, 0.921, 66.35, 0.868, 0.191, 0.681, 0.755, 0.268)
# (2238, 'United States', 2018, 6.883, 11.024, 0.904, 66.225, 0.825, 0.11, 0.71, 0.757, 0.292)
# (2239, 'United States', 2019, 6.944, 11.042, 0.917, 66.1, 0.836, 0.138, 0.707, 0.755, 0.244)
# (2240, 'United States', 2020, 7.028, 11.005, 0.937, 65.975, 0.85, 0.028, 0.678, 0.722, 0.295)
# (2241, 'United States', 2021, 6.959, 11.061, 0.92, 65.85, 0.816, 0.188, 0.687, 0.74, 0.277)
# (2242, 'United States', 2022, 6.693, 11.078, 0.9, 65.725, 0.736, 0.189, 0.701, 0.712, 0.267)
# (2243, 'United States', 2023, 6.521, 11.089, 0.861, 65.6, 0.721, 0.185, 0.722, 0.706, 0.284)
# (2244, 'Uruguay', 2006, 5.786, 9.64, 0.912, 66.78, 0.807, -0.125, 0.477, 0.701, 0.306)
# (2245, 'Uruguay', 2007, 5.694, 9.702, 0.875, 66.86, 0.786, -0.178, 0.614, 0.71, 0.274)
# (2246, 'Uruguay', 2008, 5.664, 9.769, 0.879, 66.94, 0.808, -0.156, 0.597, 0.685, 0.264)
# (2247, 'Uruguay', 2009, 6.296, 9.808, 0.924, 67.02, 0.825, -0.131, 0.544, 0.722, 0.255)
# (2248, 'Uruguay', 2010, 6.062, 9.88, 0.893, 67.1, 0.832, -0.171, 0.471, 0.738, 0.231)
# (2249, 'Uruguay', 2011, 6.554, 9.928, 0.891, 67.18, 0.851, -0.093, 0.556, 0.702, 0.252)
# (2250, 'Uruguay', 2012, 6.45, 9.96, 0.865, 67.26, 0.871, 0.054, 0.615, 0.692, 0.214)
# (2251, 'Uruguay', 2013, 6.444, 10.002, 0.917, 67.34, 0.888, -0.056, 0.586, 0.743, 0.253)
# (2252, 'Uruguay', 2014, 6.561, 10.031, 0.902, 67.42, 0.904, -0.086, 0.533, 0.788, 0.251)
# (2253, 'Uruguay', 2015, 6.628, 10.032, 0.891, 67.5, 0.917, -0.045, 0.673, 0.812, 0.3)
# (2254, 'Uruguay', 2016, 6.171, 10.045, 0.9, 67.5, 0.886, -0.085, 0.676, 0.735, 0.283)
# (2255, 'Uruguay', 2017, 6.336, 10.06, 0.914, 67.5, 0.898, -0.104, 0.627, 0.742, 0.28)
# (2256, 'Uruguay', 2018, 6.372, 10.06, 0.917, 67.5, 0.876, -0.109, 0.683, 0.775, 0.275)
# (2257, 'Uruguay', 2019, 6.6, 10.067, 0.933, 67.5, 0.903, -0.107, 0.599, 0.764, 0.222)
# (2258, 'Uruguay', 2020, 6.31, 10.002, 0.921, 67.5, 0.908, -0.094, 0.491, 0.721, 0.265)
# (2259, 'Uruguay', 2021, 6.502, 10.054, 0.914, 67.5, 0.899, -0.054, 0.606, 0.746, 0.263)
# (2260, 'Uruguay', 2022, 6.671, 10.103, 0.905, 67.5, 0.878, -0.055, 0.631, 0.775, 0.267)
# (2261, 'Uruguay', 2023, 6.662, 10.122, 0.908, 67.5, 0.904, -0.05, 0.662, 0.753, 0.265)
# (2262, 'Uzbekistan', 2006, 5.232, 8.256, 0.903, 61.34, 0.784, -0.125, 0.609, 0.65, 0.195)
# (2263, 'Uzbekistan', 2008, 5.311, 8.402, 0.894, 61.82, 0.831, -0.033, 0.6094999999999999, 0.647, 0.187)
# (2264, 'Uzbekistan', 2009, 5.261, 8.463, 0.905, 62.06, 0.8653333333333333, 0.003, 0.61, 0.646, 0.159)
# (2265, 'Uzbekistan', 2010, 5.095, 8.508, 0.903, 62.3, 0.8996666666666667, -0.04, 0.519, 0.665, 0.152)
# (2266, 'Uzbekistan', 2011, 5.739, 8.554, 0.924, 62.54, 0.934, 0.032, 0.522, 0.663, 0.123)
# (2267, 'Uzbekistan', 2012, 6.019, 8.608, 0.933, 62.78, 0.914, -0.047, 0.463, 0.65, 0.118)
# (2268, 'Uzbekistan', 2013, 5.94, 8.662, 0.963, 63.02, 0.95, -0.043, 0.434, 0.686, 0.13)
# (2269, 'Uzbekistan', 2014, 6.049, 8.712, 0.952, 63.26, 0.954, 0.052, 0.536, 0.713, 0.106)
# (2270, 'Uzbekistan', 2015, 5.972, 8.764, 0.968, 63.5, 0.98, 0.366, 0.471, 0.778, 0.103)
# (2271, 'Uzbekistan', 2016, 5.893, 8.804, 0.945, 63.8, 0.984, 0.199, 0.46799999999999997, 0.771, 0.147)
# (2272, 'Uzbekistan', 2017, 6.421, 8.831, 0.942, 64.1, 0.985, 0.114, 0.465, 0.745, 0.203)
# (2273, 'Uzbekistan', 2018, 6.205, 8.87, 0.921, 64.4, 0.97, 0.308, 0.52, 0.746, 0.209)
# (2274, 'Uzbekistan', 2019, 6.154, 8.91, 0.915, 64.7, 0.97, 0.295, 0.511, 0.751, 0.22)
# (2275, 'Uzbekistan', 2020, 5.842, 8.91, 0.85, 65.0, 0.928, 0.19, 0.642, 0.678, 0.279)
# (2276, 'Uzbekistan', 2021, 6.185, 8.962, 0.896, 65.3, 0.927, 0.183, 0.662, 0.698, 0.233)
# (2277, 'Uzbekistan', 2022, 6.016, 8.996, 0.879, 65.6, 0.959, 0.306, 0.616, 0.741, 0.225)
# (2278, 'Uzbekistan', 2023, 6.385, 9.026, 0.909, 65.9, 0.927, 0.247, 0.65, 0.752, 0.202)
# (2279, 'Venezuela', 2005, 7.17, 9.316, 0.955, 65.5, 0.838, -0.037, 0.72, 0.803, 0.233)
# (2280, 'Venezuela', 2006, 6.525, 9.467, 0.946, 65.46, 0.798, -0.037, 0.646, 0.837, 0.178)
# (2281, 'Venezuela', 2008, 6.258, 9.719, 0.922, 65.38, 0.678, -0.232, 0.776, 0.818, 0.224)
# (2282, 'Venezuela', 2009, 7.189, 9.567, 0.945, 65.34, 0.677, -0.124, 0.828, 0.792, 0.18)
# (2283, 'Venezuela', 2010, 7.478, 9.748, 0.932, 65.3, 0.768, -0.163, 0.754, 0.847, 0.13)
# (2284, 'Venezuela', 2011, 6.58, 9.859, 0.931, 65.26, 0.766, -0.235, 0.772, 0.823, 0.199)
# (2285, 'Venezuela', 2012, 7.067, 9.862, 0.932, 65.22, 0.804, -0.201, 0.743, 0.844, 0.176)
# (2286, 'Venezuela', 2013, 6.553, 9.802, 0.896, 65.18, 0.642, -0.23, 0.837, 0.812, 0.238)
# (2287, 'Venezuela', 2014, 6.136, 9.366, 0.904, 65.14, 0.57, -0.191, 0.827, 0.797, 0.244)
# (2288, 'Venezuela', 2015, 5.569, 8.532, 0.911, 65.1, 0.512, -0.089, 0.813, 0.837, 0.223)
# (2289, 'Venezuela', 2016, 4.041, 7.602, 0.902, 64.925, 0.458, -0.06, 0.89, 0.676, 0.392)
# (2290, 'Venezuela', 2017, 5.071, 5.943, 0.896, 64.75, 0.636, 0.05, 0.844, 0.697, 0.363)
# (2291, 'Venezuela', 2018, 5.006, 5.935, 0.887, 64.575, 0.611, 0.068, 0.828, 0.723, 0.374)
# (2292, 'Venezuela', 2019, 5.081, 5.527, 0.888, 64.4, 0.626, 0.124, 0.839, 0.73, 0.351)
# (2293, 'Venezuela', 2020, 4.574, 5.527, 0.805, 64.225, 0.612, 0.124, 0.811, 0.689, 0.396)
# (2294, 'Venezuela', 2021, 5.108, 5.527, 0.812, 64.05, 0.596, 0.124, 0.824, 0.698, 0.389)
# (2295, 'Venezuela', 2022, 5.949, 5.527, 0.899, 63.875, 0.77, 0.124, 0.798, 0.754, 0.292)
# (2296, 'Venezuela', 2023, 5.765, 5.527, 0.885, 63.7, 0.757, 0.124, 0.825, 0.758, 0.3)
# (2297, 'Vietnam', 2006, 5.294, 8.554, 0.888, 64.18, 0.886, -0.006, 0.754, 0.657, 0.204)
# (2298, 'Vietnam', 2007, 5.422, 8.613, 0.856, 64.26, 0.918, 0.068, 0.754, 0.6405000000000001, 0.206)
# (2299, 'Vietnam', 2008, 5.48, 8.658, 0.805, 64.34, 0.889, 0.18, 0.789, 0.624, 0.218)
# (2300, 'Vietnam', 2009, 5.304, 8.701, 0.815, 64.42, 0.834, -0.083, 0.838, 0.481, 0.19)
# (2301, 'Vietnam', 2010, 5.296, 8.752, 0.787, 64.5, 0.831, -0.027, 0.743, 0.671, 0.216)
# (2302, 'Vietnam', 2011, 5.767, 8.804, 0.898, 64.58, 0.818, 0.084, 0.742, 0.494, 0.193)
# (2303, 'Vietnam', 2012, 5.535, 8.847, 0.775, 64.66, 0.856, -0.131, 0.815, 0.546, 0.221)
# (2304, 'Vietnam', 2013, 5.023, 8.89, 0.759, 64.74, 0.92, -0.048, 0.771, 0.689, 0.165)
# (2305, 'Vietnam', 2014, 5.085, 8.941, 0.792, 64.82, 0.9113333333333333, -0.022, 0.7803333333333333, 0.634, 0.241)
# (2306, 'Vietnam', 2015, 5.076, 8.999, 0.849, 64.9, 0.9026666666666667, 0.064, 0.7896666666666667, 0.583, 0.232)
# (2307, 'Vietnam', 2016, 5.062, 9.053, 0.876, 65.0, 0.894, -0.112, 0.799, 0.487, 0.223)
# (2308, 'Vietnam', 2017, 5.175, 9.111, 0.854, 65.1, 0.9015, -0.0875, 0.8035000000000001, 0.5505, 0.20700000000000002)
# (2309, 'Vietnam', 2018, 5.296, 9.173, 0.832, 65.2, 0.909, -0.063, 0.808, 0.614, 0.191)
# (2310, 'Vietnam', 2019, 5.467, 9.235, 0.848, 65.3, 0.952, -0.148, 0.788, 0.658, 0.186)
# (2311, 'Vietnam', 2020, 5.462, 9.254, 0.765, 65.4, 0.945, 0.063, 0.791, 0.699, 0.286)
# (2312, 'Vietnam', 2021, 5.54, 9.271, 0.799, 65.5, 0.897, 0.104, 0.798, 0.651, 0.28)
# (2313, 'Vietnam', 2022, 6.267, 9.341, 0.879, 65.6, 0.975, -0.182, 0.703, 0.774, 0.108)
# (2314, 'Vietnam', 2023, 6.325, 9.392, 0.845, 65.7, 0.956, -0.159, 0.655, 0.71, 0.12)
# (2315, 'Yemen', 2007, 4.477, 8.212, 0.825, 58.72, 0.673, 0.006, 0.832, 0.524, 0.379)
# (2316, 'Yemen', 2009, 4.809, 8.25, 0.756, 58.64, 0.644, -0.056, 0.832, 0.511, 0.374)
# (2317, 'Yemen', 2010, 4.35, 8.414, 0.727, 58.6, 0.659, -0.107, 0.853, 0.514, 0.308)
# (2318, 'Yemen', 2011, 3.746, 8.264, 0.663, 58.56, 0.638, -0.174, 0.754, 0.416, 0.285)
# (2319, 'Yemen', 2012, 4.061, 8.179, 0.682, 58.52, 0.706, -0.172, 0.793, 0.413, 0.263)
# (2320, 'Yemen', 2013, 4.218, 8.166, 0.694, 58.48, 0.543, -0.179, 0.885, 0.478, 0.266)
# (2321, 'Yemen', 2014, 3.968, 8.159, 0.638, 58.44, 0.664, -0.166, 0.885, 0.527, 0.276)
# (2322, 'Yemen', 2015, 2.983, 7.772, 0.669, 58.4, 0.61, -0.138, 0.829, 0.458, 0.321)
# (2323, 'Yemen', 2016, 3.826, 7.552, 0.775, 58.175, 0.533, -0.144, 0.817, 0.401, 0.228)
# (2324, 'Yemen', 2017, 3.254, 7.243, 0.79, 57.95, 0.595, -0.128, 0.805, 0.368, 0.295)
# (2325, 'Yemen', 2018, 3.058, 7.444, 0.789, 57.725, 0.553, -0.127, 0.793, 0.409, 0.315)
# (2326, 'Yemen', 2019, 4.197, 7.448, 0.87, 57.5, 0.651, -0.106, 0.798, 0.481, 0.213)
# (2327, 'Yemen', 2022, 3.59, 7.448, 0.872, 56.825, 0.607, -0.106, 0.788, 0.46, 0.255)
# (2328, 'Yemen', 2023, 3.532, 7.448, 0.825, 56.6, 0.583, -0.106, 0.771, 0.447, 0.341)
# (2329, 'Zambia', 2006, 4.824, 7.834, 0.798, 46.76, 0.721, -0.012, 0.785, 0.664, 0.226)
# (2330, 'Zambia', 2007, 3.998, 7.879, 0.688, 47.42, 0.682, -0.073, 0.948, 0.653, 0.246)
# (2331, 'Zambia', 2008, 4.73, 7.918, 0.624, 48.08, 0.717, 0.051, 0.89, 0.707, 0.206)
# (2332, 'Zambia', 2009, 5.26, 7.971, 0.782, 48.74, 0.696, -0.101, 0.917, 0.693, 0.123)
# (2333, 'Zambia', 2011, 4.999, 8.054, 0.864, 50.06, 0.663, -0.001, 0.882, 0.771, 0.204)
# (2334, 'Zambia', 2012, 5.013, 8.094, 0.78, 50.72, 0.788, 0.004, 0.806, 0.676, 0.25)
# (2335, 'Zambia', 2013, 5.244, 8.111, 0.761, 51.38, 0.77, -0.108, 0.732, 0.727, 0.308)
# (2336, 'Zambia', 2014, 4.346, 8.124, 0.706, 52.04, 0.812, -0.014, 0.809, 0.639, 0.327)
# (2337, 'Zambia', 2015, 4.843, 8.121, 0.691, 52.7, 0.759, -0.042, 0.871, 0.634, 0.382)
# (2338, 'Zambia', 2016, 4.348, 8.127, 0.767, 53.125, 0.812, 0.119, 0.771, 0.688, 0.372)
# (2339, 'Zambia', 2017, 3.933, 8.13, 0.744, 53.55, 0.823, 0.137, 0.74, 0.66, 0.387)
# (2340, 'Zambia', 2018, 4.041, 8.139, 0.718, 53.975, 0.791, 0.045, 0.811, 0.662, 0.351)
# (2341, 'Zambia', 2019, 3.307, 8.123, 0.638, 54.4, 0.811, 0.074, 0.832, 0.674, 0.394)
# (2342, 'Zambia', 2020, 4.838, 8.066, 0.767, 54.825, 0.75, 0.054, 0.81, 0.679, 0.345)
# (2343, 'Zambia', 2021, 3.082, 8.082, 0.619, 55.25, 0.833, 0.138, 0.824, 0.656, 0.349)
# (2344, 'Zambia', 2022, 3.728, 8.101, 0.717, 55.675, 0.889, -0.009, 0.716, 0.66, 0.309)
# (2345, 'Zambia', 2023, 3.686, 8.115, 0.664, 56.1, 0.854, 0.092, 0.814, 0.653, 0.359)
# (2346, 'Zimbabwe', 2006, 3.826, 7.46, 0.822, 40.4, 0.431, -0.063, 0.905, 0.669, 0.297)
# (2347, 'Zimbabwe', 2007, 3.28, 7.413, 0.828, 41.6, 0.456, -0.069, 0.946, 0.589, 0.265)
# (2348, 'Zimbabwe', 2008, 3.174, 7.21, 0.843, 42.8, 0.344, -0.077, 0.964, 0.571, 0.25)
# (2349, 'Zimbabwe', 2009, 4.056, 7.313, 0.806, 44.0, 0.411, -0.065, 0.931, 0.66, 0.218)
# (2350, 'Zimbabwe', 2010, 4.682, 7.495, 0.857, 45.2, 0.665, -0.081, 0.828, 0.699, 0.122)
# (2351, 'Zimbabwe', 2011, 4.846, 7.617, 0.865, 46.4, 0.633, -0.077, 0.83, 0.699, 0.211)
# (2352, 'Zimbabwe', 2012, 4.955, 7.745, 0.896, 47.6, 0.47, -0.091, 0.859, 0.613, 0.177)
# (2353, 'Zimbabwe', 2013, 4.69, 7.755, 0.799, 48.8, 0.576, -0.093, 0.831, 0.624, 0.182)
# (2354, 'Zimbabwe', 2014, 4.184, 7.748, 0.766, 50.0, 0.642, -0.062, 0.82, 0.661, 0.239)
# (2355, 'Zimbabwe', 2015, 3.703, 7.747, 0.736, 51.2, 0.667, -0.111, 0.81, 0.639, 0.179)
# (2356, 'Zimbabwe', 2016, 3.735, 7.735, 0.768, 51.675, 0.733, -0.082, 0.724, 0.685, 0.209)
# (2357, 'Zimbabwe', 2017, 3.638, 7.754, 0.754, 52.15, 0.753, -0.084, 0.751, 0.734, 0.224)
# (2358, 'Zimbabwe', 2018, 3.616, 7.783, 0.775, 52.625, 0.763, -0.055, 0.844, 0.658, 0.212)
# (2359, 'Zimbabwe', 2019, 2.694, 7.698, 0.759, 53.1, 0.632, -0.051, 0.831, 0.658, 0.235)
# (2360, 'Zimbabwe', 2020, 3.16, 7.596, 0.717, 53.575, 0.643, 0.003, 0.789, 0.661, 0.346)
# (2361, 'Zimbabwe', 2021, 3.155, 7.657, 0.685, 54.05, 0.668, -0.079, 0.757, 0.61, 0.242)
# (2362, 'Zimbabwe', 2022, 3.296, 7.67, 0.666, 54.525, 0.652, -0.073, 0.753, 0.641, 0.191)
# (2363, 'Zimbabwe', 2023, 3.572, 7.679, 0.694, 55.0, 0.735, -0.069, 0.757, 0.61, 0.179)

# %%
'''
cursor.execute("DROP TABLE IF EXISTS file") 
con.commit()
con.close()
'''
#Za brisanje tablice ukoliko je potrebno

# %% [markdown]
# Kao što je vidljivo, na prethodnim NaN mjestima gdje se koristila metoda interpolacije, sada se prikazuju primjereni brojčani iznosi, a na mjestima gdje to nije bilo moguće i gdje se koristila samo fillna metoda, moguće je prepoznati veću količinu decimalnih mjesta što ne utječe negativno na izlaze, osim na preglednost.

# %%
cursor.execute("""
    CREATE UNIQUE INDEX IF NOT EXISTS idx_country_year 
    ON file (country_name, year);
""")

cursor.execute("""
    CREATE INDEX IF NOT EXISTS idx_country_name 
    ON file (country_name);
""")

cursor.execute("""
    CREATE INDEX IF NOT EXISTS idx_year 
    ON file (year);
""")

cursor.execute("""
    CREATE INDEX IF NOT EXISTS idx_life_ladder 
    ON file (life_ladder);
""")

con.close()

# %% [markdown]
# Naknadno su kreirani ključevi preko kojih će se kasnije upravljati ispis podataka u nadolazećem koraku.
#
# Sada će se u bazu uvesti i drugi set podataka koji će se kasnije koristiti kako bi se vidjelo ima li preklapanja među indeksom sreće i indeksa mira u istoj godini.

# %%
# Spajanje na bazu i kreiranje nove tablice za indeks mira
con = sqlite3.connect("SQL1.db")
cursor = con.cursor()

cursor.execute("""
    CREATE TABLE IF NOT EXISTS pis_file (
        id INTEGER PRIMARY KEY AUTOINCREMENT,
        Country TEXT,
        iso3c INT,
        Two8 REAL,
        Two9 REAL,
        Two10 REAL,
        Two11 REAL,
        Two12 REAL,
        Two13 REAL,
        Two14 REAL,
        Two15 REAL,
        Two16 REAL,
        Two17 REAL,
        Two18 REAL,
        Two19 REAL,
        Two20 REAL
    )
""")
con.commit()

# %%
# Dodavanje podataka u tablicu
for _, row in pis.iterrows():
    cursor.execute("""
        INSERT OR REPLACE INTO pis_file (Country, iso3c, Two8,Two9,Two10,Two11,
        Two12,Two13,Two14,Two15,Two16,Two17,Two18,Two19,Two20)
    VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
    """, tuple(row))

con.commit()

# %%
'''
cursor.execute("DROP TABLE IF EXISTS pis_file") 
con.commit()
#con.close()
'''
#Za brisanje tablice ukoliko je potrebno
#$ Ako se dogodi da se slučajno više puta pokrene petlja stvorit će se dupli podaci pa je poželjno da se za svaki slučaj izbriše tablica. 
#
# Out:
# '\ncursor.execute("DROP TABLE IF EXISTS pis_file") \ncon.commit()\n#con.close()\n'

# %% [markdown]
# S obzirom da se radi o dva različita seta podataka, potrebno ih je normalizirati.
#
# ### Precizirani opis normalizacije
#
# Skup podataka za indeks sreće:
#
# U ovom skupu podataka, godina je zaseban stupac, dok se država pojavljuje više puta, s jednim retkom za svaku godinu prema određenoj državi.
# Ovaj skup podataka već ima odgovarajući format za analize i pretrage koje uključuju promjene po godinama za svaku državu.
# Naime, u ovom setu podataka, osim indeksa sreće, prisutni su i drugi čimbenici koji su specifični za svaku državu pa bi bilo teško kombinirati ovaj skup s drugim skupom podataka u trenutnom obliku.
#
# Skup podataka za indeks mira:
#
# Ovdje svaka država ima samo jedan redak, a godine (2008 do 2020) predstavljaju zasebne stupce. Svaka država prikazuje svoje vrijednosti indeksa mira za svaku godinu u posebnom stupcu. Ovaj način organiziranja podataka znači da postoji manji broj redaka jer se godina prikazuje u obliku stupaca, umjesto da postoji više redaka po godinama za svaku državu. Međutim, s obzirom na postojanje više čimbenika u prvom setu podataka, normalizirat će se skup podataka za indeks mira.
#
# Postupak normalizacije:
#
# Proces normalizacije podrazumijeva transformaciju trenutno svakog stupca koji predstavlja pojedinačnu godinu u zaseban redak s novim stupcima (country_name, year, peace_index). Na taj način, i indeks mira postaje organiziran u obliku koji je usporediv s indeksom sreće, gdje svaka država ima više redaka (jedan za svaku godinu).
#
# Nakon normalizacije, oba skupa podataka (indeks sreće i indeks mira) bit će u istom formatu. Svaki redak predstavlja jednu godinu za određenu državu, a bit će jasno definiran stupac za godinu, stupac za državu i stupac za vrijednost indeksa (bilo da je to indeks sreće ili indeks mira). Na taj način bit će moguće uspoređivati ove dvije varijable kroz godine za svaku državu.

# %%
con = sqlite3.connect("SQL1.db")
cursor = con.cursor()

cursor.execute("""
    CREATE TABLE IF NOT EXISTS peace_normalized (
        id INTEGER PRIMARY KEY AUTOINCREMENT,
        country_name TEXT,
        year INT,
        peace_index REAL
    )
""")
con.commit()

# potrebno je normalizirati tablicu
cursor.execute("SELECT Country, iso3c, Two8, Two9, Two10, Two11, Two12, Two13, Two14, Two15, Two16, Two17, Two18, Two19, Two20 FROM pis_file")
rows = cursor.fetchall()

normalized_data = []
years = range(2008, 2021) 

for row in rows:
    country = row[0]
    for i, year in enumerate(years):
        peace_index = row[i + 2] 
        
        
        if peace_index is not None:
            normalized_data.append((country, year, peace_index))

# normalizirani podaci
cursor.executemany("""
    INSERT INTO peace_normalized (country_name, year, peace_index)
    VALUES (?, ?, ?)
""", normalized_data)

con.commit()

#con.close()

# %%
cursor.execute("SELECT * FROM peace_normalized")
rows = cursor.fetchall()

for row in rows:
    print(row)
    
#con.close()
# Out:
# (1, 'Afghanistan', 2008, 3.095)
# (2, 'Afghanistan', 2009, 3.19099999999999)
# (3, 'Afghanistan', 2010, 3.04)
# (4, 'Afghanistan', 2011, 3.02099999999999)
# (5, 'Afghanistan', 2012, 3.15399999999999)
# (6, 'Afghanistan', 2013, 3.258)
# (7, 'Afghanistan', 2014, 3.212)
# (8, 'Afghanistan', 2015, 3.31599999999999)
# (9, 'Afghanistan', 2016, 3.362)
# (10, 'Afghanistan', 2017, 3.41199999999999)
# (11, 'Afghanistan', 2018, 3.51299999999999)
# (12, 'Afghanistan', 2019, 3.52)
# (13, 'Afghanistan', 2020, 3.592)
# (14, 'Albania', 2008, 1.806)
# (15, 'Albania', 2009, 1.77899999999999)
# (16, 'Albania', 2010, 1.77)
# (17, 'Albania', 2011, 1.79699999999999)
# (18, 'Albania', 2012, 1.79899999999999)
# (19, 'Albania', 2013, 1.816)
# (20, 'Albania', 2014, 1.81)
# (21, 'Albania', 2015, 1.806)
# (22, 'Albania', 2016, 1.76099999999999)
# (23, 'Albania', 2017, 1.774)
# (24, 'Albania', 2018, 1.714)
# (25, 'Albania', 2019, 1.712)
# (26, 'Albania', 2020, 1.77099999999999)
# (27, 'Algeria', 2008, 2.306)
# (28, 'Algeria', 2009, 2.333)
# (29, 'Algeria', 2010, 2.333)
# (30, 'Algeria', 2011, 2.479)
# (31, 'Algeria', 2012, 2.399)
# (32, 'Algeria', 2013, 2.383)
# (33, 'Algeria', 2014, 2.293)
# (34, 'Algeria', 2015, 2.26299999999999)
# (35, 'Algeria', 2016, 2.238)
# (36, 'Algeria', 2017, 2.206)
# (37, 'Algeria', 2018, 2.212)
# (38, 'Algeria', 2019, 2.23499999999999)
# (39, 'Algeria', 2020, 2.234)
# (40, 'Angola', 2008, 2.06199999999999)
# (41, 'Angola', 2009, 2.06599999999999)
# (42, 'Angola', 2010, 2.00599999999999)
# (43, 'Angola', 2011, 2.04899999999999)
# (44, 'Angola', 2012, 2.087)
# (45, 'Angola', 2013, 2.089)
# (46, 'Angola', 2014, 2.06199999999999)
# (47, 'Angola', 2015, 1.957)
# (48, 'Angola', 2016, 1.974)
# (49, 'Angola', 2017, 1.93799999999999)
# (50, 'Angola', 2018, 1.972)
# (51, 'Angola', 2019, 1.955)
# (52, 'Angola', 2020, 1.989)
# (53, 'Argentina', 2008, 1.818)
# (54, 'Argentina', 2009, 1.946)
# (55, 'Argentina', 2010, 1.947)
# (56, 'Argentina', 2011, 1.909)
# (57, 'Argentina', 2012, 1.872)
# (58, 'Argentina', 2013, 2.00099999999999)
# (59, 'Argentina', 2014, 1.905)
# (60, 'Argentina', 2015, 1.984)
# (61, 'Argentina', 2016, 1.981)
# (62, 'Argentina', 2017, 1.93599999999999)
# (63, 'Argentina', 2018, 1.91399999999999)
# (64, 'Argentina', 2019, 1.978)
# (65, 'Argentina', 2020, 1.948)
# (66, 'Armenia', 2008, 2.196)
# (67, 'Armenia', 2009, 2.21899999999999)
# (68, 'Armenia', 2010, 2.229)
# (69, 'Armenia', 2011, 2.193)
# (70, 'Armenia', 2012, 2.194)
# (71, 'Armenia', 2013, 2.198)
# (72, 'Armenia', 2014, 2.13399999999999)
# (73, 'Armenia', 2015, 2.157)
# (74, 'Armenia', 2016, 2.105)
# (75, 'Armenia', 2017, 2.177)
# (76, 'Armenia', 2018, 2.228)
# (77, 'Armenia', 2019, 2.121)
# (78, 'Armenia', 2020, 1.952)
# (79, 'Australia', 2008, 1.349)
# (80, 'Australia', 2009, 1.37599999999999)
# (81, 'Australia', 2010, 1.387)
# (82, 'Australia', 2011, 1.439)
# (83, 'Australia', 2012, 1.497)
# (84, 'Australia', 2013, 1.451)
# (85, 'Australia', 2014, 1.38599999999999)
# (86, 'Australia', 2015, 1.359)
# (87, 'Australia', 2016, 1.38799999999999)
# (88, 'Australia', 2017, 1.41399999999999)
# (89, 'Australia', 2018, 1.42199999999999)
# (90, 'Australia', 2019, 1.427)
# (91, 'Australia', 2020, 1.42799999999999)
# (92, 'Austria', 2008, 1.347)
# (93, 'Austria', 2009, 1.365)
# (94, 'Austria', 2010, 1.357)
# (95, 'Austria', 2011, 1.395)
# (96, 'Austria', 2012, 1.364)
# (97, 'Austria', 2013, 1.28299999999999)
# (98, 'Austria', 2014, 1.26499999999999)
# (99, 'Austria', 2015, 1.233)
# (100, 'Austria', 2016, 1.22)
# (101, 'Austria', 2017, 1.298)
# (102, 'Austria', 2018, 1.26299999999999)
# (103, 'Austria', 2019, 1.249)
# (104, 'Austria', 2020, 1.25099999999999)
# (105, 'Azerbaijan', 2008, 2.28299999999999)
# (106, 'Azerbaijan', 2009, 2.31999999999999)
# (107, 'Azerbaijan', 2010, 2.342)
# (108, 'Azerbaijan', 2011, 2.34799999999999)
# (109, 'Azerbaijan', 2012, 2.36799999999999)
# (110, 'Azerbaijan', 2013, 2.456)
# (111, 'Azerbaijan', 2014, 2.38899999999999)
# (112, 'Azerbaijan', 2015, 2.394)
# (113, 'Azerbaijan', 2016, 2.38)
# (114, 'Azerbaijan', 2017, 2.434)
# (115, 'Azerbaijan', 2018, 2.41299999999999)
# (116, 'Azerbaijan', 2019, 2.37599999999999)
# (117, 'Azerbaijan', 2020, 2.144)
# (118, 'Bahrain', 2008, 1.869)
# (119, 'Bahrain', 2009, 1.868)
# (120, 'Bahrain', 2010, 1.812)
# (121, 'Bahrain', 2011, 2.14699999999999)
# (122, 'Bahrain', 2012, 2.068)
# (123, 'Bahrain', 2013, 2.152)
# (124, 'Bahrain', 2014, 2.206)
# (125, 'Bahrain', 2015, 2.11399999999999)
# (126, 'Bahrain', 2016, 2.19099999999999)
# (127, 'Bahrain', 2017, 2.29099999999999)
# (128, 'Bahrain', 2018, 2.27199999999999)
# (129, 'Bahrain', 2019, 2.19099999999999)
# (130, 'Bahrain', 2020, 2.103)
# (131, 'Bangladesh', 2008, 2.039)
# (132, 'Bangladesh', 2009, 2.028)
# (133, 'Bangladesh', 2010, 2.11)
# (134, 'Bangladesh', 2011, 2.13399999999999)
# (135, 'Bangladesh', 2012, 2.15799999999999)
# (136, 'Bangladesh', 2013, 2.09399999999999)
# (137, 'Bangladesh', 2014, 2.012)
# (138, 'Bangladesh', 2015, 1.998)
# (139, 'Bangladesh', 2016, 2.00599999999999)
# (140, 'Bangladesh', 2017, 1.969)
# (141, 'Bangladesh', 2018, 2.02199999999999)
# (142, 'Bangladesh', 2019, 2.109)
# (143, 'Bangladesh', 2020, 2.091)
# (144, 'Belarus', 2008, 2.12699999999999)
# (145, 'Belarus', 2009, 2.137)
# (146, 'Belarus', 2010, 2.144)
# (147, 'Belarus', 2011, 2.128)
# (148, 'Belarus', 2012, 2.12199999999999)
# (149, 'Belarus', 2013, 2.109)
# (150, 'Belarus', 2014, 2.08)
# (151, 'Belarus', 2015, 2.12699999999999)
# (152, 'Belarus', 2016, 2.05699999999999)
# (153, 'Belarus', 2017, 1.991)
# (154, 'Belarus', 2018, 2.019)
# (155, 'Belarus', 2019, 2.04199999999999)
# (156, 'Belarus', 2020, 2.04199999999999)
# (157, 'Belgium', 2008, 1.468)
# (158, 'Belgium', 2009, 1.479)
# (159, 'Belgium', 2010, 1.489)
# (160, 'Belgium', 2011, 1.476)
# (161, 'Belgium', 2012, 1.476)
# (162, 'Belgium', 2013, 1.437)
# (163, 'Belgium', 2014, 1.401)
# (164, 'Belgium', 2015, 1.39199999999999)
# (165, 'Belgium', 2016, 1.38599999999999)
# (166, 'Belgium', 2017, 1.456)
# (167, 'Belgium', 2018, 1.53)
# (168, 'Belgium', 2019, 1.526)
# (169, 'Belgium', 2020, 1.50899999999999)
# (170, 'Benin', 2008, 2.093)
# (171, 'Benin', 2009, 2.092)
# (172, 'Benin', 2010, 2.093)
# (173, 'Benin', 2011, 2.15099999999999)
# (174, 'Benin', 2012, 2.097)
# (175, 'Benin', 2013, 2.023)
# (176, 'Benin', 2014, 2.0)
# (177, 'Benin', 2015, 1.88599999999999)
# (178, 'Benin', 2016, 1.93199999999999)
# (179, 'Benin', 2017, 1.989)
# (180, 'Benin', 2018, 1.899)
# (181, 'Benin', 2019, 1.911)
# (182, 'Benin', 2020, 2.17799999999999)
# (183, 'Bhutan', 2008, 1.883)
# (184, 'Bhutan', 2009, 1.89199999999999)
# (185, 'Bhutan', 2010, 1.947)
# (186, 'Bhutan', 2011, 1.91599999999999)
# (187, 'Bhutan', 2012, 1.75299999999999)
# (188, 'Bhutan', 2013, 1.68199999999999)
# (189, 'Bhutan', 2014, 1.65399999999999)
# (190, 'Bhutan', 2015, 1.627)
# (191, 'Bhutan', 2016, 1.55499999999999)
# (192, 'Bhutan', 2017, 1.58)
# (193, 'Bhutan', 2018, 1.494)
# (194, 'Bhutan', 2019, 1.473)
# (195, 'Bhutan', 2020, 1.489)
# (196, 'Bolivia', 2008, 1.931)
# (197, 'Bolivia', 2009, 2.012)
# (198, 'Bolivia', 2010, 2.039)
# (199, 'Bolivia', 2011, 1.974)
# (200, 'Bolivia', 2012, 2.03699999999999)
# (201, 'Bolivia', 2013, 2.055)
# (202, 'Bolivia', 2014, 2.015)
# (203, 'Bolivia', 2015, 2.02)
# (204, 'Bolivia', 2016, 1.923)
# (205, 'Bolivia', 2017, 1.958)
# (206, 'Bolivia', 2018, 1.969)
# (207, 'Bolivia', 2019, 1.975)
# (208, 'Bolivia', 2020, 2.01699999999999)
# (209, 'Bosnia and Herzegovina', 2008, 1.736)
# (210, 'Bosnia and Herzegovina', 2009, 1.78299999999999)
# (211, 'Bosnia and Herzegovina', 2010, 1.792)
# (212, 'Bosnia and Herzegovina', 2011, 1.778)
# (213, 'Bosnia and Herzegovina', 2012, 1.81)
# (214, 'Bosnia and Herzegovina', 2013, 1.77299999999999)
# (215, 'Bosnia and Herzegovina', 2014, 1.721)
# (216, 'Bosnia and Herzegovina', 2015, 1.78099999999999)
# (217, 'Bosnia and Herzegovina', 2016, 1.76299999999999)
# (218, 'Bosnia and Herzegovina', 2017, 1.874)
# (219, 'Bosnia and Herzegovina', 2018, 1.903)
# (220, 'Bosnia and Herzegovina', 2019, 1.871)
# (221, 'Bosnia and Herzegovina', 2020, 1.899)
# (222, 'Botswana', 2008, 1.833)
# (223, 'Botswana', 2009, 1.788)
# (224, 'Botswana', 2010, 1.766)
# (225, 'Botswana', 2011, 1.806)
# (226, 'Botswana', 2012, 1.782)
# (227, 'Botswana', 2013, 1.749)
# (228, 'Botswana', 2014, 1.869)
# (229, 'Botswana', 2015, 1.75299999999999)
# (230, 'Botswana', 2016, 1.716)
# (231, 'Botswana', 2017, 1.73)
# (232, 'Botswana', 2018, 1.77499999999999)
# (233, 'Botswana', 2019, 1.79099999999999)
# (234, 'Botswana', 2020, 1.812)
# (235, 'Brazil', 2008, 2.02199999999999)
# (236, 'Brazil', 2009, 2.02899999999999)
# (237, 'Brazil', 2010, 2.02999999999999)
# (238, 'Brazil', 2011, 2.019)
# (239, 'Brazil', 2012, 2.052)
# (240, 'Brazil', 2013, 2.03799999999999)
# (241, 'Brazil', 2014, 2.075)
# (242, 'Brazil', 2015, 2.156)
# (243, 'Brazil', 2016, 2.15799999999999)
# (244, 'Brazil', 2017, 2.23499999999999)
# (245, 'Brazil', 2018, 2.213)
# (246, 'Brazil', 2019, 2.37)
# (247, 'Brazil', 2020, 2.41199999999999)
# (248, 'Bulgaria', 2008, 1.667)
# (249, 'Bulgaria', 2009, 1.691)
# (250, 'Bulgaria', 2010, 1.66799999999999)
# (251, 'Bulgaria', 2011, 1.609)
# (252, 'Bulgaria', 2012, 1.64399999999999)
# (253, 'Bulgaria', 2013, 1.67399999999999)
# (254, 'Bulgaria', 2014, 1.575)
# (255, 'Bulgaria', 2015, 1.643)
# (256, 'Bulgaria', 2016, 1.597)
# (257, 'Bulgaria', 2017, 1.589)
# (258, 'Bulgaria', 2018, 1.58)
# (259, 'Bulgaria', 2019, 1.585)
# (260, 'Bulgaria', 2020, 1.612)
# (261, 'Burkina Faso', 2008, 1.858)
# (262, 'Burkina Faso', 2009, 1.774)
# (263, 'Burkina Faso', 2010, 1.712)
# (264, 'Burkina Faso', 2011, 1.735)
# (265, 'Burkina Faso', 2012, 1.68599999999999)
# (266, 'Burkina Faso', 2013, 1.82)
# (267, 'Burkina Faso', 2014, 1.723)
# (268, 'Burkina Faso', 2015, 1.856)
# (269, 'Burkina Faso', 2016, 2.01299999999999)
# (270, 'Burkina Faso', 2017, 2.02099999999999)
# (271, 'Burkina Faso', 2018, 2.04099999999999)
# (272, 'Burkina Faso', 2019, 2.153)
# (273, 'Burkina Faso', 2020, 2.241)
# (274, 'Burundi', 2008, 2.43699999999999)
# (275, 'Burundi', 2009, 2.411)
# (276, 'Burundi', 2010, 2.456)
# (277, 'Burundi', 2011, 2.341)
# (278, 'Burundi', 2012, 2.29)
# (279, 'Burundi', 2013, 2.302)
# (280, 'Burundi', 2014, 2.241)
# (281, 'Burundi', 2015, 2.313)
# (282, 'Burundi', 2016, 2.52899999999999)
# (283, 'Burundi', 2017, 2.531)
# (284, 'Burundi', 2018, 2.48099999999999)
# (285, 'Burundi', 2019, 2.476)
# (286, 'Burundi', 2020, 2.418)
# (287, 'Cambodia', 2008, 1.994)
# (288, 'Cambodia', 2009, 2.105)
# (289, 'Cambodia', 2010, 2.121)
# (290, 'Cambodia', 2011, 2.099)
# (291, 'Cambodia', 2012, 2.15499999999999)
# (292, 'Cambodia', 2013, 2.137)
# (293, 'Cambodia', 2014, 2.121)
# (294, 'Cambodia', 2015, 2.04)
# (295, 'Cambodia', 2016, 2.00499999999999)
# (296, 'Cambodia', 2017, 1.91599999999999)
# (297, 'Cambodia', 2018, 2.003)
# (298, 'Cambodia', 2019, 1.92799999999999)
# (299, 'Cambodia', 2020, 1.889)
# (300, 'Cameroon', 2008, 1.97)
# (301, 'Cameroon', 2009, 2.00899999999999)
# (302, 'Cameroon', 2010, 2.101)
# (303, 'Cameroon', 2011, 1.986)
# (304, 'Cameroon', 2012, 2.01699999999999)
# (305, 'Cameroon', 2013, 1.921)
# (306, 'Cameroon', 2014, 1.999)
# (307, 'Cameroon', 2015, 2.204)
# (308, 'Cameroon', 2016, 2.359)
# (309, 'Cameroon', 2017, 2.455)
# (310, 'Cameroon', 2018, 2.55399999999999)
# (311, 'Cameroon', 2019, 2.572)
# (312, 'Cameroon', 2020, 2.645)
# (313, 'Canada', 2008, 1.409)
# (314, 'Canada', 2009, 1.437)
# (315, 'Canada', 2010, 1.499)
# (316, 'Canada', 2011, 1.44)
# (317, 'Canada', 2012, 1.41399999999999)
# (318, 'Canada', 2013, 1.30099999999999)
# (319, 'Canada', 2014, 1.28299999999999)
# (320, 'Canada', 2015, 1.31)
# (321, 'Canada', 2016, 1.308)
# (322, 'Canada', 2017, 1.314)
# (323, 'Canada', 2018, 1.316)
# (324, 'Canada', 2019, 1.319)
# (325, 'Canada', 2020, 1.333)
# (326, 'Central African Republic', 2008, 2.81)
# (327, 'Central African Republic', 2009, 2.70299999999999)
# (328, 'Central African Republic', 2010, 2.611)
# (329, 'Central African Republic', 2011, 2.67899999999999)
# (330, 'Central African Republic', 2012, 2.78)
# (331, 'Central African Republic', 2013, 2.998)
# (332, 'Central African Republic', 2014, 3.144)
# (333, 'Central African Republic', 2015, 3.24)
# (334, 'Central African Republic', 2016, 3.21499999999999)
# (335, 'Central African Republic', 2017, 3.16599999999999)
# (336, 'Central African Republic', 2018, 3.164)
# (337, 'Central African Republic', 2019, 3.16299999999999)
# (338, 'Central African Republic', 2020, 3.072)
# (339, 'Chad', 2008, 2.785)
# (340, 'Chad', 2009, 2.843)
# (341, 'Chad', 2010, 2.90799999999999)
# (342, 'Chad', 2011, 2.668)
# (343, 'Chad', 2012, 2.612)
# (344, 'Chad', 2013, 2.361)
# (345, 'Chad', 2014, 2.438)
# (346, 'Chad', 2015, 2.454)
# (347, 'Chad', 2016, 2.414)
# (348, 'Chad', 2017, 2.523)
# (349, 'Chad', 2018, 2.44099999999999)
# (350, 'Chad', 2019, 2.499)
# (351, 'Chad', 2020, 2.54899999999999)
# (352, 'Chile', 2008, 1.691)
# (353, 'Chile', 2009, 1.68799999999999)
# (354, 'Chile', 2010, 1.721)
# (355, 'Chile', 2011, 1.748)
# (356, 'Chile', 2012, 1.641)
# (357, 'Chile', 2013, 1.62599999999999)
# (358, 'Chile', 2014, 1.59)
# (359, 'Chile', 2015, 1.612)
# (360, 'Chile', 2016, 1.582)
# (361, 'Chile', 2017, 1.583)
# (362, 'Chile', 2018, 1.62799999999999)
# (363, 'Chile', 2019, 1.65199999999999)
# (364, 'Chile', 2020, 1.828)
# (365, 'China', 2008, 2.169)
# (366, 'China', 2009, 2.09399999999999)
# (367, 'China', 2010, 2.176)
# (368, 'China', 2011, 2.185)
# (369, 'China', 2012, 2.17499999999999)
# (370, 'China', 2013, 2.088)
# (371, 'China', 2014, 2.091)
# (372, 'China', 2015, 2.116)
# (373, 'China', 2016, 2.099)
# (374, 'China', 2017, 2.121)
# (375, 'China', 2018, 2.06499999999999)
# (376, 'China', 2019, 2.047)
# (377, 'China', 2020, 2.02599999999999)
# (378, 'Colombia', 2008, 2.797)
# (379, 'Colombia', 2009, 2.72699999999999)
# (380, 'Colombia', 2010, 2.806)
# (381, 'Colombia', 2011, 2.714)
# (382, 'Colombia', 2012, 2.648)
# (383, 'Colombia', 2013, 2.596)
# (384, 'Colombia', 2014, 2.61)
# (385, 'Colombia', 2015, 2.67)
# (386, 'Colombia', 2016, 2.616)
# (387, 'Colombia', 2017, 2.689)
# (388, 'Colombia', 2018, 2.69)
# (389, 'Colombia', 2019, 2.68599999999999)
# (390, 'Colombia', 2020, 2.69099999999999)
# (391, 'Costa Rica', 2008, 1.63199999999999)
# (392, 'Costa Rica', 2009, 1.64599999999999)
# (393, 'Costa Rica', 2010, 1.655)
# (394, 'Costa Rica', 2011, 1.78099999999999)
# (395, 'Costa Rica', 2012, 1.731)
# (396, 'Costa Rica', 2013, 1.78099999999999)
# (397, 'Costa Rica', 2014, 1.75699999999999)
# (398, 'Costa Rica', 2015, 1.698)
# (399, 'Costa Rica', 2016, 1.689)
# (400, 'Costa Rica', 2017, 1.701)
# (401, 'Costa Rica', 2018, 1.748)
# (402, 'Costa Rica', 2019, 1.728)
# (403, 'Costa Rica', 2020, 1.704)
# (404, "Cote d' Ivoire", 2008, 2.38799999999999)
# (405, "Cote d' Ivoire", 2009, 2.26699999999999)
# (406, "Cote d' Ivoire", 2010, 2.16299999999999)
# (407, "Cote d' Ivoire", 2011, 2.366)
# (408, "Cote d' Ivoire", 2012, 2.318)
# (409, "Cote d' Ivoire", 2013, 2.523)
# (410, "Cote d' Ivoire", 2014, 2.37599999999999)
# (411, "Cote d' Ivoire", 2015, 2.189)
# (412, "Cote d' Ivoire", 2016, 2.226)
# (413, "Cote d' Ivoire", 2017, 2.22)
# (414, "Cote d' Ivoire", 2018, 2.221)
# (415, "Cote d' Ivoire", 2019, 2.153)
# (416, "Cote d' Ivoire", 2020, 2.129)
# (417, 'Croatia', 2008, 1.667)
# (418, 'Croatia', 2009, 1.687)
# (419, 'Croatia', 2010, 1.623)
# (420, 'Croatia', 2011, 1.629)
# (421, 'Croatia', 2012, 1.611)
# (422, 'Croatia', 2013, 1.591)
# (423, 'Croatia', 2014, 1.54499999999999)
# (424, 'Croatia', 2015, 1.55699999999999)
# (425, 'Croatia', 2016, 1.55699999999999)
# (426, 'Croatia', 2017, 1.568)
# (427, 'Croatia', 2018, 1.556)
# (428, 'Croatia', 2019, 1.54899999999999)
# (429, 'Croatia', 2020, 1.52899999999999)
# (430, 'Cuba', 2008, 2.023)
# (431, 'Cuba', 2009, 2.01699999999999)
# (432, 'Cuba', 2010, 2.016)
# (433, 'Cuba', 2011, 1.99)
# (434, 'Cuba', 2012, 2.032)
# (435, 'Cuba', 2013, 2.01799999999999)
# (436, 'Cuba', 2014, 1.987)
# (437, 'Cuba', 2015, 1.993)
# (438, 'Cuba', 2016, 1.975)
# (439, 'Cuba', 2017, 1.978)
# (440, 'Cuba', 2018, 1.961)
# (441, 'Cuba', 2019, 1.988)
# (442, 'Cuba', 2020, 2.01699999999999)
# (443, 'Cyprus', 2008, 1.712)
# (444, 'Cyprus', 2009, 1.72)
# (445, 'Cyprus', 2010, 1.90599999999999)
# (446, 'Cyprus', 2011, 1.895)
# (447, 'Cyprus', 2012, 1.923)
# (448, 'Cyprus', 2013, 1.873)
# (449, 'Cyprus', 2014, 1.93)
# (450, 'Cyprus', 2015, 1.89)
# (451, 'Cyprus', 2016, 1.9)
# (452, 'Cyprus', 2017, 1.901)
# (453, 'Cyprus', 2018, 1.848)
# (454, 'Cyprus', 2019, 1.88)
# (455, 'Cyprus', 2020, 1.877)
# (456, 'Czech Republic', 2008, 1.461)
# (457, 'Czech Republic', 2009, 1.445)
# (458, 'Czech Republic', 2010, 1.41599999999999)
# (459, 'Czech Republic', 2011, 1.37799999999999)
# (460, 'Czech Republic', 2012, 1.431)
# (461, 'Czech Republic', 2013, 1.421)
# (462, 'Czech Republic', 2014, 1.38)
# (463, 'Czech Republic', 2015, 1.39199999999999)
# (464, 'Czech Republic', 2016, 1.335)
# (465, 'Czech Republic', 2017, 1.32)
# (466, 'Czech Republic', 2018, 1.337)
# (467, 'Czech Republic', 2019, 1.335)
# (468, 'Czech Republic', 2020, 1.341)
# (469, 'Democratic Republic of the Congo', 2008, 2.825)
# (470, 'Democratic Republic of the Congo', 2009, 2.85199999999999)
# (471, 'Democratic Republic of the Congo', 2010, 2.87599999999999)
# (472, 'Democratic Republic of the Congo', 2011, 2.88399999999999)
# (473, 'Democratic Republic of the Congo', 2012, 2.934)
# (474, 'Democratic Republic of the Congo', 2013, 2.862)
# (475, 'Democratic Republic of the Congo', 2014, 3.00499999999999)
# (476, 'Democratic Republic of the Congo', 2015, 3.068)
# (477, 'Democratic Republic of the Congo', 2016, 3.00099999999999)
# (478, 'Democratic Republic of the Congo', 2017, 2.963)
# (479, 'Democratic Republic of the Congo', 2018, 3.109)
# (480, 'Democratic Republic of the Congo', 2019, 3.111)
# (481, 'Democratic Republic of the Congo', 2020, 3.109)
# (482, 'Denmark', 2008, 1.286)
# (483, 'Denmark', 2009, 1.28499999999999)
# (484, 'Denmark', 2010, 1.352)
# (485, 'Denmark', 2011, 1.304)
# (486, 'Denmark', 2012, 1.258)
# (487, 'Denmark', 2013, 1.219)
# (488, 'Denmark', 2014, 1.198)
# (489, 'Denmark', 2015, 1.219)
# (490, 'Denmark', 2016, 1.209)
# (491, 'Denmark', 2017, 1.31)
# (492, 'Denmark', 2018, 1.302)
# (493, 'Denmark', 2019, 1.288)
# (494, 'Denmark', 2020, 1.306)
# (495, 'Djibouti', 2008, 1.966)
# (496, 'Djibouti', 2009, 1.954)
# (497, 'Djibouti', 2010, 2.00899999999999)
# (498, 'Djibouti', 2011, 2.1)
# (499, 'Djibouti', 2012, 1.917)
# (500, 'Djibouti', 2013, 1.968)
# (501, 'Djibouti', 2014, 1.94199999999999)
# (502, 'Djibouti', 2015, 2.08199999999999)
# (503, 'Djibouti', 2016, 2.153)
# (504, 'Djibouti', 2017, 2.111)
# (505, 'Djibouti', 2018, 2.172)
# (506, 'Djibouti', 2019, 2.103)
# (507, 'Djibouti', 2020, 2.145)
# (508, 'Dominican Republic', 2008, 1.989)
# (509, 'Dominican Republic', 2009, 1.999)
# (510, 'Dominican Republic', 2010, 2.075)
# (511, 'Dominican Republic', 2011, 2.093)
# (512, 'Dominican Republic', 2012, 2.04499999999999)
# (513, 'Dominican Republic', 2013, 2.051)
# (514, 'Dominican Republic', 2014, 2.035)
# (515, 'Dominican Republic', 2015, 2.039)
# (516, 'Dominican Republic', 2016, 2.035)
# (517, 'Dominican Republic', 2017, 2.027)
# (518, 'Dominican Republic', 2018, 2.04099999999999)
# (519, 'Dominican Republic', 2019, 2.019)
# (520, 'Dominican Republic', 2020, 1.96)
# (521, 'Ecuador', 2008, 2.15899999999999)
# (522, 'Ecuador', 2009, 2.189)
# (523, 'Ecuador', 2010, 2.189)
# (524, 'Ecuador', 2011, 2.13799999999999)
# (525, 'Ecuador', 2012, 2.044)
# (526, 'Ecuador', 2013, 2.02099999999999)
# (527, 'Ecuador', 2014, 1.992)
# (528, 'Ecuador', 2015, 1.967)
# (529, 'Ecuador', 2016, 1.958)
# (530, 'Ecuador', 2017, 1.846)
# (531, 'Ecuador', 2018, 1.90799999999999)
# (532, 'Ecuador', 2019, 1.95)
# (533, 'Ecuador', 2020, 2.04099999999999)
# (534, 'Egypt', 2008, 2.04099999999999)
# (535, 'Egypt', 2009, 1.93)
# (536, 'Egypt', 2010, 1.94199999999999)
# (537, 'Egypt', 2011, 2.20299999999999)
# (538, 'Egypt', 2012, 2.302)
# (539, 'Egypt', 2013, 2.382)
# (540, 'Egypt', 2014, 2.52899999999999)
# (541, 'Egypt', 2015, 2.4)
# (542, 'Egypt', 2016, 2.41199999999999)
# (543, 'Egypt', 2017, 2.419)
# (544, 'Egypt', 2018, 2.479)
# (545, 'Egypt', 2019, 2.398)
# (546, 'Egypt', 2020, 2.45)
# (547, 'El Salvador', 2008, 2.016)
# (548, 'El Salvador', 2009, 2.1)
# (549, 'El Salvador', 2010, 2.12699999999999)
# (550, 'El Salvador', 2011, 2.161)
# (551, 'El Salvador', 2012, 2.197)
# (552, 'El Salvador', 2013, 2.129)
# (553, 'El Salvador', 2014, 2.081)
# (554, 'El Salvador', 2015, 2.17399999999999)
# (555, 'El Salvador', 2016, 2.141)
# (556, 'El Salvador', 2017, 2.173)
# (557, 'El Salvador', 2018, 2.197)
# (558, 'El Salvador', 2019, 2.19099999999999)
# (559, 'El Salvador', 2020, 2.177)
# (560, 'Equatorial Guinea', 2008, 1.88399999999999)
# (561, 'Equatorial Guinea', 2009, 1.808)
# (562, 'Equatorial Guinea', 2010, 1.844)
# (563, 'Equatorial Guinea', 2011, 1.925)
# (564, 'Equatorial Guinea', 2012, 1.88199999999999)
# (565, 'Equatorial Guinea', 2013, 1.823)
# (566, 'Equatorial Guinea', 2014, 1.846)
# (567, 'Equatorial Guinea', 2015, 1.812)
# (568, 'Equatorial Guinea', 2016, 1.778)
# (569, 'Equatorial Guinea', 2017, 1.79299999999999)
# (570, 'Equatorial Guinea', 2018, 1.83)
# (571, 'Equatorial Guinea', 2019, 1.843)
# (572, 'Equatorial Guinea', 2020, 1.77499999999999)
# (573, 'Eritrea', 2008, 2.475)
# (574, 'Eritrea', 2009, 2.462)
# (575, 'Eritrea', 2010, 2.447)
# (576, 'Eritrea', 2011, 2.426)
# (577, 'Eritrea', 2012, 2.40499999999999)
# (578, 'Eritrea', 2013, 2.365)
# (579, 'Eritrea', 2014, 2.37199999999999)
# (580, 'Eritrea', 2015, 2.369)
# (581, 'Eritrea', 2016, 2.40799999999999)
# (582, 'Eritrea', 2017, 2.464)
# (583, 'Eritrea', 2018, 2.592)
# (584, 'Eritrea', 2019, 2.55799999999999)
# (585, 'Eritrea', 2020, 2.567)
# (586, 'Estonia', 2008, 1.689)
# (587, 'Estonia', 2009, 1.723)
# (588, 'Estonia', 2010, 1.729)
# (589, 'Estonia', 2011, 1.701)
# (590, 'Estonia', 2012, 1.679)
# (591, 'Estonia', 2013, 1.65799999999999)
# (592, 'Estonia', 2014, 1.55299999999999)
# (593, 'Estonia', 2015, 1.619)
# (594, 'Estonia', 2016, 1.598)
# (595, 'Estonia', 2017, 1.588)
# (596, 'Estonia', 2018, 1.598)
# (597, 'Estonia', 2019, 1.582)
# (598, 'Estonia', 2020, 1.577)
# (599, 'Eswatini', 2008, 1.939)
# (600, 'Eswatini', 2009, 1.92399999999999)
# (601, 'Eswatini', 2010, 1.92599999999999)
# (602, 'Eswatini', 2011, 2.035)
# (603, 'Eswatini', 2012, 2.00599999999999)
# (604, 'Eswatini', 2013, 2.02199999999999)
# (605, 'Eswatini', 2014, 2.055)
# (606, 'Eswatini', 2015, 2.05699999999999)
# (607, 'Eswatini', 2016, 2.01299999999999)
# (608, 'Eswatini', 2017, 1.948)
# (609, 'Eswatini', 2018, 1.971)
# (610, 'Eswatini', 2019, 1.917)
# (611, 'Eswatini', 2020, 1.929)
# (612, 'Ethiopia', 2008, 2.40899999999999)
# (613, 'Ethiopia', 2009, 2.65)
# (614, 'Ethiopia', 2010, 2.41299999999999)
# (615, 'Ethiopia', 2011, 2.43199999999999)
# (616, 'Ethiopia', 2012, 2.587)
# (617, 'Ethiopia', 2013, 2.483)
# (618, 'Ethiopia', 2014, 2.378)
# (619, 'Ethiopia', 2015, 2.29999999999999)
# (620, 'Ethiopia', 2016, 2.285)
# (621, 'Ethiopia', 2017, 2.402)
# (622, 'Ethiopia', 2018, 2.468)
# (623, 'Ethiopia', 2019, 2.46899999999999)
# (624, 'Ethiopia', 2020, 2.507)
# (625, 'Finland', 2008, 1.369)
# (626, 'Finland', 2009, 1.371)
# (627, 'Finland', 2010, 1.369)
# (628, 'Finland', 2011, 1.37)
# (629, 'Finland', 2012, 1.336)
# (630, 'Finland', 2013, 1.331)
# (631, 'Finland', 2014, 1.324)
# (632, 'Finland', 2015, 1.331)
# (633, 'Finland', 2016, 1.348)
# (634, 'Finland', 2017, 1.435)
# (635, 'Finland', 2018, 1.44)
# (636, 'Finland', 2019, 1.40599999999999)
# (637, 'Finland', 2020, 1.365)
# (638, 'France', 2008, 1.76)
# (639, 'France', 2009, 1.78699999999999)
# (640, 'France', 2010, 1.794)
# (641, 'France', 2011, 1.77099999999999)
# (642, 'France', 2012, 1.802)
# (643, 'France', 2013, 1.77299999999999)
# (644, 'France', 2014, 1.712)
# (645, 'France', 2015, 1.703)
# (646, 'France', 2016, 1.744)
# (647, 'France', 2017, 1.871)
# (648, 'France', 2018, 1.899)
# (649, 'France', 2019, 1.861)
# (650, 'France', 2020, 1.91599999999999)
# (651, 'Gabon', 2008, 1.958)
# (652, 'Gabon', 2009, 1.962)
# (653, 'Gabon', 2010, 2.04199999999999)
# (654, 'Gabon', 2011, 2.048)
# (655, 'Gabon', 2012, 2.02599999999999)
# (656, 'Gabon', 2013, 1.988)
# (657, 'Gabon', 2014, 1.931)
# (658, 'Gabon', 2015, 1.976)
# (659, 'Gabon', 2016, 1.986)
# (660, 'Gabon', 2017, 2.007)
# (661, 'Gabon', 2018, 2.052)
# (662, 'Gabon', 2019, 2.069)
# (663, 'Gabon', 2020, 2.096)
# (664, 'Georgia', 2008, 2.65499999999999)
# (665, 'Georgia', 2009, 2.688)
# (666, 'Georgia', 2010, 2.971)
# (667, 'Georgia', 2011, 2.577)
# (668, 'Georgia', 2012, 2.49699999999999)
# (669, 'Georgia', 2013, 2.4)
# (670, 'Georgia', 2014, 2.133)
# (671, 'Georgia', 2015, 2.00499999999999)
# (672, 'Georgia', 2016, 1.992)
# (673, 'Georgia', 2017, 1.994)
# (674, 'Georgia', 2018, 1.986)
# (675, 'Georgia', 2019, 1.992)
# (676, 'Georgia', 2020, 1.982)
# (677, 'Germany', 2008, 1.564)
# (678, 'Germany', 2009, 1.589)
# (679, 'Germany', 2010, 1.61)
# (680, 'Germany', 2011, 1.61)
# (681, 'Germany', 2012, 1.595)
# (682, 'Germany', 2013, 1.518)
# (683, 'Germany', 2014, 1.451)
# (684, 'Germany', 2015, 1.43)
# (685, 'Germany', 2016, 1.43599999999999)
# (686, 'Germany', 2017, 1.465)
# (687, 'Germany', 2018, 1.50899999999999)
# (688, 'Germany', 2019, 1.534)
# (689, 'Germany', 2020, 1.51299999999999)
# (690, 'Ghana', 2008, 1.718)
# (691, 'Ghana', 2009, 1.76699999999999)
# (692, 'Ghana', 2010, 1.832)
# (693, 'Ghana', 2011, 1.80499999999999)
# (694, 'Ghana', 2012, 1.75)
# (695, 'Ghana', 2013, 1.75699999999999)
# (696, 'Ghana', 2014, 1.745)
# (697, 'Ghana', 2015, 1.707)
# (698, 'Ghana', 2016, 1.728)
# (699, 'Ghana', 2017, 1.76)
# (700, 'Ghana', 2018, 1.747)
# (701, 'Ghana', 2019, 1.743)
# (702, 'Ghana', 2020, 1.796)
# (703, 'Greece', 2008, 1.957)
# (704, 'Greece', 2009, 1.948)
# (705, 'Greece', 2010, 1.991)
# (706, 'Greece', 2011, 1.985)
# (707, 'Greece', 2012, 2.02599999999999)
# (708, 'Greece', 2013, 2.02599999999999)
# (709, 'Greece', 2014, 2.01699999999999)
# (710, 'Greece', 2015, 1.9)
# (711, 'Greece', 2016, 1.91)
# (712, 'Greece', 2017, 1.911)
# (713, 'Greece', 2018, 1.93)
# (714, 'Greece', 2019, 1.903)
# (715, 'Greece', 2020, 1.856)
# (716, 'Guatemala', 2008, 2.176)
# (717, 'Guatemala', 2009, 2.099)
# (718, 'Guatemala', 2010, 2.15)
# (719, 'Guatemala', 2011, 2.253)
# (720, 'Guatemala', 2012, 2.20699999999999)
# (721, 'Guatemala', 2013, 2.196)
# (722, 'Guatemala', 2014, 2.14199999999999)
# (723, 'Guatemala', 2015, 2.08)
# (724, 'Guatemala', 2016, 2.15499999999999)
# (725, 'Guatemala', 2017, 2.20699999999999)
# (726, 'Guatemala', 2018, 2.181)
# (727, 'Guatemala', 2019, 2.206)
# (728, 'Guatemala', 2020, 2.17099999999999)
# (729, 'Guinea', 2008, 2.244)
# (730, 'Guinea', 2009, 2.261)
# (731, 'Guinea', 2010, 2.326)
# (732, 'Guinea', 2011, 2.31)
# (733, 'Guinea', 2012, 2.17399999999999)
# (734, 'Guinea', 2013, 2.184)
# (735, 'Guinea', 2014, 2.212)
# (736, 'Guinea', 2015, 2.196)
# (737, 'Guinea', 2016, 2.16599999999999)
# (738, 'Guinea', 2017, 2.056)
# (739, 'Guinea', 2018, 2.072)
# (740, 'Guinea', 2019, 2.02599999999999)
# (741, 'Guinea', 2020, 2.032)
# (742, 'Guinea-Bissau', 2008, 2.34799999999999)
# (743, 'Guinea-Bissau', 2009, 2.342)
# (744, 'Guinea-Bissau', 2010, 2.334)
# (745, 'Guinea-Bissau', 2011, 2.29999999999999)
# (746, 'Guinea-Bissau', 2012, 2.318)
# (747, 'Guinea-Bissau', 2013, 2.269)
# (748, 'Guinea-Bissau', 2014, 2.399)
# (749, 'Guinea-Bissau', 2015, 2.136)
# (750, 'Guinea-Bissau', 2016, 2.13499999999999)
# (751, 'Guinea-Bissau', 2017, 2.177)
# (752, 'Guinea-Bissau', 2018, 2.17799999999999)
# (753, 'Guinea-Bissau', 2019, 2.11)
# (754, 'Guinea-Bissau', 2020, 2.084)
# (755, 'Guyana', 2008, 2.03799999999999)
# (756, 'Guyana', 2009, 2.048)
# (757, 'Guyana', 2010, 2.14699999999999)
# (758, 'Guyana', 2011, 2.12199999999999)
# (759, 'Guyana', 2012, 1.962)
# (760, 'Guyana', 2013, 1.972)
# (761, 'Guyana', 2014, 1.988)
# (762, 'Guyana', 2015, 2.03299999999999)
# (763, 'Guyana', 2016, 2.06)
# (764, 'Guyana', 2017, 1.985)
# (765, 'Guyana', 2018, 2.035)
# (766, 'Guyana', 2019, 2.088)
# (767, 'Guyana', 2020, 2.063)
# (768, 'Haiti', 2008, 2.14)
# (769, 'Haiti', 2009, 2.085)
# (770, 'Haiti', 2010, 2.064)
# (771, 'Haiti', 2011, 2.02999999999999)
# (772, 'Haiti', 2012, 1.976)
# (773, 'Haiti', 2013, 1.923)
# (774, 'Haiti', 2014, 2.081)
# (775, 'Haiti', 2015, 2.04)
# (776, 'Haiti', 2016, 2.007)
# (777, 'Haiti', 2017, 1.95)
# (778, 'Haiti', 2018, 1.97)
# (779, 'Haiti', 2019, 2.044)
# (780, 'Haiti', 2020, 2.128)
# (781, 'Honduras', 2008, 2.17799999999999)
# (782, 'Honduras', 2009, 2.205)
# (783, 'Honduras', 2010, 2.343)
# (784, 'Honduras', 2011, 2.29499999999999)
# (785, 'Honduras', 2012, 2.269)
# (786, 'Honduras', 2013, 2.22)
# (787, 'Honduras', 2014, 2.17799999999999)
# (788, 'Honduras', 2015, 2.137)
# (789, 'Honduras', 2016, 2.2)
# (790, 'Honduras', 2017, 2.149)
# (791, 'Honduras', 2018, 2.2)
# (792, 'Honduras', 2019, 2.26399999999999)
# (793, 'Honduras', 2020, 2.22299999999999)
# (794, 'Hungary', 2008, 1.39799999999999)
# (795, 'Hungary', 2009, 1.50299999999999)
# (796, 'Hungary', 2010, 1.481)
# (797, 'Hungary', 2011, 1.53899999999999)
# (798, 'Hungary', 2012, 1.512)
# (799, 'Hungary', 2013, 1.492)
# (800, 'Hungary', 2014, 1.471)
# (801, 'Hungary', 2015, 1.489)
# (802, 'Hungary', 2016, 1.456)
# (803, 'Hungary', 2017, 1.479)
# (804, 'Hungary', 2018, 1.514)
# (805, 'Hungary', 2019, 1.494)
# (806, 'Hungary', 2020, 1.534)
# (807, 'Iceland', 2008, 1.139)
# (808, 'Iceland', 2009, 1.151)
# (809, 'Iceland', 2010, 1.133)
# (810, 'Iceland', 2011, 1.125)
# (811, 'Iceland', 2012, 1.18199999999999)
# (812, 'Iceland', 2013, 1.181)
# (813, 'Iceland', 2014, 1.175)
# (814, 'Iceland', 2015, 1.153)
# (815, 'Iceland', 2016, 1.15199999999999)
# (816, 'Iceland', 2017, 1.097)
# (817, 'Iceland', 2018, 1.112)
# (818, 'Iceland', 2019, 1.094)
# (819, 'Iceland', 2020, 1.104)
# (820, 'India', 2008, 2.402)
# (821, 'India', 2009, 2.44899999999999)
# (822, 'India', 2010, 2.579)
# (823, 'India', 2011, 2.579)
# (824, 'India', 2012, 2.487)
# (825, 'India', 2013, 2.50099999999999)
# (826, 'India', 2014, 2.49299999999999)
# (827, 'India', 2015, 2.48499999999999)
# (828, 'India', 2016, 2.52)
# (829, 'India', 2017, 2.52599999999999)
# (830, 'India', 2018, 2.499)
# (831, 'India', 2019, 2.611)
# (832, 'India', 2020, 2.616)
# (833, 'Indonesia', 2008, 1.778)
# (834, 'Indonesia', 2009, 1.75)
# (835, 'Indonesia', 2010, 1.723)
# (836, 'Indonesia', 2011, 1.736)
# (837, 'Indonesia', 2012, 1.685)
# (838, 'Indonesia', 2013, 1.69)
# (839, 'Indonesia', 2014, 1.732)
# (840, 'Indonesia', 2015, 1.734)
# (841, 'Indonesia', 2016, 1.747)
# (842, 'Indonesia', 2017, 1.76499999999999)
# (843, 'Indonesia', 2018, 1.746)
# (844, 'Indonesia', 2019, 1.737)
# (845, 'Indonesia', 2020, 1.814)
# (846, 'Iran', 2008, 2.488)
# (847, 'Iran', 2009, 2.38899999999999)
# (848, 'Iran', 2010, 2.46499999999999)
# (849, 'Iran', 2011, 2.544)
# (850, 'Iran', 2012, 2.564)
# (851, 'Iran', 2013, 2.512)
# (852, 'Iran', 2014, 2.452)
# (853, 'Iran', 2015, 2.511)
# (854, 'Iran', 2016, 2.359)
# (855, 'Iran', 2017, 2.371)
# (856, 'Iran', 2018, 2.486)
# (857, 'Iran', 2019, 2.512)
# (858, 'Iran', 2020, 2.705)
# (859, 'Iraq', 2008, 3.51)
# (860, 'Iraq', 2009, 3.46)
# (861, 'Iraq', 2010, 3.42099999999999)
# (862, 'Iraq', 2011, 3.193)
# (863, 'Iraq', 2012, 3.085)
# (864, 'Iraq', 2013, 3.077)
# (865, 'Iraq', 2014, 3.05399999999999)
# (866, 'Iraq', 2015, 3.238)
# (867, 'Iraq', 2016, 3.394)
# (868, 'Iraq', 2017, 3.42099999999999)
# (869, 'Iraq', 2018, 3.31199999999999)
# (870, 'Iraq', 2019, 3.249)
# (871, 'Iraq', 2020, 3.398)
# (872, 'Ireland', 2008, 1.397)
# (873, 'Ireland', 2009, 1.453)
# (874, 'Ireland', 2010, 1.437)
# (875, 'Ireland', 2011, 1.452)
# (876, 'Ireland', 2012, 1.409)
# (877, 'Ireland', 2013, 1.395)
# (878, 'Ireland', 2014, 1.369)
# (879, 'Ireland', 2015, 1.38199999999999)
# (880, 'Ireland', 2016, 1.381)
# (881, 'Ireland', 2017, 1.375)
# (882, 'Ireland', 2018, 1.332)
# (883, 'Ireland', 2019, 1.326)
# (884, 'Ireland', 2020, 1.357)
# (885, 'Israel', 2008, 2.89199999999999)
# (886, 'Israel', 2009, 2.883)
# (887, 'Israel', 2010, 2.886)
# (888, 'Israel', 2011, 2.867)
# (889, 'Israel', 2012, 2.761)
# (890, 'Israel', 2013, 2.713)
# (891, 'Israel', 2014, 2.63)
# (892, 'Israel', 2015, 2.633)
# (893, 'Israel', 2016, 2.741)
# (894, 'Israel', 2017, 2.786)
# (895, 'Israel', 2018, 2.73099999999999)
# (896, 'Israel', 2019, 2.717)
# (897, 'Israel', 2020, 2.753)
# (898, 'Italy', 2008, 1.635)
# (899, 'Italy', 2009, 1.71)
# (900, 'Italy', 2010, 1.722)
# (901, 'Italy', 2011, 1.74)
# (902, 'Italy', 2012, 1.726)
# (903, 'Italy', 2013, 1.716)
# (904, 'Italy', 2014, 1.65799999999999)
# (905, 'Italy', 2015, 1.65799999999999)
# (906, 'Italy', 2016, 1.64399999999999)
# (907, 'Italy', 2017, 1.653)
# (908, 'Italy', 2018, 1.705)
# (909, 'Italy', 2019, 1.677)
# (910, 'Italy', 2020, 1.639)
# (911, 'Jamaica', 2008, 1.981)
# (912, 'Jamaica', 2009, 1.979)
# (913, 'Jamaica', 2010, 1.999)
# (914, 'Jamaica', 2011, 2.03799999999999)
# (915, 'Jamaica', 2012, 2.084)
# (916, 'Jamaica', 2013, 2.036)
# (917, 'Jamaica', 2014, 2.015)
# (918, 'Jamaica', 2015, 1.987)
# (919, 'Jamaica', 2016, 1.964)
# (920, 'Jamaica', 2017, 1.94199999999999)
# (921, 'Jamaica', 2018, 1.954)
# (922, 'Jamaica', 2019, 1.944)
# (923, 'Jamaica', 2020, 1.964)
# (924, 'Japan', 2008, 1.405)
# (925, 'Japan', 2009, 1.40199999999999)
# (926, 'Japan', 2010, 1.397)
# (927, 'Japan', 2011, 1.40199999999999)
# (928, 'Japan', 2012, 1.41599999999999)
# (929, 'Japan', 2013, 1.367)
# (930, 'Japan', 2014, 1.364)
# (931, 'Japan', 2015, 1.365)
# (932, 'Japan', 2016, 1.38)
# (933, 'Japan', 2017, 1.347)
# (934, 'Japan', 2018, 1.352)
# (935, 'Japan', 2019, 1.38)
# (936, 'Japan', 2020, 1.37)
# (937, 'Jordan', 2008, 1.921)
# (938, 'Jordan', 2009, 1.872)
# (939, 'Jordan', 2010, 1.88599999999999)
# (940, 'Jordan', 2011, 1.863)
# (941, 'Jordan', 2012, 1.92399999999999)
# (942, 'Jordan', 2013, 1.911)
# (943, 'Jordan', 2014, 1.859)
# (944, 'Jordan', 2015, 1.939)
# (945, 'Jordan', 2016, 1.93599999999999)
# (946, 'Jordan', 2017, 1.966)
# (947, 'Jordan', 2018, 2.04099999999999)
# (948, 'Jordan', 2019, 1.962)
# (949, 'Jordan', 2020, 1.964)
# (950, 'Kazakhstan', 2008, 2.077)
# (951, 'Kazakhstan', 2009, 2.109)
# (952, 'Kazakhstan', 2010, 2.148)
# (953, 'Kazakhstan', 2011, 2.111)
# (954, 'Kazakhstan', 2012, 2.09399999999999)
# (955, 'Kazakhstan', 2013, 1.962)
# (956, 'Kazakhstan', 2014, 2.007)
# (957, 'Kazakhstan', 2015, 1.979)
# (958, 'Kazakhstan', 2016, 1.957)
# (959, 'Kazakhstan', 2017, 1.948)
# (960, 'Kazakhstan', 2018, 1.939)
# (961, 'Kazakhstan', 2019, 1.911)
# (962, 'Kazakhstan', 2020, 1.978)
# (963, 'Kenya', 2008, 2.42499999999999)
# (964, 'Kenya', 2009, 2.50899999999999)
# (965, 'Kenya', 2010, 2.551)
# (966, 'Kenya', 2011, 2.528)
# (967, 'Kenya', 2012, 2.452)
# (968, 'Kenya', 2013, 2.52)
# (969, 'Kenya', 2014, 2.487)
# (970, 'Kenya', 2015, 2.44099999999999)
# (971, 'Kenya', 2016, 2.439)
# (972, 'Kenya', 2017, 2.426)
# (973, 'Kenya', 2018, 2.40099999999999)
# (974, 'Kenya', 2019, 2.365)
# (975, 'Kenya', 2020, 2.395)
# (976, 'Kosovo', 2008, 1.98)
# (977, 'Kosovo', 2009, 1.978)
# (978, 'Kosovo', 2010, 1.983)
# (979, 'Kosovo', 2011, 1.985)
# (980, 'Kosovo', 2012, 1.953)
# (981, 'Kosovo', 2013, 1.976)
# (982, 'Kosovo', 2014, 1.90799999999999)
# (983, 'Kosovo', 2015, 1.92199999999999)
# (984, 'Kosovo', 2016, 1.93199999999999)
# (985, 'Kosovo', 2017, 1.885)
# (986, 'Kosovo', 2018, 1.943)
# (987, 'Kosovo', 2019, 1.911)
# (988, 'Kosovo', 2020, 1.959)
# (989, 'Kuwait', 2008, 1.603)
# (990, 'Kuwait', 2009, 1.595)
# (991, 'Kuwait', 2010, 1.52499999999999)
# (992, 'Kuwait', 2011, 1.538)
# (993, 'Kuwait', 2012, 1.611)
# (994, 'Kuwait', 2013, 1.614)
# (995, 'Kuwait', 2014, 1.59)
# (996, 'Kuwait', 2015, 1.655)
# (997, 'Kuwait', 2016, 1.702)
# (998, 'Kuwait', 2017, 1.837)
# (999, 'Kuwait', 2018, 1.839)
# (1000, 'Kuwait', 2019, 1.748)
# (1001, 'Kuwait', 2020, 1.685)
# (1002, 'Kyrgyz Republic', 2008, 2.25899999999999)
# (1003, 'Kyrgyz Republic', 2009, 2.253)
# (1004, 'Kyrgyz Republic', 2010, 2.25099999999999)
# (1005, 'Kyrgyz Republic', 2011, 2.25)
# (1006, 'Kyrgyz Republic', 2012, 2.42899999999999)
# (1007, 'Kyrgyz Republic', 2013, 2.387)
# (1008, 'Kyrgyz Republic', 2014, 2.28299999999999)
# (1009, 'Kyrgyz Republic', 2015, 2.184)
# (1010, 'Kyrgyz Republic', 2016, 2.136)
# (1011, 'Kyrgyz Republic', 2017, 2.103)
# (1012, 'Kyrgyz Republic', 2018, 2.088)
# (1013, 'Kyrgyz Republic', 2019, 2.05399999999999)
# (1014, 'Kyrgyz Republic', 2020, 2.04099999999999)
# (1015, 'Laos', 2008, 1.91799999999999)
# (1016, 'Laos', 2009, 1.90799999999999)
# (1017, 'Laos', 2010, 1.746)
# (1018, 'Laos', 2011, 1.768)
# (1019, 'Laos', 2012, 1.78899999999999)
# (1020, 'Laos', 2013, 1.77)
# (1021, 'Laos', 2014, 1.739)
# (1022, 'Laos', 2015, 1.74)
# (1023, 'Laos', 2016, 1.814)
# (1024, 'Laos', 2017, 1.766)
# (1025, 'Laos', 2018, 1.78)
# (1026, 'Laos', 2019, 1.76099999999999)
# (1027, 'Laos', 2020, 1.806)
# (1028, 'Latvia', 2008, 1.595)
# (1029, 'Latvia', 2009, 1.68799999999999)
# (1030, 'Latvia', 2010, 1.66599999999999)
# (1031, 'Latvia', 2011, 1.66)
# (1032, 'Latvia', 2012, 1.65599999999999)
# (1033, 'Latvia', 2013, 1.596)
# (1034, 'Latvia', 2014, 1.556)
# (1035, 'Latvia', 2015, 1.609)
# (1036, 'Latvia', 2016, 1.562)
# (1037, 'Latvia', 2017, 1.55699999999999)
# (1038, 'Latvia', 2018, 1.562)
# (1039, 'Latvia', 2019, 1.599)
# (1040, 'Latvia', 2020, 1.617)
# (1041, 'Lebanon', 2008, 2.62699999999999)
# (1042, 'Lebanon', 2009, 2.56599999999999)
# (1043, 'Lebanon', 2010, 2.573)
# (1044, 'Lebanon', 2011, 2.583)
# (1045, 'Lebanon', 2012, 2.394)
# (1046, 'Lebanon', 2013, 2.41)
# (1047, 'Lebanon', 2014, 2.56099999999999)
# (1048, 'Lebanon', 2015, 2.577)
# (1049, 'Lebanon', 2016, 2.632)
# (1050, 'Lebanon', 2017, 2.716)
# (1051, 'Lebanon', 2018, 2.67799999999999)
# (1052, 'Lebanon', 2019, 2.75599999999999)
# (1053, 'Lebanon', 2020, 2.7)
# (1054, 'Lesotho', 2008, 1.856)
# (1055, 'Lesotho', 2009, 1.857)
# (1056, 'Lesotho', 2010, 1.852)
# (1057, 'Lesotho', 2011, 1.883)
# (1058, 'Lesotho', 2012, 1.858)
# (1059, 'Lesotho', 2013, 1.867)
# (1060, 'Lesotho', 2014, 1.82)
# (1061, 'Lesotho', 2015, 1.87)
# (1062, 'Lesotho', 2016, 1.93799999999999)
# (1063, 'Lesotho', 2017, 2.012)
# (1064, 'Lesotho', 2018, 2.09)
# (1065, 'Lesotho', 2019, 2.144)
# (1066, 'Lesotho', 2020, 2.088)
# (1067, 'Liberia', 2008, 1.957)
# (1068, 'Liberia', 2009, 1.967)
# (1069, 'Liberia', 2010, 2.00499999999999)
# (1070, 'Liberia', 2011, 1.996)
# (1071, 'Liberia', 2012, 1.93599999999999)
# (1072, 'Liberia', 2013, 1.869)
# (1073, 'Liberia', 2014, 1.846)
# (1074, 'Liberia', 2015, 1.92)
# (1075, 'Liberia', 2016, 1.939)
# (1076, 'Liberia', 2017, 1.978)
# (1077, 'Liberia', 2018, 1.89199999999999)
# (1078, 'Liberia', 2019, 1.841)
# (1079, 'Liberia', 2020, 1.864)
# (1080, 'Libya', 2008, 2.08599999999999)
# (1081, 'Libya', 2009, 2.055)
# (1082, 'Libya', 2010, 2.023)
# (1083, 'Libya', 2011, 2.694)
# (1084, 'Libya', 2012, 2.467)
# (1085, 'Libya', 2013, 2.55799999999999)
# (1086, 'Libya', 2014, 2.48099999999999)
# (1087, 'Libya', 2015, 2.86399999999999)
# (1088, 'Libya', 2016, 3.079)
# (1089, 'Libya', 2017, 3.218)
# (1090, 'Libya', 2018, 3.113)
# (1091, 'Libya', 2019, 3.10599999999999)
# (1092, 'Libya', 2020, 3.068)
# (1093, 'Lithuania', 2008, 1.69199999999999)
# (1094, 'Lithuania', 2009, 1.67599999999999)
# (1095, 'Lithuania', 2010, 1.683)
# (1096, 'Lithuania', 2011, 1.77)
# (1097, 'Lithuania', 2012, 1.75699999999999)
# (1098, 'Lithuania', 2013, 1.709)
# (1099, 'Lithuania', 2014, 1.675)
# (1100, 'Lithuania', 2015, 1.691)
# (1101, 'Lithuania', 2016, 1.701)
# (1102, 'Lithuania', 2017, 1.704)
# (1103, 'Lithuania', 2018, 1.687)
# (1104, 'Lithuania', 2019, 1.65)
# (1105, 'Lithuania', 2020, 1.622)
# (1106, 'Madagascar', 2008, 1.772)
# (1107, 'Madagascar', 2009, 2.035)
# (1108, 'Madagascar', 2010, 1.98)
# (1109, 'Madagascar', 2011, 2.164)
# (1110, 'Madagascar', 2012, 2.164)
# (1111, 'Madagascar', 2013, 2.101)
# (1112, 'Madagascar', 2014, 2.05399999999999)
# (1113, 'Madagascar', 2015, 1.99)
# (1114, 'Madagascar', 2016, 1.903)
# (1115, 'Madagascar', 2017, 1.944)
# (1116, 'Madagascar', 2018, 1.891)
# (1117, 'Madagascar', 2019, 1.867)
# (1118, 'Madagascar', 2020, 1.905)
# (1119, 'Malawi', 2008, 1.843)
# (1120, 'Malawi', 2009, 1.838)
# (1121, 'Malawi', 2010, 1.80899999999999)
# (1122, 'Malawi', 2011, 1.71)
# (1123, 'Malawi', 2012, 1.794)
# (1124, 'Malawi', 2013, 1.77)
# (1125, 'Malawi', 2014, 1.78699999999999)
# (1126, 'Malawi', 2015, 1.731)
# (1127, 'Malawi', 2016, 1.864)
# (1128, 'Malawi', 2017, 1.823)
# (1129, 'Malawi', 2018, 1.825)
# (1130, 'Malawi', 2019, 1.78699999999999)
# (1131, 'Malawi', 2020, 1.89799999999999)
# (1132, 'Malaysia', 2008, 1.691)
# (1133, 'Malaysia', 2009, 1.68599999999999)
# (1134, 'Malaysia', 2010, 1.657)
# (1135, 'Malaysia', 2011, 1.575)
# (1136, 'Malaysia', 2012, 1.62599999999999)
# (1137, 'Malaysia', 2013, 1.582)
# (1138, 'Malaysia', 2014, 1.558)
# (1139, 'Malaysia', 2015, 1.61)
# (1140, 'Malaysia', 2016, 1.66799999999999)
# (1141, 'Malaysia', 2017, 1.679)
# (1142, 'Malaysia', 2018, 1.629)
# (1143, 'Malaysia', 2019, 1.589)
# (1144, 'Malaysia', 2020, 1.54499999999999)
# (1145, 'Mali', 2008, 2.216)
# (1146, 'Mali', 2009, 2.232)
# (1147, 'Mali', 2010, 2.313)
# (1148, 'Mali', 2011, 2.30299999999999)
# (1149, 'Mali', 2012, 2.313)
# (1150, 'Mali', 2013, 2.42399999999999)
# (1151, 'Mali', 2014, 2.51399999999999)
# (1152, 'Mali', 2015, 2.589)
# (1153, 'Mali', 2016, 2.52)
# (1154, 'Mali', 2017, 2.648)
# (1155, 'Mali', 2018, 2.63)
# (1156, 'Mali', 2019, 2.685)
# (1157, 'Mali', 2020, 2.7)
# (1158, 'Mauritania', 2008, 2.278)
# (1159, 'Mauritania', 2009, 2.351)
# (1160, 'Mauritania', 2010, 2.24299999999999)
# (1161, 'Mauritania', 2011, 2.29999999999999)
# (1162, 'Mauritania', 2012, 2.29599999999999)
# (1163, 'Mauritania', 2013, 2.23099999999999)
# (1164, 'Mauritania', 2014, 2.24299999999999)
# (1165, 'Mauritania', 2015, 2.20299999999999)
# (1166, 'Mauritania', 2016, 2.16)
# (1167, 'Mauritania', 2017, 2.241)
# (1168, 'Mauritania', 2018, 2.22299999999999)
# (1169, 'Mauritania', 2019, 2.214)
# (1170, 'Mauritania', 2020, 2.184)
# (1171, 'Mauritius', 2008, 1.605)
# (1172, 'Mauritius', 2009, 1.62)
# (1173, 'Mauritius', 2010, 1.614)
# (1174, 'Mauritius', 2011, 1.619)
# (1175, 'Mauritius', 2012, 1.601)
# (1176, 'Mauritius', 2013, 1.522)
# (1177, 'Mauritius', 2014, 1.51699999999999)
# (1178, 'Mauritius', 2015, 1.522)
# (1179, 'Mauritius', 2016, 1.542)
# (1180, 'Mauritius', 2017, 1.534)
# (1181, 'Mauritius', 2018, 1.53299999999999)
# (1182, 'Mauritius', 2019, 1.554)
# (1183, 'Mauritius', 2020, 1.54)
# (1184, 'Mexico', 2008, 2.25099999999999)
# (1185, 'Mexico', 2009, 2.323)
# (1186, 'Mexico', 2010, 2.33599999999999)
# (1187, 'Mexico', 2011, 2.40399999999999)
# (1188, 'Mexico', 2012, 2.51799999999999)
# (1189, 'Mexico', 2013, 2.47299999999999)
# (1190, 'Mexico', 2014, 2.41599999999999)
# (1191, 'Mexico', 2015, 2.398)
# (1192, 'Mexico', 2016, 2.41599999999999)
# (1193, 'Mexico', 2017, 2.50999999999999)
# (1194, 'Mexico', 2018, 2.536)
# (1195, 'Mexico', 2019, 2.53299999999999)
# (1196, 'Mexico', 2020, 2.575)
# (1197, 'Moldova', 2008, 1.966)
# (1198, 'Moldova', 2009, 1.949)
# (1199, 'Moldova', 2010, 1.981)
# (1200, 'Moldova', 2011, 1.981)
# (1201, 'Moldova', 2012, 1.966)
# (1202, 'Moldova', 2013, 1.937)
# (1203, 'Moldova', 2014, 1.923)
# (1204, 'Moldova', 2015, 1.903)
# (1205, 'Moldova', 2016, 1.92199999999999)
# (1206, 'Moldova', 2017, 1.887)
# (1207, 'Moldova', 2018, 1.855)
# (1208, 'Moldova', 2019, 1.869)
# (1209, 'Moldova', 2020, 1.848)
# (1210, 'Mongolia', 2008, 2.015)
# (1211, 'Mongolia', 2009, 1.983)
# (1212, 'Mongolia', 2010, 1.981)
# (1213, 'Mongolia', 2011, 1.814)
# (1214, 'Mongolia', 2012, 1.818)
# (1215, 'Mongolia', 2013, 1.87)
# (1216, 'Mongolia', 2014, 1.725)
# (1217, 'Mongolia', 2015, 1.708)
# (1218, 'Mongolia', 2016, 1.778)
# (1219, 'Mongolia', 2017, 1.75)
# (1220, 'Mongolia', 2018, 1.764)
# (1221, 'Mongolia', 2019, 1.76)
# (1222, 'Mongolia', 2020, 1.745)
# (1223, 'Montenegro', 2008, 2.071)
# (1224, 'Montenegro', 2009, 2.02099999999999)
# (1225, 'Montenegro', 2010, 1.994)
# (1226, 'Montenegro', 2011, 1.996)
# (1227, 'Montenegro', 2012, 1.949)
# (1228, 'Montenegro', 2013, 1.77099999999999)
# (1229, 'Montenegro', 2014, 1.79299999999999)
# (1230, 'Montenegro', 2015, 1.80099999999999)
# (1231, 'Montenegro', 2016, 1.745)
# (1232, 'Montenegro', 2017, 1.792)
# (1233, 'Montenegro', 2018, 1.742)
# (1234, 'Montenegro', 2019, 1.81099999999999)
# (1235, 'Montenegro', 2020, 1.806)
# (1236, 'Morocco', 2008, 2.00199999999999)
# (1237, 'Morocco', 2009, 1.988)
# (1238, 'Morocco', 2010, 1.976)
# (1239, 'Morocco', 2011, 2.044)
# (1240, 'Morocco', 2012, 2.071)
# (1241, 'Morocco', 2013, 2.03399999999999)
# (1242, 'Morocco', 2014, 2.04999999999999)
# (1243, 'Morocco', 2015, 2.05699999999999)
# (1244, 'Morocco', 2016, 2.04999999999999)
# (1245, 'Morocco', 2017, 1.93199999999999)
# (1246, 'Morocco', 2018, 1.933)
# (1247, 'Morocco', 2019, 2.03699999999999)
# (1248, 'Morocco', 2020, 2.04499999999999)
# (1249, 'Mozambique', 2008, 1.87)
# (1250, 'Mozambique', 2009, 1.853)
# (1251, 'Mozambique', 2010, 1.843)
# (1252, 'Mozambique', 2011, 1.969)
# (1253, 'Mozambique', 2012, 1.845)
# (1254, 'Mozambique', 2013, 1.891)
# (1255, 'Mozambique', 2014, 1.972)
# (1256, 'Mozambique', 2015, 1.976)
# (1257, 'Mozambique', 2016, 1.977)
# (1258, 'Mozambique', 2017, 2.06)
# (1259, 'Mozambique', 2018, 2.121)
# (1260, 'Mozambique', 2019, 2.14)
# (1261, 'Mozambique', 2020, 2.132)
# (1262, 'Myanmar', 2008, 2.494)
# (1263, 'Myanmar', 2009, 2.52099999999999)
# (1264, 'Myanmar', 2010, 2.383)
# (1265, 'Myanmar', 2011, 2.229)
# (1266, 'Myanmar', 2012, 2.248)
# (1267, 'Myanmar', 2013, 2.29499999999999)
# (1268, 'Myanmar', 2014, 2.229)
# (1269, 'Myanmar', 2015, 2.297)
# (1270, 'Myanmar', 2016, 2.12199999999999)
# (1271, 'Myanmar', 2017, 2.096)
# (1272, 'Myanmar', 2018, 2.23899999999999)
# (1273, 'Myanmar', 2019, 2.347)
# (1274, 'Myanmar', 2020, 2.379)
# (1275, 'Namibia', 2008, 2.05799999999999)
# (1276, 'Namibia', 2009, 2.04899999999999)
# (1277, 'Namibia', 2010, 2.04899999999999)
# (1278, 'Namibia', 2011, 1.976)
# (1279, 'Namibia', 2012, 1.927)
# (1280, 'Namibia', 2013, 1.91799999999999)
# (1281, 'Namibia', 2014, 1.87799999999999)
# (1282, 'Namibia', 2015, 1.913)
# (1283, 'Namibia', 2016, 1.869)
# (1284, 'Namibia', 2017, 1.834)
# (1285, 'Namibia', 2018, 1.832)
# (1286, 'Namibia', 2019, 1.919)
# (1287, 'Namibia', 2020, 1.845)
# (1288, 'Nepal', 2008, 2.11399999999999)
# (1289, 'Nepal', 2009, 2.052)
# (1290, 'Nepal', 2010, 2.104)
# (1291, 'Nepal', 2011, 2.13)
# (1292, 'Nepal', 2012, 2.012)
# (1293, 'Nepal', 2013, 2.00599999999999)
# (1294, 'Nepal', 2014, 1.95)
# (1295, 'Nepal', 2015, 1.863)
# (1296, 'Nepal', 2016, 1.965)
# (1297, 'Nepal', 2017, 1.98)
# (1298, 'Nepal', 2018, 1.992)
# (1299, 'Nepal', 2019, 1.959)
# (1300, 'Nepal', 2020, 1.948)
# (1301, 'Netherlands', 2008, 1.53099999999999)
# (1302, 'Netherlands', 2009, 1.546)
# (1303, 'Netherlands', 2010, 1.558)
# (1304, 'Netherlands', 2011, 1.53699999999999)
# (1305, 'Netherlands', 2012, 1.50499999999999)
# (1306, 'Netherlands', 2013, 1.476)
# (1307, 'Netherlands', 2014, 1.469)
# (1308, 'Netherlands', 2015, 1.453)
# (1309, 'Netherlands', 2016, 1.443)
# (1310, 'Netherlands', 2017, 1.451)
# (1311, 'Netherlands', 2018, 1.463)
# (1312, 'Netherlands', 2019, 1.471)
# (1313, 'Netherlands', 2020, 1.528)
# (1314, 'New Zealand', 2008, 1.294)
# (1315, 'New Zealand', 2009, 1.3)
# (1316, 'New Zealand', 2010, 1.312)
# (1317, 'New Zealand', 2011, 1.31099999999999)
# (1318, 'New Zealand', 2012, 1.325)
# (1319, 'New Zealand', 2013, 1.335)
# (1320, 'New Zealand', 2014, 1.318)
# (1321, 'New Zealand', 2015, 1.29099999999999)
# (1322, 'New Zealand', 2016, 1.26899999999999)
# (1323, 'New Zealand', 2017, 1.278)
# (1324, 'New Zealand', 2018, 1.234)
# (1325, 'New Zealand', 2019, 1.28499999999999)
# (1326, 'New Zealand', 2020, 1.27899999999999)
# (1327, 'Nicaragua', 2008, 1.846)
# (1328, 'Nicaragua', 2009, 1.85)
# (1329, 'Nicaragua', 2010, 1.844)
# (1330, 'Nicaragua', 2011, 1.885)
# (1331, 'Nicaragua', 2012, 1.93)
# (1332, 'Nicaragua', 2013, 1.877)
# (1333, 'Nicaragua', 2014, 1.86)
# (1334, 'Nicaragua', 2015, 1.948)
# (1335, 'Nicaragua', 2016, 1.89599999999999)
# (1336, 'Nicaragua', 2017, 1.927)
# (1337, 'Nicaragua', 2018, 1.872)
# (1338, 'Nicaragua', 2019, 2.293)
# (1339, 'Nicaragua', 2020, 2.40499999999999)
# (1340, 'Niger', 2008, 2.01299999999999)
# (1341, 'Niger', 2009, 2.091)
# (1342, 'Niger', 2010, 2.117)
# (1343, 'Niger', 2011, 2.06199999999999)
# (1344, 'Niger', 2012, 2.05699999999999)
# (1345, 'Niger', 2013, 2.00899999999999)
# (1346, 'Niger', 2014, 1.981)
# (1347, 'Niger', 2015, 2.237)
# (1348, 'Niger', 2016, 2.194)
# (1349, 'Niger', 2017, 2.38899999999999)
# (1350, 'Niger', 2018, 2.44)
# (1351, 'Niger', 2019, 2.374)
# (1352, 'Niger', 2020, 2.55799999999999)
# (1353, 'Nigeria', 2008, 2.499)
# (1354, 'Nigeria', 2009, 2.467)
# (1355, 'Nigeria', 2010, 2.459)
# (1356, 'Nigeria', 2011, 2.455)
# (1357, 'Nigeria', 2012, 2.581)
# (1358, 'Nigeria', 2013, 2.60199999999999)
# (1359, 'Nigeria', 2014, 2.71899999999999)
# (1360, 'Nigeria', 2015, 2.76699999999999)
# (1361, 'Nigeria', 2016, 2.78699999999999)
# (1362, 'Nigeria', 2017, 2.75599999999999)
# (1363, 'Nigeria', 2018, 2.754)
# (1364, 'Nigeria', 2019, 2.769)
# (1365, 'Nigeria', 2020, 2.782)
# (1366, 'North Korea', 2008, 2.887)
# (1367, 'North Korea', 2009, 2.886)
# (1368, 'North Korea', 2010, 2.935)
# (1369, 'North Korea', 2011, 2.982)
# (1370, 'North Korea', 2012, 2.92099999999999)
# (1371, 'North Korea', 2013, 2.935)
# (1372, 'North Korea', 2014, 2.946)
# (1373, 'North Korea', 2015, 2.954)
# (1374, 'North Korea', 2016, 2.922)
# (1375, 'North Korea', 2017, 2.946)
# (1376, 'North Korea', 2018, 2.927)
# (1377, 'North Korea', 2019, 2.899)
# (1378, 'North Korea', 2020, 2.97699999999999)
# (1379, 'North Macedonia', 2008, 1.856)
# (1380, 'North Macedonia', 2009, 1.88399999999999)
# (1381, 'North Macedonia', 2010, 1.851)
# (1382, 'North Macedonia', 2011, 1.804)
# (1383, 'North Macedonia', 2012, 1.843)
# (1384, 'North Macedonia', 2013, 1.911)
# (1385, 'North Macedonia', 2014, 1.90399999999999)
# (1386, 'North Macedonia', 2015, 1.891)
# (1387, 'North Macedonia', 2016, 1.989)
# (1388, 'North Macedonia', 2017, 2.01299999999999)
# (1389, 'North Macedonia', 2018, 1.944)
# (1390, 'North Macedonia', 2019, 1.835)
# (1391, 'North Macedonia', 2020, 1.8)
# (1392, 'Norway', 2008, 1.395)
# (1393, 'Norway', 2009, 1.419)
# (1394, 'Norway', 2010, 1.44)
# (1395, 'Norway', 2011, 1.512)
# (1396, 'Norway', 2012, 1.55299999999999)
# (1397, 'Norway', 2013, 1.516)
# (1398, 'Norway', 2014, 1.542)
# ...
# (1683, 'Slovenia', 2013, 1.37599999999999)
# (1684, 'Slovenia', 2014, 1.37)
# (1685, 'Slovenia', 2015, 1.354)
# (1686, 'Slovenia', 2016, 1.321)
# (1687, 'Slovenia', 2017, 1.31299999999999)
# (1688, 'Slovenia', 2018, 1.33)
# (1689, 'Slovenia', 2019, 1.29299999999999)
# (1690, 'Slovenia', 2020, 1.312)
# (1691, 'Somalia', 2008, 3.153)
# (1692, 'Somalia', 2009, 3.237)
# (1693, 'Somalia', 2010, 3.3)
# (1694, 'Somalia', 2011, 3.157)
# (1695, 'Somalia', 2012, 3.228)
# (1696, 'Somalia', 2013, 3.184)
# (1697, 'Somalia', 2014, 3.17099999999999)
# (1698, 'Somalia', 2015, 3.133)
# (1699, 'Somalia', 2016, 3.156)
# (1700, 'Somalia', 2017, 3.103)
# (1701, 'Somalia', 2018, 3.13399999999999)
# (1702, 'Somalia', 2019, 3.05399999999999)
# (1703, 'Somalia', 2020, 3.128)
# (1704, 'South Africa', 2008, 2.221)
# (1705, 'South Africa', 2009, 2.39)
# (1706, 'South Africa', 2010, 2.365)
# (1707, 'South Africa', 2011, 2.341)
# (1708, 'South Africa', 2012, 2.334)
# (1709, 'South Africa', 2013, 2.33)
# (1710, 'South Africa', 2014, 2.33199999999999)
# (1711, 'South Africa', 2015, 2.39)
# (1712, 'South Africa', 2016, 2.29)
# (1713, 'South Africa', 2017, 2.29199999999999)
# (1714, 'South Africa', 2018, 2.302)
# (1715, 'South Africa', 2019, 2.41)
# (1716, 'South Africa', 2020, 2.321)
# (1717, 'South Korea', 2008, 1.756)
# (1718, 'South Korea', 2009, 1.776)
# (1719, 'South Korea', 2010, 1.802)
# (1720, 'South Korea', 2011, 1.879)
# (1721, 'South Korea', 2012, 1.78899999999999)
# (1722, 'South Korea', 2013, 1.762)
# (1723, 'South Korea', 2014, 1.774)
# (1724, 'South Korea', 2015, 1.78899999999999)
# (1725, 'South Korea', 2016, 1.77899999999999)
# (1726, 'South Korea', 2017, 1.79899999999999)
# (1727, 'South Korea', 2018, 1.80499999999999)
# (1728, 'South Korea', 2019, 1.804)
# (1729, 'South Korea', 2020, 1.764)
# (1730, 'South Sudan', 2008, 0.0)
# (1731, 'South Sudan', 2009, 0.0)
# (1732, 'South Sudan', 2010, 0.0)
# (1733, 'South Sudan', 2011, 2.345)
# (1734, 'South Sudan', 2012, 2.31499999999999)
# (1735, 'South Sudan', 2013, 2.567)
# (1736, 'South Sudan', 2014, 3.04899999999999)
# (1737, 'South Sudan', 2015, 3.266)
# (1738, 'South Sudan', 2016, 3.29899999999999)
# (1739, 'South Sudan', 2017, 3.23899999999999)
# (1740, 'South Sudan', 2018, 3.289)
# (1741, 'South Sudan', 2019, 3.28)
# (1742, 'South Sudan', 2020, 3.28699999999999)
# (1743, 'Spain', 2008, 1.65199999999999)
# (1744, 'Spain', 2009, 1.707)
# (1745, 'Spain', 2010, 1.719)
# (1746, 'Spain', 2011, 1.673)
# (1747, 'Spain', 2012, 1.609)
# (1748, 'Spain', 2013, 1.589)
# (1749, 'Spain', 2014, 1.52699999999999)
# (1750, 'Spain', 2015, 1.504)
# (1751, 'Spain', 2016, 1.51299999999999)
# (1752, 'Spain', 2017, 1.487)
# (1753, 'Spain', 2018, 1.619)
# (1754, 'Spain', 2019, 1.691)
# (1755, 'Spain', 2020, 1.673)
# (1756, 'Sri Lanka', 2008, 2.47)
# (1757, 'Sri Lanka', 2009, 2.56)
# (1758, 'Sri Lanka', 2010, 2.689)
# (1759, 'Sri Lanka', 2011, 2.596)
# (1760, 'Sri Lanka', 2012, 2.523)
# (1761, 'Sri Lanka', 2013, 2.213)
# (1762, 'Sri Lanka', 2014, 2.11)
# (1763, 'Sri Lanka', 2015, 2.119)
# (1764, 'Sri Lanka', 2016, 2.00199999999999)
# (1765, 'Sri Lanka', 2017, 1.87)
# (1766, 'Sri Lanka', 2018, 1.899)
# (1767, 'Sri Lanka', 2019, 1.943)
# (1768, 'Sri Lanka', 2020, 1.982)
# (1769, 'Sudan', 2008, 3.02199999999999)
# (1770, 'Sudan', 2009, 3.016)
# (1771, 'Sudan', 2010, 3.04099999999999)
# (1772, 'Sudan', 2011, 3.10199999999999)
# (1773, 'Sudan', 2012, 3.117)
# (1774, 'Sudan', 2013, 3.128)
# (1775, 'Sudan', 2014, 3.18199999999999)
# (1776, 'Sudan', 2015, 3.13)
# (1777, 'Sudan', 2016, 3.096)
# (1778, 'Sudan', 2017, 3.06199999999999)
# (1779, 'Sudan', 2018, 3.03799999999999)
# (1780, 'Sudan', 2019, 2.866)
# (1781, 'Sudan', 2020, 2.94099999999999)
# (1782, 'Sweden', 2008, 1.45)
# (1783, 'Sweden', 2009, 1.441)
# (1784, 'Sweden', 2010, 1.444)
# (1785, 'Sweden', 2011, 1.439)
# (1786, 'Sweden', 2012, 1.43399999999999)
# (1787, 'Sweden', 2013, 1.41599999999999)
# (1788, 'Sweden', 2014, 1.389)
# (1789, 'Sweden', 2015, 1.375)
# (1790, 'Sweden', 2016, 1.42199999999999)
# (1791, 'Sweden', 2017, 1.504)
# (1792, 'Sweden', 2018, 1.482)
# (1793, 'Sweden', 2019, 1.51499999999999)
# (1794, 'Sweden', 2020, 1.508)
# (1795, 'Switzerland', 2008, 1.44)
# (1796, 'Switzerland', 2009, 1.476)
# (1797, 'Switzerland', 2010, 1.469)
# (1798, 'Switzerland', 2011, 1.447)
# (1799, 'Switzerland', 2012, 1.411)
# (1800, 'Switzerland', 2013, 1.39399999999999)
# (1801, 'Switzerland', 2014, 1.37799999999999)
# (1802, 'Switzerland', 2015, 1.364)
# (1803, 'Switzerland', 2016, 1.357)
# (1804, 'Switzerland', 2017, 1.354)
# (1805, 'Switzerland', 2018, 1.397)
# (1806, 'Switzerland', 2019, 1.37)
# (1807, 'Switzerland', 2020, 1.389)
# (1808, 'Syria', 2008, 2.15399999999999)
# (1809, 'Syria', 2009, 2.222)
# (1810, 'Syria', 2010, 2.29199999999999)
# (1811, 'Syria', 2011, 2.305)
# (1812, 'Syria', 2012, 2.63399999999999)
# (1813, 'Syria', 2013, 2.98899999999999)
# (1814, 'Syria', 2014, 3.278)
# (1815, 'Syria', 2015, 3.359)
# (1816, 'Syria', 2016, 3.362)
# (1817, 'Syria', 2017, 3.40499999999999)
# (1818, 'Syria', 2018, 3.38099999999999)
# (1819, 'Syria', 2019, 3.331)
# (1820, 'Syria', 2020, 3.334)
# (1821, 'Taiwan', 2008, 1.79499999999999)
# (1822, 'Taiwan', 2009, 1.852)
# (1823, 'Taiwan', 2010, 1.711)
# (1824, 'Taiwan', 2011, 1.689)
# (1825, 'Taiwan', 2012, 1.617)
# (1826, 'Taiwan', 2013, 1.609)
# (1827, 'Taiwan', 2014, 1.606)
# (1828, 'Taiwan', 2015, 1.729)
# (1829, 'Taiwan', 2016, 1.702)
# (1830, 'Taiwan', 2017, 1.72)
# (1831, 'Taiwan', 2018, 1.732)
# (1832, 'Taiwan', 2019, 1.697)
# (1833, 'Taiwan', 2020, 1.66799999999999)
# (1834, 'Tajikistan', 2008, 2.20299999999999)
# (1835, 'Tajikistan', 2009, 2.209)
# (1836, 'Tajikistan', 2010, 2.177)
# (1837, 'Tajikistan', 2011, 2.18)
# (1838, 'Tajikistan', 2012, 2.177)
# (1839, 'Tajikistan', 2013, 2.244)
# (1840, 'Tajikistan', 2014, 2.261)
# (1841, 'Tajikistan', 2015, 2.12699999999999)
# (1842, 'Tajikistan', 2016, 2.09399999999999)
# (1843, 'Tajikistan', 2017, 2.06999999999999)
# (1844, 'Tajikistan', 2018, 2.077)
# (1845, 'Tajikistan', 2019, 2.168)
# (1846, 'Tajikistan', 2020, 2.153)
# (1847, 'Tanzania', 2008, 1.707)
# (1848, 'Tanzania', 2009, 1.744)
# (1849, 'Tanzania', 2010, 1.778)
# (1850, 'Tanzania', 2011, 1.77099999999999)
# (1851, 'Tanzania', 2012, 1.786)
# (1852, 'Tanzania', 2013, 1.80099999999999)
# (1853, 'Tanzania', 2014, 1.81099999999999)
# (1854, 'Tanzania', 2015, 1.861)
# (1855, 'Tanzania', 2016, 1.856)
# (1856, 'Tanzania', 2017, 1.80899999999999)
# (1857, 'Tanzania', 2018, 1.889)
# (1858, 'Tanzania', 2019, 1.872)
# (1859, 'Tanzania', 2020, 1.854)
# (1860, 'Thailand', 2008, 2.326)
# (1861, 'Thailand', 2009, 2.39599999999999)
# (1862, 'Thailand', 2010, 2.379)
# (1863, 'Thailand', 2011, 2.38399999999999)
# (1864, 'Thailand', 2012, 2.415)
# (1865, 'Thailand', 2013, 2.375)
# (1866, 'Thailand', 2014, 2.378)
# (1867, 'Thailand', 2015, 2.353)
# (1868, 'Thailand', 2016, 2.21)
# (1869, 'Thailand', 2017, 2.224)
# (1870, 'Thailand', 2018, 2.16699999999999)
# (1871, 'Thailand', 2019, 2.18199999999999)
# (1872, 'Thailand', 2020, 2.19)
# (1873, 'The Gambia', 2008, 1.891)
# (1874, 'The Gambia', 2009, 1.869)
# (1875, 'The Gambia', 2010, 1.89199999999999)
# (1876, 'The Gambia', 2011, 1.93599999999999)
# (1877, 'The Gambia', 2012, 2.00899999999999)
# (1878, 'The Gambia', 2013, 2.027)
# (1879, 'The Gambia', 2014, 2.055)
# (1880, 'The Gambia', 2015, 2.083)
# (1881, 'The Gambia', 2016, 2.05799999999999)
# (1882, 'The Gambia', 2017, 2.19499999999999)
# (1883, 'The Gambia', 2018, 1.995)
# (1884, 'The Gambia', 2019, 1.91)
# (1885, 'The Gambia', 2020, 1.925)
# (1886, 'Timor-Leste', 2008, 1.941)
# (1887, 'Timor-Leste', 2009, 1.861)
# (1888, 'Timor-Leste', 2010, 1.848)
# (1889, 'Timor-Leste', 2011, 1.77099999999999)
# (1890, 'Timor-Leste', 2012, 1.738)
# (1891, 'Timor-Leste', 2013, 1.741)
# (1892, 'Timor-Leste', 2014, 1.78499999999999)
# (1893, 'Timor-Leste', 2015, 1.81299999999999)
# (1894, 'Timor-Leste', 2016, 1.78499999999999)
# (1895, 'Timor-Leste', 2017, 1.778)
# (1896, 'Timor-Leste', 2018, 1.80699999999999)
# (1897, 'Timor-Leste', 2019, 1.742)
# (1898, 'Timor-Leste', 2020, 1.8)
# (1899, 'Togo', 2008, 2.00199999999999)
# (1900, 'Togo', 2009, 1.91399999999999)
# (1901, 'Togo', 2010, 1.92199999999999)
# (1902, 'Togo', 2011, 1.937)
# (1903, 'Togo', 2012, 1.915)
# (1904, 'Togo', 2013, 1.883)
# (1905, 'Togo', 2014, 1.92599999999999)
# (1906, 'Togo', 2015, 1.867)
# (1907, 'Togo', 2016, 1.889)
# (1908, 'Togo', 2017, 1.868)
# (1909, 'Togo', 2018, 2.00999999999999)
# (1910, 'Togo', 2019, 2.099)
# (1911, 'Togo', 2020, 2.084)
# (1912, 'Trinidad and Tobago', 2008, 2.08199999999999)
# (1913, 'Trinidad and Tobago', 2009, 2.02099999999999)
# (1914, 'Trinidad and Tobago', 2010, 2.079)
# (1915, 'Trinidad and Tobago', 2011, 2.04999999999999)
# (1916, 'Trinidad and Tobago', 2012, 2.10199999999999)
# (1917, 'Trinidad and Tobago', 2013, 2.01299999999999)
# (1918, 'Trinidad and Tobago', 2014, 2.00999999999999)
# (1919, 'Trinidad and Tobago', 2015, 2.031)
# (1920, 'Trinidad and Tobago', 2016, 1.995)
# (1921, 'Trinidad and Tobago', 2017, 2.01399999999999)
# (1922, 'Trinidad and Tobago', 2018, 2.003)
# (1923, 'Trinidad and Tobago', 2019, 2.059)
# (1924, 'Trinidad and Tobago', 2020, 2.01399999999999)
# (1925, 'Tunisia', 2008, 1.814)
# (1926, 'Tunisia', 2009, 1.81499999999999)
# (1927, 'Tunisia', 2010, 1.75699999999999)
# (1928, 'Tunisia', 2011, 1.901)
# (1929, 'Tunisia', 2012, 2.036)
# (1930, 'Tunisia', 2013, 2.044)
# (1931, 'Tunisia', 2014, 2.03799999999999)
# (1932, 'Tunisia', 2015, 1.944)
# (1933, 'Tunisia', 2016, 1.87799999999999)
# (1934, 'Tunisia', 2017, 1.956)
# (1935, 'Tunisia', 2018, 2.012)
# (1936, 'Tunisia', 2019, 1.975)
# (1937, 'Tunisia', 2020, 1.975)
# (1938, 'Turkey', 2008, 2.45)
# (1939, 'Turkey', 2009, 2.515)
# (1940, 'Turkey', 2010, 2.5)
# (1941, 'Turkey', 2011, 2.435)
# (1942, 'Turkey', 2012, 2.375)
# (1943, 'Turkey', 2013, 2.487)
# (1944, 'Turkey', 2014, 2.44)
# (1945, 'Turkey', 2015, 2.49)
# (1946, 'Turkey', 2016, 2.539)
# (1947, 'Turkey', 2017, 2.67)
# (1948, 'Turkey', 2018, 2.798)
# (1949, 'Turkey', 2019, 2.886)
# (1950, 'Turkey', 2020, 2.919)
# (1951, 'Turkmenistan', 2008, 2.145)
# (1952, 'Turkmenistan', 2009, 2.03699999999999)
# (1953, 'Turkmenistan', 2010, 2.12)
# (1954, 'Turkmenistan', 2011, 2.075)
# (1955, 'Turkmenistan', 2012, 2.13899999999999)
# (1956, 'Turkmenistan', 2013, 2.096)
# (1957, 'Turkmenistan', 2014, 2.063)
# (1958, 'Turkmenistan', 2015, 2.124)
# (1959, 'Turkmenistan', 2016, 2.13899999999999)
# (1960, 'Turkmenistan', 2017, 2.20699999999999)
# (1961, 'Turkmenistan', 2018, 2.214)
# (1962, 'Turkmenistan', 2019, 2.22)
# (1963, 'Turkmenistan', 2020, 2.152)
# (1964, 'Uganda', 2008, 2.54)
# (1965, 'Uganda', 2009, 2.423)
# (1966, 'Uganda', 2010, 2.31099999999999)
# (1967, 'Uganda', 2011, 2.246)
# (1968, 'Uganda', 2012, 2.277)
# (1969, 'Uganda', 2013, 2.196)
# (1970, 'Uganda', 2014, 2.21499999999999)
# (1971, 'Uganda', 2015, 2.16299999999999)
# (1972, 'Uganda', 2016, 2.07799999999999)
# (1973, 'Uganda', 2017, 2.083)
# (1974, 'Uganda', 2018, 2.149)
# (1975, 'Uganda', 2019, 2.193)
# (1976, 'Uganda', 2020, 2.222)
# (1977, 'Ukraine', 2008, 2.095)
# (1978, 'Ukraine', 2009, 2.173)
# (1979, 'Ukraine', 2010, 2.217)
# (1980, 'Ukraine', 2011, 2.13099999999999)
# (1981, 'Ukraine', 2012, 2.071)
# (1982, 'Ukraine', 2013, 2.19099999999999)
# (1983, 'Ukraine', 2014, 2.43299999999999)
# (1984, 'Ukraine', 2015, 2.712)
# (1985, 'Ukraine', 2016, 3.007)
# (1986, 'Ukraine', 2017, 2.999)
# (1987, 'Ukraine', 2018, 2.874)
# (1988, 'Ukraine', 2019, 2.76799999999999)
# (1989, 'Ukraine', 2020, 2.793)
# (1990, 'United Arab Emirates', 2008, 1.699)
# (1991, 'United Arab Emirates', 2009, 1.627)
# (1992, 'United Arab Emirates', 2010, 1.611)
# (1993, 'United Arab Emirates', 2011, 1.577)
# (1994, 'United Arab Emirates', 2012, 1.633)
# (1995, 'United Arab Emirates', 2013, 1.588)
# (1996, 'United Arab Emirates', 2014, 1.624)
# (1997, 'United Arab Emirates', 2015, 1.71)
# (1998, 'United Arab Emirates', 2016, 1.721)
# (1999, 'United Arab Emirates', 2017, 1.81499999999999)
# (2000, 'United Arab Emirates', 2018, 1.774)
# (2001, 'United Arab Emirates', 2019, 1.79699999999999)
# (2002, 'United Arab Emirates', 2020, 1.93)
# (2003, 'United Kingdom', 2008, 1.837)
# (2004, 'United Kingdom', 2009, 1.782)
# (2005, 'United Kingdom', 2010, 1.78299999999999)
# (2006, 'United Kingdom', 2011, 1.78499999999999)
# (2007, 'United Kingdom', 2012, 1.746)
# (2008, 'United Kingdom', 2013, 1.743)
# (2009, 'United Kingdom', 2014, 1.736)
# (2010, 'United Kingdom', 2015, 1.705)
# (2011, 'United Kingdom', 2016, 1.68599999999999)
# (2012, 'United Kingdom', 2017, 1.683)
# (2013, 'United Kingdom', 2018, 1.741)
# (2014, 'United Kingdom', 2019, 1.681)
# (2015, 'United Kingdom', 2020, 1.74)
# (2016, 'United States of America', 2008, 2.236)
# (2017, 'United States of America', 2009, 2.31199999999999)
# (2018, 'United States of America', 2010, 2.286)
# (2019, 'United States of America', 2011, 2.23899999999999)
# (2020, 'United States of America', 2012, 2.229)
# (2021, 'United States of America', 2013, 2.19099999999999)
# (2022, 'United States of America', 2014, 2.172)
# (2023, 'United States of America', 2015, 2.17499999999999)
# (2024, 'United States of America', 2016, 2.13899999999999)
# (2025, 'United States of America', 2017, 2.248)
# (2026, 'United States of America', 2018, 2.29099999999999)
# (2027, 'United States of America', 2019, 2.361)
# (2028, 'United States of America', 2020, 2.35599999999999)
# (2029, 'Uruguay', 2008, 1.689)
# (2030, 'Uruguay', 2009, 1.704)
# (2031, 'Uruguay', 2010, 1.713)
# (2032, 'Uruguay', 2011, 1.618)
# (2033, 'Uruguay', 2012, 1.63599999999999)
# (2034, 'Uruguay', 2013, 1.629)
# (2035, 'Uruguay', 2014, 1.64199999999999)
# (2036, 'Uruguay', 2015, 1.66199999999999)
# (2037, 'Uruguay', 2016, 1.65799999999999)
# (2038, 'Uruguay', 2017, 1.637)
# (2039, 'Uruguay', 2018, 1.713)
# (2040, 'Uruguay', 2019, 1.695)
# (2041, 'Uruguay', 2020, 1.702)
# (2042, 'Uzbekistan', 2008, 2.13099999999999)
# (2043, 'Uzbekistan', 2009, 2.12)
# (2044, 'Uzbekistan', 2010, 2.17799999999999)
# (2045, 'Uzbekistan', 2011, 2.274)
# (2046, 'Uzbekistan', 2012, 2.30399999999999)
# (2047, 'Uzbekistan', 2013, 2.234)
# (2048, 'Uzbekistan', 2014, 2.14199999999999)
# (2049, 'Uzbekistan', 2015, 2.141)
# (2050, 'Uzbekistan', 2016, 2.088)
# (2051, 'Uzbekistan', 2017, 2.03299999999999)
# (2052, 'Uzbekistan', 2018, 2.071)
# (2053, 'Uzbekistan', 2019, 2.056)
# (2054, 'Uzbekistan', 2020, 2.04899999999999)
# (2055, 'Venezuela', 2008, 2.313)
# (2056, 'Venezuela', 2009, 2.359)
# (2057, 'Venezuela', 2010, 2.36399999999999)
# (2058, 'Venezuela', 2011, 2.337)
# (2059, 'Venezuela', 2012, 2.28399999999999)
# (2060, 'Venezuela', 2013, 2.25599999999999)
# (2061, 'Venezuela', 2014, 2.333)
# (2062, 'Venezuela', 2015, 2.448)
# (2063, 'Venezuela', 2016, 2.515)
# (2064, 'Venezuela', 2017, 2.52499999999999)
# (2065, 'Venezuela', 2018, 2.57399999999999)
# (2066, 'Venezuela', 2019, 2.673)
# (2067, 'Venezuela', 2020, 2.84799999999999)
# (2068, 'Vietnam', 2008, 1.832)
# (2069, 'Vietnam', 2009, 1.846)
# (2070, 'Vietnam', 2010, 1.87)
# (2071, 'Vietnam', 2011, 1.86)
# (2072, 'Vietnam', 2012, 1.923)
# (2073, 'Vietnam', 2013, 1.871)
# (2074, 'Vietnam', 2014, 1.832)
# (2075, 'Vietnam', 2015, 1.93199999999999)
# (2076, 'Vietnam', 2016, 1.871)
# (2077, 'Vietnam', 2017, 1.88199999999999)
# (2078, 'Vietnam', 2018, 1.895)
# (2079, 'Vietnam', 2019, 1.895)
# (2080, 'Vietnam', 2020, 1.952)
# (2081, 'Yemen', 2008, 2.407)
# (2082, 'Yemen', 2009, 2.474)
# (2083, 'Yemen', 2010, 2.56199999999999)
# (2084, 'Yemen', 2011, 2.56499999999999)
# (2085, 'Yemen', 2012, 2.609)
# (2086, 'Yemen', 2013, 2.547)
# (2087, 'Yemen', 2014, 2.611)
# (2088, 'Yemen', 2015, 2.738)
# (2089, 'Yemen', 2016, 2.974)
# (2090, 'Yemen', 2017, 3.112)
# (2091, 'Yemen', 2018, 3.10599999999999)
# (2092, 'Yemen', 2019, 3.21099999999999)
# (2093, 'Yemen', 2020, 3.25899999999999)
# (2094, 'Zambia', 2008, 1.843)
# (2095, 'Zambia', 2009, 1.834)
# (2096, 'Zambia', 2010, 1.827)
# (2097, 'Zambia', 2011, 1.73)
# (2098, 'Zambia', 2012, 1.814)
# (2099, 'Zambia', 2013, 1.728)
# (2100, 'Zambia', 2014, 1.81)
# (2101, 'Zambia', 2015, 1.816)
# (2102, 'Zambia', 2016, 1.782)
# (2103, 'Zambia', 2017, 1.77299999999999)
# (2104, 'Zambia', 2018, 1.78699999999999)
# (2105, 'Zambia', 2019, 1.768)
# (2106, 'Zambia', 2020, 1.788)
# (2107, 'Zimbabwe', 2008, 2.37599999999999)
# (2108, 'Zimbabwe', 2009, 2.66)
# (2109, 'Zimbabwe', 2010, 2.732)
# (2110, 'Zimbabwe', 2011, 2.66)
# (2111, 'Zimbabwe', 2012, 2.422)
# (2112, 'Zimbabwe', 2013, 2.395)
# (2113, 'Zimbabwe', 2014, 2.25999999999999)
# (2114, 'Zimbabwe', 2015, 2.16199999999999)
# (2115, 'Zimbabwe', 2016, 2.14599999999999)
# (2116, 'Zimbabwe', 2017, 2.165)
# (2117, 'Zimbabwe', 2018, 2.198)
# (2118, 'Zimbabwe', 2019, 2.31499999999999)
# (2119, 'Zimbabwe', 2020, 2.302)

# %%
'''
cursor.execute("DROP TABLE IF EXISTS peace_normalized") 
con.commit()
#con.close()
'''
#Za brisanje tablice ukoliko je potrebno

# %%
'''
db_path = "SQL1.db"

if os.path.exists(db_path):
    os.remove(db_path)
    print(f"Baza podataka {db_path} je obrisana.")
else:
    print(f"Baza podataka {db_path} nije pronađena.")
'''
#Za brisanje baze podataka ukoliko je potrebno
# Out:
# '\ndb_path = "SQL1.db"\n\nif os.path.exists(db_path):\n    os.remove(db_path)\n    print(f"Baza podataka {db_path} je obrisana.")\nelse:\n    print(f"Baza podataka {db_path} nije pronađena.")\n'

# %%
con.close()

# %% [markdown]
# <br>
#
# ## 3.2. Postavljanje Flask servera
#
# Za razvoj API-ja, odabran je Python Flask framework. Prvo su definirane osnovne funkcionalnosti, a zatim je i postavljen sam Flask server. Na samoj početnoj stranici se korisnicima pruža informacije o dostupnim funkcijama, odnosno definiranim osnovnim rutama koje omogućuju dohvat podataka o indeksu sreće, čimbenicima sreće vezanih za pojedinačnu zemlju, filtriranje prema minimalnim i maksimalnim vrijednostima indeksa sreće, te potencijalno preklapanje između indeksa sreće i indeksa mira.
#
# Nakon postavljanja osnovnih ruta, povezan je server s SQLite bazom podataka. To je omogućeno preko postavljenih funkcija za spajanje na bazu i izvođenje SQL upita za dohvat podataka, koji su pohranjeni u dvije tablice od kojih svaka predstavlja pojedini skup podataka.
#
# Za svaku funkcionalnost koja je trebala biti omogućena kroz API, definirane su odgovarajuće rute. Za početak, dohvat indeksa sreće po godinama za odabranu zemlju koji omogućava ispis popisa godina i odgovarajućih vrijednosti indeksa sreće za određenu zemlju. Zatim dohvat čimbenika koji utječu na sreću. Prilikom unosa imena zemlje, ispisali bi se svi spomenuti čimbenici i njihove vrijednosti po godini. Osim toga, moguće je i filtriranje podataka prema minimalnim i maksimalnim vrijednostima indeksa sreće. Ova funkcionalnost omogućuje korisnicima da filtriraju zemlje prema vrijednostima indeksa sreće, s mogućnosti postavljanja proizvoljnih granica. Za kraj, omogućen je pregled preklapanja između indeksa sreće i indeksa mira, fiksno postavljenim pragovima prihvatljivosti. Konkretno, "gr_sreca" postavlja minimalni indeks sreće, dok "gr_mir" određuje maksimalni indeks mira (niži indeks mira znači veći mir). Kao rezultat se vraća  popis zemalja i godina gdje je indeks sreće veći od gr_sreca, a indeks mira manji od gr_mir      .
#
#
# Nakon implementacije svih potrebnih funkcionalnosti, server je testiran kako bi se provjerilo ispravno funkcioniranje svih ruta i API poziva. Upotrebljeno je par testnih uzoraka kako bi se osiguralo da API pravilno vraća rezultate na temelju korisničkih upita. Server je pokrenut na lokalnoj adresi i portu, omogućujući korisnicima da pristupe API-ju i pretražuju podatke prema svojim potrebama.
#
# Za postavljanje Flask servera koristile su se bilješke s predavanja na kolegiju Programiranje za analizu podataka [7]. Za rad s dohvaćanjem argumenata preko GET metode, također su se koristile bilješke s predavanja, kao i online članak za pomoć u radu s request argumentima [7][11].

# %%
import threading
from flask import Flask, jsonify, request
import sqlite3

app = Flask(__name__)
port = "5005"

def get_connection():
    return sqlite3.connect('SQL1.db')

# Home route
@app.route("/")
def home():
    message = (
        "Dobrodosli u Indeks Srece API! "
        "Dostupne relacije: "
        "/indeks_sreca/country?country_name=Ime "
        "/sreca/cimbenici?country_name=Ime "
        "/indeks_sreca/filter?min_index=vrijednost&max_index=vrijednost "
        "/sreca-mir/preklapanje"
    )
    return jsonify(message)

# iskljucivo indeks srece
@app.route("/indeks_sreca/country", methods=["GET"])
def get_happiness_by_country():
    country_name = request.args.get("country_name")
    if not country_name:
        return jsonify({"ERROR": "Niste dobro unjeli ime zemlje. Format: /happiness/country?country_name=Ime"}), 400

    con = get_connection()
    cursor = con.cursor()
    cursor.execute("""
        SELECT year, life_ladder 
        FROM file 
        WHERE country_name = ? 
        ORDER BY year
    """, (country_name,))
    data = cursor.fetchall()
    con.close()

    return jsonify({"Country": country_name, "Indeks srece po godini": data})

# svi cimbenici srece
@app.route("/sreca/cimbenici", methods=["GET"])
def get_happiness_factors():
    country_name = request.args.get("country_name")
    if not country_name:
        return jsonify({"ERROR": "Niste dobro unjeli ime zemlje. Format: /happiness/factors?country_name=Ime"}), 400

    con = get_connection()
    cursor = con.cursor()
    cursor.execute("""
        SELECT year, log_gdp_per_capita, social_support, healthy_life_expectancy, 
               freedom_to_make_choices, generosity, perceptions_of_corruption, 
               positive_affect, negative_affect
        FROM file 
        WHERE country_name = ? 
        ORDER BY year
    """, (country_name,))
    data = cursor.fetchall()
    con.close()

    return jsonify({"Zemlja": country_name, "Cimbenici srece": data})

# filder baziran na min i max vrijednostima indeksa srece
@app.route("/indeks_sreca/filter", methods=["GET"])
def filter_happiness_index():
    min_index = request.args.get("min_index", type=float)
    max_index = request.args.get("max_index", type=float)

    if min_index is None or max_index is None:
        return jsonify({"ERROR": "Potrebni su i min_index i max_index. Format: /happiness/filter?min_index=vrijednost&max_index=vrijednost"}), 400

    con = get_connection()
    cursor = con.cursor()
    
    cursor.execute("""
        SELECT country_name, year, life_ladder 
        FROM file 
        WHERE life_ladder BETWEEN ? AND ?
        ORDER BY life_ladder DESC
    """, (min_index, max_index))
    data = cursor.fetchall()
    con.close()

    return jsonify({"Rezultati": data})

# ovdje se uvodi drugi set podataka i potencijalno preklapanje
@app.route("/sreca-mir/preklapanje", methods=["GET"])
def preklapanje():
    gr_sreca = request.args.get("gr_sreca", type=float, default=5.0)
    gr_mir = request.args.get("gr_mir", type=float, default=1.5)
    
    con = get_connection()
    cursor = con.cursor()
    
    cursor.execute("""
        SELECT h.country_name, h.year, h.life_ladder, p.peace_index
        FROM file h
        INNER JOIN peace_normalized p
        ON h.country_name = p.country_name AND h.year = p.year
        WHERE h.life_ladder > ? AND p.peace_index < ?
        ORDER BY h.year, h.country_name
    """, (gr_sreca, gr_mir))
    
    data = cursor.fetchall()
    con.close()

    return jsonify({"Uocena preklapanja": data})


# start flask servera
threading.Thread(target=app.run, kwargs={"host": "127.0.0.1", "port": port, "use_reloader": False}).start()

#app.run(host="127.0.0.1", port=port, debug=True)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5005
# Press CTRL+C to quit

# %% [markdown]
# <br>
#
# ## 3.3. Vizualizacija podataka
#
# U sljedećem dijelu projekta nastojit će se obraditi vizualizacija podata, a provest će se putem biblioteka za grafičko prikazivanje podataka Seaborn, odnosno Pyplot. Konkretnije, vizualizacija će se fokusirati na tri osnovna grafa; boxplot, histogram, i heatmap, od kojih svaki ima specifičnu ulogu i svrhu kod analite podataka.
#
# Za početak, objasnit će se pojam boxplot dijagrama. Boxplot dijagram je grafički prikaz raspodjele podataka, gdje je glavna poanta prikazati medijane i kvartile, a također omogućuje i lako prepoznavanje stršila. Dolje obojane kutije označavaju interkvartilni raspon, odnosno podatke između prvog i trećeg kvartila, dok gornji i donji "brkovi" označavaju totalni raspon podataka. Stršila, dosnosno outliers su predstavljeni kao točke van spomenutih brkova. Sam medijan se unutar kutije označava horizontalnom linijom, a predstavlja najučestaliju vrijednost.
#
# U ovom slučaju, prikazivat će se distribucija indeksa sreće kroz godine. S obzirom na to kako su dijagrami poredani jedan za drugim, moguće je lako pratiti promjene kroz vrijeme, kao i moguća stršila.
#
# Za izvedbu svih navedenih dijagrame koristili su se materijali iz laboratorijskih vježbi sa kolegija Uvod u umjetnu inteligenciju [9].

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
sns.boxplot(data=hepi_podaci, x='year', y='Life Ladder')
plt.title('Indeks srece kroz godine')
plt.xlabel('Godine')
plt.ylabel('Indeks srece')
plt.show()

# %% [markdown]
# Vidjlivo je da osim iznimke u prijelazu između 2005. i 2006. godine, indeks sreće ukazuje na jako blagi pozitivan rast, dok su stršila primjetiva tek početkom 2019. godine. Iz ovog prikaza je moguće zaključiti da makar je promjena jako blaga, dolazi do pozitivnog rasta. Osim toga, vrijedi napomenuti da kod većine ispitanih zemalja indeks sreće prelazi vrijednost od 5, što bi impliciralo da se većina stanovništva osjeća relativno zadovoljno.
#
# Kao što je već napomenuto, do 2019. godine nema stršila, što ukazuje na relativnu stabilnost među državama u kontekstu sreće i ekonomskih indikatora. Međutim, s obzirom na to da je pandemija COVID-19 imala globalne posljedice, osobito na zdravlje, ekonomiju i društvene sfere života, moglo bi se pretpostaviti da je iz tog razloga došlo do značajnih padova u ekonomskom stanju nekih država, i da je to razlog zašto je točno te godine došlo do pojave ekstremnih vrijednosti u podacima. Moguće je da su u ekonomskim čimbenicima poput socijalne podrške i BDP-a došle nagle promjene, što bi automatski utjecalo na ispitani indeks sreće.

# %% [markdown]
# Nadalje, prikazat će se potencijalne korelacije među podacima koristeći heatmap; vizualni prikaz matrice podataka, gdje se intenzitet boje koristi za označavanje vrijednosti.
#
# Heatmap će se koristiti za analizu povezanosti između prije navedeni čimbenika: indeks sreće, BDP, društvena podršla, velikodušnost, itd. Cilj je identificirati snažne pozitivne ili negativne korelacije između varijabli koje bi mogle objasniti obrasce u podacima.
#
# Kako bi se iščitali podaci, napomenut će se da tamnije boje predstavljaju jače korelacije (pozitivne ili negativne), tj. korelacija bliska 1 ili -1 ukazuje na snažnu vezu, dok korelacija bliska 0 sugerira slab odnos. Tople nijanse prikazuju pozitivan utjecaj, dok hladnije nijanse ukazuju na negativan učinak.

# %%
hp2 = hepi_podaci.drop(columns=['Country name', 'year'])

plt.figure(figsize=(12, 8))
correlation_matrix = hp2.corr()
sns.heatmap(correlation_matrix, annot=True, fmt='.2f', cmap='coolwarm')
plt.title('Correlation Heatmap of Happiness Factors')
plt.show()

# %% [markdown]
# Iz gore vidljivog prikaza, jasno je vidljiva razlika u čimbenicima koji pozitivno, odnosno negativno međusobno utječu jedni na druge.
#
# S obzirom da je glavna ideja analizirati čimbenike koji utječu na indeks sreće specifično, koristit će se prvi redak za referencu. Uočljivo je da najznačajniji pozitivan utjecaj na indeks sreće imaju BDP, socijalna podrška, i zdravlje, odnosno očekivano trajanje života, koje ovisi o zdravstvenom sustavu i skrb koju država pruža pojedincu. Vrijednost veća od 0.7 ukazuje na relativno značajnu korelaciju, što znači da bi povećanje i jednog od tog kriterija automatski i povećalo sreću pojedinca. Nešto manji utjecaj imaju čimbenici slobode donošenja odluka i pozitivnog učinka, na početku objašnjen kao "iskušenje pozitivnih emocija ispitanika u prethodnom danu", u vrijednosti oko 0.5.
#
# Za sad su navedeni čimbenici koji su pozitivno utjecali na indeks sreće, a sada slijede oni koji negativno utječu na njega. Makar ne toliko značajni kao i prva tri prethodno spomenuta, negativan utjecaj ima percepcija korupcije, mišljenja ispitanika o postojanju korupcije unutar vlade i poslovanja, te negativan učinak, prethodno objašnjen kao "iskušenje negativnih emocija ispitanika u prethodnom danu". Jasno je zašto bi korupcija unutar države negativno utjecala na doživljaj sreće njezinih stanovnika; korumpirani sustavi često onemogućuju zadovoljenje osnovnih potreba, čineći svakodnevni život težim.
#
# U takvim uvjetima, problemi se mogu gomilati i postajati sve veći, s obzirom na to da pojedincima često nedostaju sredstva i mogućnosti za njihovo rješavanje. Makar to ne utjeće znatno na sve države, pogotovo ne kada ima dovoljno sredstava i resursa za svakoga, to se puno više osjeti u siromašnijim državama. Naravno, lakše je kloniti se problema kada od početka pojedinac ima sve zadovoljene uvjete za normalan život, ali kada od početka osoba živi u lošim uvjetima, teško je bez ikakve potpore izvući se van ili uopće naučiti kako postupati bolje.
#
# Osim toga, jedini čimbenik koji gotovo uopće nije utjecao na rezultate ispitivanja je bio čimbenik velikodušnosti, odnosno odgovor na pitanje jesu li pojedinci birali darivati u dobrotvorne svrhe u prethodnih mjesec dana. Ujedno, to je jedini čimbenik koji je imao neočekivani rezultat, a to je da jako blago negativno utječe na percepciju sreće, naspram očekivanja da će imati pozitivan utjecaj.

# %%
cimbenici = ['Life Ladder', 'Social support', 'Log GDP per capita', 'Healthy life expectancy at birth']

plt.figure(figsize=(25, 4))

# Generiranje histograma za svaki čimbenik
for i, cimbenik in enumerate(cimbenici):
    plt.subplot(1,4,i+1)
    sns.histplot(hepi_podaci[cimbenik], bins=25, kde=True)
    plt.title(f'Distribucija: {cimbenik}')
    plt.xlabel(cimbenik)
    plt.ylabel('Ucestalost')

plt.show()

# %% [markdown]
# Sada će se dodatno pregledati distribucije podataka, specifično onih čimbenika koji su pokazali najvišu razinu korelacije s indeksom sreće.
#
# Kao što je vidljivo iz dijagrama, svi su iskrivljeni u lijevo. Dok je prvi histogram koji predstavlja sveukupan indeks sreće više simetričan, i dalje nema uniformnu distribuciju podataka te je blago iskošen. Osim toga, moguće je zaključiti da su svi histogrami unimodalni, s obzirom da imaju samo po jedan vrh. Jedina iznimka mogao bi biti treći histogram koji prikazuje BDP, ali ovisno o tome kako se definira raspon, vrh ili vrhovi mogu postati manje ili više uočljivi. Iz prikazanog nisu vidljiva postojeća stršila. Uglavnom, sva četiri histograma imaju iskošenje u istom smjeru, ali moguće je zaključiti da bi čimbenik BDP-a bio vizualno bliži distribuciji indeksa sreće od preostala dva histograma, koji su više iskošeni u lijevo i manje simetrični.
#
# Specifično za ovaj dijagram, kako bi se prikazali svi histogrami u istom retku, kao izvori su se pobliže koristili materijali s laboratorijskih vježbi iz kolegija Uvod u umjetnu inteligenciju i W3Schools [9][12].

# %% [markdown]
# # 4. Kritički osvrt (praktična izvedivost i primjena)
#
# Sa elementima obrade podataka, razvoja baze, implementacije REST API-ja i vizualizacije, ovaj projekt predstavlja solidnu osnovu za analizu čimbenika koji utječu na indeks sreće, no u svojoj trenutnoj verziji ima određene limitacije.
#
# Obrada podataka je obavljena interpolacijom nedostajućih vrijednosti, što osigurava konzistentnost, no taj pristup ima ograničenja jer se oslanja na pretpostavku linearnosti podataka, što nije uvijek slučaj u stvarnim scenarijima. Nadalje, korištenje SQLite baze podataka funkcionalno je za lokalnu uporabu i razvoj, no zbog njezinih ograničenja u paralelnom pristupu i skalabilnosti, nije optimalan izbor za sustave koji zahtijevaju velike performanse ili rukovanje velikim količinama podataka. U stvarnom poslovnom slučaju, bilo bi potrebno preći na baze poput PostgreSQL-a.
#
# Što se tiće implementacije REST API-ja pomoću Flaska, pružane su osnovne funkcionalnosti za dohvaćanje i filtriranje podataka, i iako je API jednostavan za korištenje i lako se može proširiti, ovdje nedostaju ključne značajke poput autentifikacije korisnika te udovoljavanju većem broju korisnika. U svrhe projekta nije bilo utvrđena potreba za autentifikacijom, ali ta funkcionalnosti mogla bi se nadodati. Također, sigurnost podataka nije postojana, što bi bio problem u produkcijskim okruženjima.
#
# Sljedeća stavka, odnosno vizualizacija podataka pomoću Seaborn i Matplotlib biblioteka omogućila je dublju analizu čimbenika i njihovih odnosa. Iako su korišteni grafovi poput boxplotova, histograma i heatmapova korisni za otkrivanje obrazaca i anomalija, za njihovu interpretaciju potrebno je određeno znanje iz statistike, što može ograničiti njihovu praktičnu primjenu kod šire publike. Interaktivni alati za vizualizaciju bili bi bolji u kontekstu upotrebljivosti rezultata.
#
# Dakle, nedostaci projekta uključuju oslanjanje na statičke podatke, te fokus na lokalnu primjenu i manjak brige oko sigurnosti podataka, što ne bi prolazilo u složenijim distribuiranim sustavima. Iako je projekt dobar prototip, bila bi potrebna značajnija tehnička poboljšanja za profesionalne potrebe.

# %% [markdown]
# # 5. Zaključak
#
# Projekt uspješno prikazuje ključne vještine potrebne za analizu podataka, od obrade i pohrane u bazi, preko izrade REST API-ja, sve do vizualizacije čimbenika povezanih s indeksom sreće. Unatoč svojim ograničenjima, projekt pruža vrijednu osnovu za daljnji razvoj, omogućujući širenje funkcionalnosti i prilagodbu za složenije sustave. Dobiveni rezultati naglašavaju važnost čimbenika poput korupcije, socijalne podrške i ekonomskih uvjeta u oblikovanju percepcije sreće, pružajući korisnicima alate za istraživanje i bolje razumijevanje podataka. S obzirom na mogućnosti proširenja funkcionalnosti, projekt ima potencijal za primjenu u akademskim istraživanjima i razvoju složenijih sustava za analizu podataka.

# %% [markdown]
# # 6. Literatura
#
# [1]	Kaggle. (2024.). *World Happiness Report - 2024*. [Link na pregled članka](https://www.kaggle.com/datasets/jainaru/world-happiness-report-2024-yearly-updated?select=World-happiness-report-updated_2024.csv), pristupljeno 30.12.2024.<br>
# [2] Vision of Huanity (2022.). *Global Peace Index 2022 : overall scores and domains*. [Link za preuzimanje XLSX datoteke](https://www.visionofhumanity.org/wp-content/uploads/2022/06/GPI-2022-overall-scores-and-domains-2008-2022.xlsx), pristupljeno 05.01.2025.<br>
# [3] World Happiness Report (n.d.). *FAQ*. [Link na pregled stranice](https://worldhappiness.report/faq/), pristupljeno 30.12.2024.<br>
# [4] World Happiness Report (2023.). *World Happiness, Trust and Social Connections in Times of Crisis*. [Link na pregled članka](https://worldhappiness.report/ed/2023/world-happiness-trust-and-social-connections-in-times-of-crisis/), pristupljeno 05.01.2025.<br>
# [5] Stackoverflow (2019.). *Create a Database using Python on Jupyter Notebook*. [Link na pregled foruma](https://stackoverflow.com/questions/52122119/create-database-using-python-on-jupyter-notebook), pristupljeno 05.01.2025.<br>
# [6] Pandas (2024.). *Pandas documentation*. [Link na pregled stranice](https://pandas.pydata.org/docs/index.html), pristupljeno 05.01.2025.<br>
# [7] FOI, Schatten, M. (2024.). *Applied Concepts in Data Analytics*. [Link na pregled stranice](https://colab.research.google.com/drive/10tWVfRrx7TdnmAvEnX-WZHR2hG_QrBSF?usp=sharing#scrollTo=h_blBE_fqQU6), pristupljeno 05.01.2025.<br>
# [8] Wikipedia (2003.). *ISO 3166-1*. [Link na pregled stranice](https://en.wikipedia.org/wiki/ISO_3166-1), pristupljeno 10.01.2025.<br>
# [9] FOI, (2023.). *Laboratorijske vježbe iz kolegija Uvod u umjetnu inteligenciju*. Pristupljeno 05.01.2025.<br>
# [10] llego.dev (2023.). *Filling Missing Values in Pandas*. [Link na pristup stranici](https://llego.dev/posts/filling-missing-values-pandas-fillna-interpolate/), pristupljeno 10.01.2025.<br>
# [11] Geeks for geeks, (2023.). *Using Request Args for a Variable URL in Flask*. [Link na pristup stranici](https://www.geeksforgeeks.org/using-request-args-for-a-variable-url-in-flask/), pristupljeno 10.01.2025.<br>
# [12] W3schools, (n.d.). *Matplotlib Subplot*. [Link za pristup stranici](https://www.w3schools.com/python/matplotlib_subplot.asp), pristupljeno 10.01.2025.<br>
